# %%
import math
import numpy as np
from numpy.random import default_rng

import scipy
from scipy.stats import qmc
from smt.sampling_methods import LHS

from sklearn.metrics import mean_squared_error

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import MaxNLocator

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import Tensor
import gpytorch
from sklearn.decomposition import PCA

import time
import os
os.makedirs("fig/0/", exist_ok=True)
os.makedirs("data/0/", exist_ok=True)

# %matplotlib inline 
font = {'size'   : 30}
matplotlib.rc('font', **font)
cbformat = matplotlib.ticker.ScalarFormatter()   # create the formatter
cbformat.set_powerlimits((-2,2))
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
torch.set_default_dtype(torch.float)
torch.set_default_device(device)
torch.set_printoptions(precision=10)

# %%
class Sine(nn.Module):
    def __init__(self, w0=1.0):
        super().__init__()
        self.w0 = w0

    def forward(self, x):
        return torch.sin(self.w0 * x)

# %%
class Autoencoder(nn.Module):
    def __init__(self, input_dim, latent_dim, hidden_dims=[6,],
                 activation=nn.LogSigmoid, activation_kwargs=None):
        super().__init__()
        if activation_kwargs is None:
            activation_kwargs = {}
        act = lambda: activation(**activation_kwargs)

        # ----- Encoder -----
        encoder_layers = []
        prev_dim = input_dim
        for h in hidden_dims:
            encoder_layers.append(nn.Linear(prev_dim, h))
            encoder_layers.append(nn.LayerNorm(h))
            encoder_layers.append(act())
            prev_dim = h
        encoder_layers.append(nn.Linear(prev_dim, latent_dim))  # Final layer to latent
        encoder_layers.append(nn.LayerNorm(latent_dim))
        encoder_layers.append(act())
        self.encoder_net = nn.Sequential(*encoder_layers)

        # ----- Decoder -----
        decoder_layers = []
        prev_dim = latent_dim
        for h in reversed(hidden_dims):
            decoder_layers.append(nn.Linear(prev_dim, h))
            decoder_layers.append(act())
            prev_dim = h
        decoder_layers.append(nn.Linear(prev_dim, input_dim))  # Final output
        self.decoder_net = nn.Sequential(*decoder_layers)

    def encode(self, x):
        return self.encoder_net(x)

    def decode(self, z):
        return self.decoder_net(z)

    def forward(self, x):
        z = self.encode(x)
        x_hat = self.decode(z)
        return x_hat, z

    def ae_loss(self, x, lambda_l2_z=0., lambda_l2_param=0.):
        """
        AE loss with optional latent L2 and parameter L2 regularization
    
        Args:
            x: input tensor
            lambda_l2_z: regularization on latent code z (default 1e-3)
            lambda_l2_param: explicit L2 on model parameters (default 1e-3)
    
        Returns:
            total_loss, recon_loss, latent_l2, param_l2
        """
        x_hat, z = self.forward(x)
        recon_loss = F.mse_loss(x_hat, x, reduction='mean')
    
        # --- Latent code regularization ---
        latent_l2 = torch.mean(z.pow(2)) if lambda_l2_z > 0 else torch.tensor(0., device=x.device)
    
        # --- Explicit parameter regularization ---
        param_l2 = torch.tensor(0., device=x.device)
        if lambda_l2_param > 0:
            for param in self.parameters():
                if param.requires_grad:
                    param_l2 += torch.sum(param.pow(2))
    
        total_loss = recon_loss + lambda_l2_z * latent_l2 + lambda_l2_param * param_l2
        return total_loss, recon_loss, latent_l2, param_l2

# %%
class ParametricGP(nn.Module):
    def __init__(self, latent_dim):
        super().__init__()
        self.log_lengthscale = nn.Parameter(torch.zeros(latent_dim))  # θ_l
        self.log_eta = nn.Parameter(torch.tensor(-1.0))                # log η
        self._last_tau2_hat = 1.0

    def kernel(self, x1, x2):
        """
        Gaussian RBF kernel with ARD (SE-ARD), scaled by tau².
        """
        lengthscale = torch.exp(self.log_lengthscale)
        x1_ = x1 / lengthscale
        x2_ = x2 / lengthscale
        dist_sq = torch.cdist(x1_, x2_, p=2).pow(2)
        return torch.exp(-0.5 * dist_sq)  # base kernel k(x,x')

    def compute_K_eta(self, x):
        """
        Return K + ηI (without τ²), to be scaled externally.
        """
        K = self.kernel(x, x)
        eta = torch.exp(self.log_eta)
        N = x.size(0)
        return K + eta * torch.eye(N, device=x.device)

    def predict(self, x_train, y_train, x_test):
        """
        GP posterior mean and variance following Eqn (2.2) from your paper.
        """
        K_eta = self.compute_K_eta(x_train)
        k_star = self.kernel(x_train, x_test)
        k_ss_diag = torch.ones(x_test.size(0), device=x_test.device)  # since k(x,x)=1

        L = torch.linalg.cholesky(K_eta + 1e-8 * torch.eye(K_eta.shape[0], device=K_eta.device))
        alpha = torch.cholesky_solve(y_train, L)

        # Estimate τ² from data
        N = y_train.shape[0]
        tau2_hat = ((y_train.T @ alpha) / N).squeeze().detach()
        self._last_tau2_hat = tau2_hat.item()

        mean = k_star.T @ alpha                                 # (M, 1)
        v = torch.cholesky_solve(k_star, L)
        k_star_Kinv_k_star = (k_star.T @ v).diagonal().unsqueeze(-1)
        eta = torch.exp(self.log_eta)

        var = tau2_hat * (1 + eta - k_star_Kinv_k_star)         # (M, 1)
        return mean, var

    def log_marginal_likelihood(self, x_train, y_train):
        """
        Profiled log-likelihood over η, using τ² = yᵀ K⁻¹ y / N
        """
        K_eta = self.compute_K_eta(x_train)
        L = torch.linalg.cholesky(K_eta + 1e-8 * torch.eye(K_eta.shape[0], device=K_eta.device))
        alpha = torch.cholesky_solve(y_train, L)

        N = y_train.shape[0]
        tau2_hat = ((y_train.T @ alpha) / N).squeeze().detach()
        self._last_tau2_hat = tau2_hat.item()

        term1 = y_train.T @ alpha
        term2 = torch.logdet(K_eta)
        return -(term1 + term2).squeeze()
    def log_marginal_likelihood(self, x_train, y_train):
       """
       Log marginal likelihood, with τ² = hat τ²
       """
       N = y_train.shape[0]
       K_eta = self.compute_K_eta(x_train)            # (N, N)
       L = torch.linalg.cholesky(K_eta + 1e-8 * torch.eye(N, device=K_eta.device))
       alpha = torch.cholesky_solve(y_train, L)           # (N, 1)
    
       tau2_hat = (y_train.T @ alpha) / N                 # scalar
       term1 = N * tau2_hat.log()
       term2 = 2 * L.diag().log().sum()
       # const: term3 = N * math.log(2 * math.pi)
    
       nll = term1 + term2 # half positive log likelihood
       return -nll.squeeze()

    def get_hyperparams(self):
        return {
            "lengthscale": torch.exp(self.log_lengthscale).detach(),
            "eta": torch.exp(self.log_eta).item(),
            "tau²_hat": self._last_tau2_hat
        }

# %%
class JointModel(nn.Module):
    def __init__(self, ae, gp):
        """
        ae: Autoencoder model (with .encode(x): (N, d))
        gp: ParametricGP model (with .predict and .log_marginal_likelihood)
        """
        super().__init__()
        self.ae = ae
        self.gp = gp

    def forward(self, x_train, y_train, x_test):
        """
        Run AE + GP prediction pipeline

        Args:
            x_train: (N, D) input data
            y_train: (N, 1) target values
            x_test:  (M, D) test input data

        Returns:
            y_pred: mean predictions (M, 1)
            y_var:  predictive variances (M, 1)
        """
        z_train = self.ae.encode(x_train)  # (N, d)
        z_test = self.ae.encode(x_test)    # (M, d)
        return self.gp.predict(z_train, y_train, z_test)

    def loss(self, x, y):
        """
        Loss function: AE reconstruction + GP negative log marginal likelihood

        Args:
            x: (N, D)
            y: (N, 1)

        Returns:
            total_loss:  scalar
            ae_loss:     scalar
            gp_nll:      scalar
        """
        # Autoencoder loss
        ae_total, ae_recon, _, _ = self.ae.ae_loss(x)

        # GP negative log marginal likelihood
        z = self.ae.encode(x)
        gp_nll = -self.gp.log_marginal_likelihood(z, y)  # (maximize log-likelihood = minimize -ll)

        # Combined loss
        total_loss = ae_total + gp_nll
        #return total_loss, ae_total, gp_nll
        return gp_nll, ae_total, gp_nll

# %%
def generate_dataset_for_al_gp(
    N_train=10,
    N_test=500,
    N_ref=100,
    N_cand=100,
    noise_scale=0.1,
    device="cpu",
    seed=None
):
    """
    Generate active learning sets on a unit sphere with v=cos(phi), theta parameterization.
    Target function: f(x) = cos(x1) + x2^2 + exp(x3)

    Returns:
        x_train, y_train
        x_test, y_test
        x_ref, y_ref
        x_cand, y_cand
    """
    if seed is not None:
        np.random.seed(seed)
        torch.manual_seed(seed)

    def f(x):
        x1 = x[:, 0]
        x2 = x[:, 1]
        x3 = x[:, 2]
        return (np.cos(x1) + x2**2 + np.exp(x3)).reshape(-1, 1).astype(np.float32)

    def sample_sphere(N):
        # v in [-1,1], theta in [0, 2pi]
        xlimits = np.array([[-1, 1], [0, 2*np.pi]])
        lhs = LHS(xlimits=xlimits, criterion="maximin")
        v_theta = lhs(N)
        v = v_theta[:, 0]
        theta = v_theta[:, 1]

        x = np.zeros((N, 3), dtype=np.float32)
        sin_phi = np.sqrt(1 - v**2)
        x[:, 0] = sin_phi * np.cos(theta)
        x[:, 1] = sin_phi * np.sin(theta)
        x[:, 2] = v

        y = f(x)
        return x, y

    def add_noise(y, scale):
        return y + np.random.randn(*y.shape) * scale

    def to_tensor(x, y):
        return (
            torch.tensor(x, dtype=torch.float32, device=device),
            torch.tensor(y, dtype=torch.float32, device=device),
        )

    # Training
    x_train_np, y_train_np = sample_sphere(N_train)
    y_train_np = add_noise(y_train_np, noise_scale)

    # Test
    x_test_np, y_test_np = sample_sphere(N_test)
    y_test_np = add_noise(y_test_np, noise_scale)

    # Reference
    x_ref_np, y_ref_np = sample_sphere(N_ref)

    # Candidate
    x_cand_np, y_cand_np = sample_sphere(N_cand)
    y_cand_np = add_noise(y_cand_np, noise_scale)

    return (
        *to_tensor(x_train_np, y_train_np),
        *to_tensor(x_test_np, y_test_np),
        *to_tensor(x_ref_np, y_ref_np),
        *to_tensor(x_cand_np, y_cand_np)
    )

# %%
def train_joint(
    model, x_train, y_train,
    max_outer_iter=5000,
    max_inner_iter=10,
    tol_loss_change_pct=1e-4,
    verbose=False,
):
    """
    Train a JointModel using L-BFGS with outer loop and early stopping.

    Args:
        model: JointModel instance
        x_train: (N, D)
        y_train: (N, 1)
        max_outer_iter: number of outer optimization steps
        max_inner_iter: L-BFGS inner max_iter
        tol_loss_change_pct: relative loss change to early stop
        verbose: whether to print log

    Returns:
        loss_history: list of total loss per outer iteration
    """
    loss_history = []

    optimizer = torch.optim.LBFGS(
        model.parameters(),
        lr=0.01,
        history_size=20,
        max_iter=max_inner_iter,
        line_search_fn="strong_wolfe"
    )

    for outer_epoch in range(max_outer_iter):
        def closure():
            optimizer.zero_grad()
            total_loss, ae_loss, gp_nll = model.loss(x_train, y_train)
            if torch.isnan(total_loss) or torch.isinf(total_loss):
                print("  total_loss is NaN/Inf")
            if torch.isnan(ae_loss) or torch.isinf(ae_loss):
                print("  ae_loss is NaN/Inf")
            if torch.isnan(gp_nll) or torch.isinf(gp_nll):
                print("  gp_nll is NaN/Inf")
            total_loss.backward()
            if verbose:
                print(f"[Epoch {outer_epoch:03d}] Total: {total_loss.item():.5f} | AE: {ae_loss.item():.5f} | GP-NLL: {gp_nll.item():.5f}")
            return total_loss

        optimizer.step(closure)

        # Compute current loss for stopping check
        with torch.no_grad():
            current_loss, _, _ = model.loss(x_train, y_train)
            loss_history.append(current_loss.item())

        # Early stopping check
        if len(loss_history) >= 2:
            numer = abs(loss_history[-1] - loss_history[-2])
            denom = abs(loss_history[-1] - loss_history[0]) + 1e-8
            rel_change = numer / denom
            if rel_change < tol_loss_change_pct:
                if verbose:
                    print(f"[Stopping] Relative loss change {rel_change:.2e} < tol {tol_loss_change_pct}")
                break
    return loss_history

# %%
def alc_acquisition(model, x_train, y_train, x_cand, x_ref, k_variance=10):
    """
    Two-stage ALC acquisition:
    1. From all candidates, pick top-k_variance with highest posterior variance.
    2. Among these, compute exact ALC (Cohn style) and select best one.
    """
    model.gp.eval()
    model.ae.eval()

    N, Nc, Nr = x_train.shape[0], x_cand.shape[0], x_ref.shape[0]
    device = x_train.device

    with torch.no_grad():
        # Encode inputs
        z_train = model.ae.encode(x_train)
        z_cand = model.ae.encode(x_cand)
        z_ref = model.ae.encode(x_ref)

        # GP kernel and posterior variance
        K = model.gp.compute_K_eta(z_train)  # (N, N)
        L = torch.linalg.cholesky(K + 1e-8 * torch.eye(N, device=device))
        K_s = model.gp.kernel(z_train, z_cand)  # (N, Nc)
        v = torch.cholesky_solve(K_s, L)
        var_cand = model.gp.compute_K_eta(z_cand).diagonal(dim1=0, dim2=1) - (K_s * v).sum(dim=0)
        #print(var_cand)
        #mean_cand,var_cand = model.gp.predict(z_train, y_train, z_cand)
        #print(var_cand)

        topk_var_idx = torch.topk(var_cand, k=min(k_variance, Nc)).indices

        # Compute tau² (MLE of variance)
        alpha = torch.cholesky_solve(y_train, L)
        tau2_hat = (y_train.T @ alpha / N).squeeze()

        # Base posterior covariance at z_ref
        K_s_ref = model.gp.kernel(z_train, z_ref)
        K_ss_ref = model.gp.kernel(z_ref,z_ref)
        v_ref = torch.cholesky_solve(K_s_ref, L)
        cov_orig = K_ss_ref - K_s_ref.T @ v_ref
        trace_orig = cov_orig.diag().sum()

        # Evaluate ALC among top candidates
        best_score = -float('inf')
        best_idx = -1

        for idx in topk_var_idx:
            x_aug = torch.vstack([x_train, x_cand[idx:idx+1]])
            z_aug = model.ae.encode(x_aug)

            K_aug = model.gp.compute_K_eta(z_aug)
            L_aug = torch.linalg.cholesky(K_aug + 1e-8 * torch.eye(K_aug.size(0), device=device))

            K_s_aug = model.gp.kernel(z_aug, z_ref)
            K_ss_aug = model.gp.kernel(z_ref,z_ref)
            v_aug = torch.cholesky_solve(K_s_aug, L_aug)
            cov_new = K_ss_aug - K_s_aug.T @ v_aug

            trace_new = cov_new.diag().sum()
            alc_score = tau2_hat * (trace_orig - trace_new)

            if alc_score > best_score:
                best_score = alc_score
                best_idx = idx.item()

    return best_idx, best_score

# %%
def run_active_learning(
    model, x_train_init, y_train_init,
    x_cand, y_cand,
    x_ref, x_test, y_test,
    T=100,
    save_plot_path=None,
    randomAC = False,
    topk=100,
    epsilon=0.02,     # RMSE 阈值
    delta=1e-4,       # 最小改进
    patience=3        # 连续容忍次数
):
    """
    Active learning loop with early stopping based on RMSE threshold and small improvement tolerance.
    """
    x_train = x_train_init.clone()
    y_train = y_train_init.clone()

    rmse_list = []
    T = min(T, len(y_cand))
    slow_count = 0

    for t in range(T):
        print(f"\n--- Round {t} ---")

        # Retrain model
        model.train()
        train_joint(model, x_train, y_train, max_outer_iter=5000, max_inner_iter=20, verbose=False)
        print(model.gp.get_hyperparams())

        # Evaluate on test
        model.eval()
        with torch.no_grad():
            z_train = model.ae.encode(x_train)
            z_test = model.ae.encode(x_test)
            y_pred, y_var = model.gp.predict(z_train, y_train, z_test)
            rmse = torch.sqrt(torch.mean((y_pred - y_test) ** 2)).item()
            print(f"Test RMSE: {rmse:.4f}")
            rmse_list.append(rmse)
        if randomAC:
            best_idx = np.random.choice(len(y_cand), size=1, replace=False)
        else:
            # ALC acquisition from x_cand
            best_idx, _ = alc_acquisition(model, x_train, y_train, x_cand, x_ref, k_variance=topk)
        if isinstance(best_idx, int):
            best_idx = [best_idx]

        # Add selected point to training set
        x_new = x_cand[best_idx]
        y_new = y_cand[best_idx]
        x_train = torch.cat([x_train, x_new], dim=0)
        y_train = torch.cat([y_train, y_new], dim=0)

        # Remove selected from candidate pool
        mask = torch.ones(len(x_cand), dtype=torch.bool, device=x_cand.device)
        mask[best_idx] = False
        x_cand = x_cand[mask]
        y_cand = y_cand[mask]
    return {
        "rmse": np.array(rmse_list),
        "final_x_train": x_train,
        "final_y_train": y_train,
        "x_test": x_test
    }

# %%
# === 2. 生成数据 ===
x_train, y_train, x_test, y_test, x_ref, y_ref, x_cand, y_cand = generate_dataset_for_al_gp(
    N_train=50,
    N_test=500,
    N_ref=5000,
    N_cand=5000,
    noise_scale=0.,
    device=device,
    seed=None
)
np.save('data/0/ALAEmGP-2dSynthetic-xtrainInitial.npy',x_train.cpu().numpy())
np.save('data/0/ALAEmGP-2dSynthetic-ytrainInitial.npy',y_train.cpu().numpy())

# === 3. 初始化模型 ===
ae = Autoencoder(input_dim=3, latent_dim=2,hidden_dims=[10]).to(device)
gp = ParametricGP(latent_dim=2).to(device)
model = JointModel(ae, gp).to(device)

import copy

ae_copy = Autoencoder(input_dim=3, latent_dim=2, hidden_dims=[10]).to(device)
gp_copy = ParametricGP(latent_dim=2).to(device)
model_copy = JointModel(ae_copy, gp_copy).to(device)

model_copy.load_state_dict(copy.deepcopy(model.state_dict()))

# === 4. 运行主循环 ===
result = run_active_learning(
    model=model,
    x_train_init=x_train,
    y_train_init=y_train,
    x_cand=x_cand,
    y_cand=y_cand,
    x_ref=x_ref,
    x_test=x_test,
    y_test=y_test,
    T=100,
    save_plot_path="fig/0/ALAEmGP-2dSynthetic",
    randomAC=False
)

np.save('data/0/ALAEmGP-2dSynthetic-xtest.npy',result['x_test'].cpu().numpy())
np.save('data/0/ALAEmGP-2dSynthetic-xtrainFinal.npy',result['final_x_train'].cpu().numpy())
np.save('data/0/ALAEmGP-2dSynthetic-ytrainFinal.npy',result['final_y_train'].cpu().numpy())
np.save('data/0/ALAEmGP-2dSynthetic-testrmse.npy',result['rmse'])
# Out:
# --- Round 0 ---
# {'lengthscale': tensor([0.9998788834, 0.9944841266], device='cuda:0'), 'eta': 0.12373961508274078, 'tau²_hat': 1.0}
# Test RMSE: 0.7313
#
# --- Round 1 ---
# {'lengthscale': tensor([0.9998793006, 0.9943894744], device='cuda:0'), 'eta': 0.12363076955080032, 'tau²_hat': 4.600350856781006}
# Test RMSE: 0.7314
#
# --- Round 2 ---
# {'lengthscale': tensor([1.0000573397, 0.9967865944], device='cuda:0'), 'eta': 0.11023011058568954, 'tau²_hat': 4.51741361618042}
# Test RMSE: 0.7316
#
# --- Round 3 ---
# {'lengthscale': tensor([1.0000573397, 0.9967865944], device='cuda:0'), 'eta': 0.11023011058568954, 'tau²_hat': 4.9931230545043945}
# Test RMSE: 0.7323
#
# --- Round 4 ---
# {'lengthscale': tensor([1.0000573397, 0.9967865944], device='cuda:0'), 'eta': 0.11023011058568954, 'tau²_hat': 5.053117752075195}
# Test RMSE: 0.7320
#
# --- Round 5 ---
# {'lengthscale': tensor([1.0000573397, 0.9967865944], device='cuda:0'), 'eta': 0.11023011058568954, 'tau²_hat': 4.981539249420166}
# Test RMSE: 0.7320
#
# --- Round 6 ---
# {'lengthscale': tensor([1.0000573397, 0.9967865944], device='cuda:0'), 'eta': 0.11023011058568954, 'tau²_hat': 4.891860485076904}
# Test RMSE: 0.7327
#
# --- Round 7 ---
# {'lengthscale': tensor([1.0000573397, 0.9967865944], device='cuda:0'), 'eta': 0.11023011058568954, 'tau²_hat': 4.884787082672119}
# Test RMSE: 0.7334
#
# --- Round 8 ---
# {'lengthscale': tensor([1.0000573397, 0.9967865944], device='cuda:0'), 'eta': 0.11023011058568954, 'tau²_hat': 4.852156162261963}
# Test RMSE: 0.7334
#
# --- Round 9 ---
# {'lengthscale': tensor([1.0000573397, 0.9967865944], device='cuda:0'), 'eta': 0.11023011058568954, 'tau²_hat': 4.768540859222412}
# Test RMSE: 0.7348
#
# --- Round 10 ---
# {'lengthscale': tensor([1.0000573397, 0.9967865944], device='cuda:0'), 'eta': 0.11023011058568954, 'tau²_hat': 4.830400466918945}
# Test RMSE: 0.7342
#
# --- Round 11 ---
# {'lengthscale': tensor([1.0000573397, 0.9967865944], device='cuda:0'), 'eta': 0.11023011058568954, 'tau²_hat': 4.774655342102051}
# Test RMSE: 0.7334
#
# --- Round 12 ---
# {'lengthscale': tensor([1.0000952482, 0.9955095649], device='cuda:0'), 'eta': 0.10567202419042587, 'tau²_hat': 4.747513294219971}
# Test RMSE: 0.7339
#
# --- Round 13 ---
# {'lengthscale': tensor([1.0000952482, 0.9955095649], device='cuda:0'), 'eta': 0.10567202419042587, 'tau²_hat': 4.892717361450195}
# Test RMSE: 0.7355
#
# --- Round 14 ---
# {'lengthscale': tensor([1.0000952482, 0.9955095649], device='cuda:0'), 'eta': 0.10567202419042587, 'tau²_hat': 4.970873832702637}
# Test RMSE: 0.7371
#
# --- Round 15 ---
# {'lengthscale': tensor([1.0000952482, 0.9955095649], device='cuda:0'), 'eta': 0.10567202419042587, 'tau²_hat': 5.018405914306641}
# Test RMSE: 0.7377
#
# --- Round 16 ---
# {'lengthscale': tensor([1.0000952482, 0.9955095649], device='cuda:0'), 'eta': 0.10567202419042587, 'tau²_hat': 4.9530439376831055}
# Test RMSE: 0.7364
#
# --- Round 17 ---
# {'lengthscale': tensor([1.0000952482, 0.9955095649], device='cuda:0'), 'eta': 0.10567202419042587, 'tau²_hat': 4.9431962966918945}
# Test RMSE: 0.7382
#
# --- Round 18 ---
# {'lengthscale': tensor([1.0000952482, 0.9955095649], device='cuda:0'), 'eta': 0.10567202419042587, 'tau²_hat': 4.988674640655518}
# Test RMSE: 0.7380
#
# --- Round 19 ---
# {'lengthscale': tensor([1.0000952482, 0.9955095649], device='cuda:0'), 'eta': 0.10567202419042587, 'tau²_hat': 4.916864395141602}
# Test RMSE: 0.7398
#
# --- Round 20 ---
# {'lengthscale': tensor([1.0000952482, 0.9955095649], device='cuda:0'), 'eta': 0.10567202419042587, 'tau²_hat': 4.952456474304199}
# Test RMSE: 0.7371
#
# --- Round 21 ---
# {'lengthscale': tensor([1.0000952482, 0.9955095649], device='cuda:0'), 'eta': 0.10567202419042587, 'tau²_hat': 5.133133888244629}
# Test RMSE: 0.7353
#
# --- Round 22 ---
# {'lengthscale': tensor([1.0000952482, 0.9955095649], device='cuda:0'), 'eta': 0.10567202419042587, 'tau²_hat': 5.229907989501953}
# Test RMSE: 0.7351
#
# --- Round 23 ---
# {'lengthscale': tensor([1.0000952482, 0.9955095649], device='cuda:0'), 'eta': 0.10567202419042587, 'tau²_hat': 5.159198760986328}
# Test RMSE: 0.7362
#
# --- Round 24 ---
# {'lengthscale': tensor([1.0000952482, 0.9955095649], device='cuda:0'), 'eta': 0.10567202419042587, 'tau²_hat': 5.155550003051758}
# Test RMSE: 0.7377
#
# --- Round 25 ---
# {'lengthscale': tensor([1.0000952482, 0.9955095649], device='cuda:0'), 'eta': 0.10567202419042587, 'tau²_hat': 5.192538738250732}
# Test RMSE: 0.7356
#
# --- Round 26 ---
# {'lengthscale': tensor([1.0000952482, 0.9955095649], device='cuda:0'), 'eta': 0.10567202419042587, 'tau²_hat': 5.332961559295654}
# Test RMSE: 0.7352
#
# --- Round 27 ---
# {'lengthscale': tensor([1.0000952482, 0.9955095649], device='cuda:0'), 'eta': 0.10567202419042587, 'tau²_hat': 5.272393703460693}
# Test RMSE: 0.7365
#
# --- Round 28 ---
# {'lengthscale': tensor([1.0000952482, 0.9955095649], device='cuda:0'), 'eta': 0.10567202419042587, 'tau²_hat': 5.302145957946777}
# Test RMSE: 0.7372
#
# --- Round 29 ---
# {'lengthscale': tensor([1.0000952482, 0.9955095649], device='cuda:0'), 'eta': 0.10567202419042587, 'tau²_hat': 5.253227710723877}
# Test RMSE: 0.7378
#
# --- Round 30 ---
# {'lengthscale': tensor([1.0000952482, 0.9955094457], device='cuda:0'), 'eta': 0.10567288100719452, 'tau²_hat': 5.204805374145508}
# Test RMSE: 0.7383
#
# --- Round 31 ---
# {'lengthscale': tensor([1.0000952482, 0.9955094457], device='cuda:0'), 'eta': 0.10567396879196167, 'tau²_hat': 5.150178909301758}
# Test RMSE: 0.7394
#
# --- Round 32 ---
# {'lengthscale': tensor([1.0000952482, 0.9955094457], device='cuda:0'), 'eta': 0.10567396879196167, 'tau²_hat': 5.133698463439941}
# Test RMSE: 0.7405
#
# --- Round 33 ---
# {'lengthscale': tensor([1.0000952482, 0.9955094457], device='cuda:0'), 'eta': 0.10567396879196167, 'tau²_hat': 5.10838508605957}
# Test RMSE: 0.7411
#
# --- Round 34 ---
# {'lengthscale': tensor([1.0000952482, 0.9955094457], device='cuda:0'), 'eta': 0.10567396879196167, 'tau²_hat': 5.0588202476501465}
# Test RMSE: 0.7419
#
# --- Round 35 ---
# {'lengthscale': tensor([1.0000952482, 0.9955094457], device='cuda:0'), 'eta': 0.10567396879196167, 'tau²_hat': 5.016293525695801}
# Test RMSE: 0.7424
#
# --- Round 36 ---
# {'lengthscale': tensor([1.0000952482, 0.9955094457], device='cuda:0'), 'eta': 0.10567396879196167, 'tau²_hat': 4.963491916656494}
# Test RMSE: 0.7412
#
# --- Round 37 ---
# {'lengthscale': tensor([1.0000952482, 0.9955094457], device='cuda:0'), 'eta': 0.10567396879196167, 'tau²_hat': 4.95050048828125}
# Test RMSE: 0.7412
#
# --- Round 38 ---
# {'lengthscale': tensor([1.0000952482, 0.9955094457], device='cuda:0'), 'eta': 0.10567396879196167, 'tau²_hat': 4.893730640411377}
# Test RMSE: 0.7405
#
# --- Round 39 ---
# {'lengthscale': tensor([1.0000952482, 0.9955094457], device='cuda:0'), 'eta': 0.10567396879196167, 'tau²_hat': 4.854946613311768}
# Test RMSE: 0.7385
#
# --- Round 40 ---
# {'lengthscale': tensor([1.0000952482, 0.9955094457], device='cuda:0'), 'eta': 0.10567396879196167, 'tau²_hat': 4.9540300369262695}
# Test RMSE: 0.7388
#
# --- Round 41 ---
# {'lengthscale': tensor([1.0000952482, 0.9955094457], device='cuda:0'), 'eta': 0.10567396879196167, 'tau²_hat': 4.902631759643555}
# Test RMSE: 0.7368
#
# --- Round 42 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567129403352737, 'tau²_hat': 5.045544624328613}
# Test RMSE: 0.7375
#
# --- Round 43 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567129403352737, 'tau²_hat': 5.018001556396484}
# Test RMSE: 0.7360
#
# --- Round 44 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567129403352737, 'tau²_hat': 5.088743686676025}
# Test RMSE: 0.7348
#
# --- Round 45 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567129403352737, 'tau²_hat': 5.157573699951172}
# Test RMSE: 0.7343
#
# --- Round 46 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567129403352737, 'tau²_hat': 5.120883941650391}
# Test RMSE: 0.7342
#
# --- Round 47 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567129403352737, 'tau²_hat': 5.070554256439209}
# Test RMSE: 0.7333
#
# --- Round 48 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567129403352737, 'tau²_hat': 5.137082099914551}
# Test RMSE: 0.7329
#
# --- Round 49 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 5.108668804168701}
# Test RMSE: 0.7332
#
# --- Round 50 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 5.07829475402832}
# Test RMSE: 0.7331
#
# --- Round 51 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 5.03092098236084}
# Test RMSE: 0.7338
#
# --- Round 52 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 5.062306880950928}
# Test RMSE: 0.7344
#
# --- Round 53 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 5.055210590362549}
# Test RMSE: 0.7335
#
# --- Round 54 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 5.108253479003906}
# Test RMSE: 0.7335
#
# --- Round 55 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 5.059213638305664}
# Test RMSE: 0.7327
#
# --- Round 56 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 5.124152660369873}
# Test RMSE: 0.7328
#
# --- Round 57 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 5.076884746551514}
# Test RMSE: 0.7326
#
# --- Round 58 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 5.036712169647217}
# Test RMSE: 0.7327
#
# --- Round 59 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 4.9928879737854}
# Test RMSE: 0.7328
#
# --- Round 60 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 4.948047637939453}
# Test RMSE: 0.7329
#
# --- Round 61 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 4.904033660888672}
# Test RMSE: 0.7326
#
# --- Round 62 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 4.876987457275391}
# Test RMSE: 0.7328
#
# --- Round 63 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 4.844081401824951}
# Test RMSE: 0.7326
#
# --- Round 64 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 4.813457012176514}
# Test RMSE: 0.7326
#
# --- Round 65 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 4.771274566650391}
# Test RMSE: 0.7330
#
# --- Round 66 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 4.765594959259033}
# Test RMSE: 0.7334
#
# --- Round 67 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 4.765844821929932}
# Test RMSE: 0.7328
#
# --- Round 68 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 4.8209757804870605}
# Test RMSE: 0.7329
#
# --- Round 69 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 4.784703731536865}
# Test RMSE: 0.7325
#
# --- Round 70 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 4.785001754760742}
# Test RMSE: 0.7326
#
# --- Round 71 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 4.746702194213867}
# Test RMSE: 0.7326
#
# --- Round 72 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 4.707754611968994}
# Test RMSE: 0.7328
#
# --- Round 73 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567126423120499, 'tau²_hat': 4.680874347686768}
# Test RMSE: 0.7330
#
# --- Round 74 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.1056712418794632, 'tau²_hat': 4.648748397827148}
# Test RMSE: 0.7333
#
# --- Round 75 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.1056712418794632, 'tau²_hat': 4.641907691955566}
# Test RMSE: 0.7335
#
# --- Round 76 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.1056712418794632, 'tau²_hat': 4.611605167388916}
# Test RMSE: 0.7339
#
# --- Round 77 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.1056712418794632, 'tau²_hat': 4.595766067504883}
# Test RMSE: 0.7331
#
# --- Round 78 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.1056712418794632, 'tau²_hat': 4.683937072753906}
# Test RMSE: 0.7325
#
# --- Round 79 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.1056712418794632, 'tau²_hat': 4.74940299987793}
# Test RMSE: 0.7326
#
# --- Round 80 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.1056712418794632, 'tau²_hat': 4.717907905578613}
# Test RMSE: 0.7322
#
# --- Round 81 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.1056712418794632, 'tau²_hat': 4.752162456512451}
# Test RMSE: 0.7325
#
# --- Round 82 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.1056712418794632, 'tau²_hat': 4.768184661865234}
# Test RMSE: 0.7321
#
# --- Round 83 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.1056712418794632, 'tau²_hat': 4.818174362182617}
# Test RMSE: 0.7325
#
# --- Round 84 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.1056712418794632, 'tau²_hat': 4.8572678565979}
# Test RMSE: 0.7325
#
# --- Round 85 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.1056712418794632, 'tau²_hat': 4.82102108001709}
# Test RMSE: 0.7329
#
# --- Round 86 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.1056712418794632, 'tau²_hat': 4.82682991027832}
# Test RMSE: 0.7331
#
# --- Round 87 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.1056712418794632, 'tau²_hat': 4.8048319816589355}
# Test RMSE: 0.7328
#
# --- Round 88 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567106306552887, 'tau²_hat': 4.800576210021973}
# Test RMSE: 0.7324
#
# --- Round 89 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567106306552887, 'tau²_hat': 4.800241947174072}
# Test RMSE: 0.7324
#
# --- Round 90 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567106306552887, 'tau²_hat': 4.767926216125488}
# Test RMSE: 0.7325
#
# --- Round 91 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567106306552887, 'tau²_hat': 4.743785858154297}
# Test RMSE: 0.7321
#
# --- Round 92 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567106306552887, 'tau²_hat': 4.807774066925049}
# Test RMSE: 0.7319
#
# --- Round 93 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567106306552887, 'tau²_hat': 4.795376777648926}
# Test RMSE: 0.7317
#
# --- Round 94 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567106306552887, 'tau²_hat': 4.797529697418213}
# Test RMSE: 0.7319
#
# --- Round 95 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567106306552887, 'tau²_hat': 4.807267665863037}
# Test RMSE: 0.7321
#
# --- Round 96 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567106306552887, 'tau²_hat': 4.801180362701416}
# Test RMSE: 0.7323
#
# --- Round 97 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567106306552887, 'tau²_hat': 4.788598537445068}
# Test RMSE: 0.7324
#
# --- Round 98 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567106306552887, 'tau²_hat': 4.760399341583252}
# Test RMSE: 0.7324
#
# --- Round 99 ---
# {'lengthscale': tensor([1.0000952482, 0.9955093861], device='cuda:0'), 'eta': 0.10567106306552887, 'tau²_hat': 4.728257656097412}
# Test RMSE: 0.7327

# %%
print('final result', result['rmse'][-1])
print('first result', result['rmse'][0])
print('best result',min(result['rmse']))
plt.plot(result['rmse']);
# Out:
# final result 0.7327015995979309
# first result 0.7313189506530762
# best result 0.7313189506530762

# %%
result_random = run_active_learning(
    model=model_copy,
    x_train_init=x_train,
    y_train_init=y_train,
    x_cand=x_cand,
    y_cand=y_cand,
    x_ref=x_ref,
    x_test=x_test,
    y_test=y_test,
    T=100,
    save_plot_path="fig/0/rALAEmGP-2dSynthetic",
    randomAC=True
)
np.save('data/0/rALAEmGP-2dSynthetic-xtrainFinal.npy',result_random['final_x_train'].cpu().numpy())
np.save('data/0/rALAEmGP-2dSynthetic-ytrainFinal.npy',result_random['final_y_train'].cpu().numpy())
np.save('data/0/rALAEmGP-2dSynthetic-testrmse.npy',result_random['rmse'])
# Out:
# --- Round 0 ---
# {'lengthscale': tensor([0.9999665618, 0.9997904301], device='cuda:0'), 'eta': 0.11677302420139313, 'tau²_hat': 1.0}
# Test RMSE: 0.7461
#
# --- Round 1 ---
# {'lengthscale': tensor([0.9999665618, 0.9997904301], device='cuda:0'), 'eta': 0.11677302420139313, 'tau²_hat': 4.475561618804932}
# Test RMSE: 0.7463
#
# --- Round 2 ---
# {'lengthscale': tensor([0.9999665618, 0.9997904301], device='cuda:0'), 'eta': 0.11677302420139313, 'tau²_hat': 4.499835014343262}
# Test RMSE: 0.7465
#
# --- Round 3 ---
# {'lengthscale': tensor([0.9999665618, 0.9997904301], device='cuda:0'), 'eta': 0.11677302420139313, 'tau²_hat': 4.4941792488098145}
# Test RMSE: 0.7462
#
# --- Round 4 ---
# {'lengthscale': tensor([0.9999665618, 0.9997904301], device='cuda:0'), 'eta': 0.11677302420139313, 'tau²_hat': 4.5394439697265625}
# Test RMSE: 0.7464
#
# --- Round 5 ---
# {'lengthscale': tensor([0.9999665618, 0.9997904301], device='cuda:0'), 'eta': 0.11677302420139313, 'tau²_hat': 4.531432628631592}
# Test RMSE: 0.7463
#
# --- Round 6 ---
# {'lengthscale': tensor([0.9999665618, 0.9997904301], device='cuda:0'), 'eta': 0.11677302420139313, 'tau²_hat': 4.491024971008301}
# Test RMSE: 0.7461
#
# --- Round 7 ---
# {'lengthscale': tensor([0.9999665618, 0.9997904301], device='cuda:0'), 'eta': 0.11677302420139313, 'tau²_hat': 4.494723796844482}
# Test RMSE: 0.7460
#
# --- Round 8 ---
# {'lengthscale': tensor([1.0009077787, 1.0134623051], device='cuda:0'), 'eta': 0.11003196984529495, 'tau²_hat': 4.520845413208008}
# Test RMSE: 0.7460
#
# --- Round 9 ---
# {'lengthscale': tensor([1.0009077787, 1.0134623051], device='cuda:0'), 'eta': 0.11003196984529495, 'tau²_hat': 4.771368980407715}
# Test RMSE: 0.7461
#
# --- Round 10 ---
# {'lengthscale': tensor([1.0009077787, 1.0134623051], device='cuda:0'), 'eta': 0.11003196984529495, 'tau²_hat': 4.76336145401001}
# Test RMSE: 0.7461
#
# --- Round 11 ---
# {'lengthscale': tensor([1.0009071827, 1.0134515762], device='cuda:0'), 'eta': 0.10656490176916122, 'tau²_hat': 4.734585762023926}
# Test RMSE: 0.7461
#
# --- Round 12 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361436009407043, 'tau²_hat': 4.852731227874756}
# Test RMSE: 0.7460
#
# --- Round 13 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361436009407043, 'tau²_hat': 5.026065349578857}
# Test RMSE: 0.7460
#
# --- Round 14 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361436009407043, 'tau²_hat': 5.036750793457031}
# Test RMSE: 0.7461
#
# --- Round 15 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361436009407043, 'tau²_hat': 5.014858245849609}
# Test RMSE: 0.7462
#
# --- Round 16 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361436009407043, 'tau²_hat': 5.070140838623047}
# Test RMSE: 0.7461
#
# --- Round 17 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361436009407043, 'tau²_hat': 5.151177883148193}
# Test RMSE: 0.7462
#
# --- Round 18 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361436009407043, 'tau²_hat': 5.199875831604004}
# Test RMSE: 0.7461
#
# --- Round 19 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361436009407043, 'tau²_hat': 5.184545516967773}
# Test RMSE: 0.7460
#
# --- Round 20 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361436009407043, 'tau²_hat': 5.238686561584473}
# Test RMSE: 0.7461
#
# --- Round 21 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361436009407043, 'tau²_hat': 5.291087627410889}
# Test RMSE: 0.7461
#
# --- Round 22 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361436009407043, 'tau²_hat': 5.265296936035156}
# Test RMSE: 0.7460
#
# --- Round 23 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361436009407043, 'tau²_hat': 5.367852210998535}
# Test RMSE: 0.7460
#
# --- Round 24 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361436009407043, 'tau²_hat': 5.392244815826416}
# Test RMSE: 0.7461
#
# --- Round 25 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361436009407043, 'tau²_hat': 5.407180309295654}
# Test RMSE: 0.7462
#
# --- Round 26 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.453749179840088}
# Test RMSE: 0.7461
#
# --- Round 27 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.449200630187988}
# Test RMSE: 0.7461
#
# --- Round 28 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.414967060089111}
# Test RMSE: 0.7462
#
# --- Round 29 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.451528549194336}
# Test RMSE: 0.7461
#
# --- Round 30 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.462263584136963}
# Test RMSE: 0.7460
#
# --- Round 31 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.528497219085693}
# Test RMSE: 0.7460
#
# --- Round 32 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.502471446990967}
# Test RMSE: 0.7461
#
# --- Round 33 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.483388423919678}
# Test RMSE: 0.7462
#
# --- Round 34 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.525730133056641}
# Test RMSE: 0.7461
#
# --- Round 35 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.5562357902526855}
# Test RMSE: 0.7460
#
# --- Round 36 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.592127799987793}
# Test RMSE: 0.7460
#
# --- Round 37 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.560487747192383}
# Test RMSE: 0.7461
#
# --- Round 38 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.566349983215332}
# Test RMSE: 0.7461
#
# --- Round 39 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.527488708496094}
# Test RMSE: 0.7462
#
# --- Round 40 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.540465831756592}
# Test RMSE: 0.7463
#
# --- Round 41 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.518558025360107}
# Test RMSE: 0.7462
#
# --- Round 42 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.494545936584473}
# Test RMSE: 0.7461
#
# --- Round 43 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.508411407470703}
# Test RMSE: 0.7461
#
# --- Round 44 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.4750776290893555}
# Test RMSE: 0.7461
#
# --- Round 45 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.439770221710205}
# Test RMSE: 0.7461
#
# --- Round 46 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.402993679046631}
# Test RMSE: 0.7461
#
# --- Round 47 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.36607027053833}
# Test RMSE: 0.7460
#
# --- Round 48 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.340295314788818}
# Test RMSE: 0.7461
#
# --- Round 49 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.321737289428711}
# Test RMSE: 0.7461
#
# --- Round 50 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.294948101043701}
# Test RMSE: 0.7461
#
# --- Round 51 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.2653913497924805}
# Test RMSE: 0.7461
#
# --- Round 52 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.231743812561035}
# Test RMSE: 0.7462
#
# --- Round 53 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.213907241821289}
# Test RMSE: 0.7461
#
# --- Round 54 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.211458206176758}
# Test RMSE: 0.7461
#
# --- Round 55 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.186307907104492}
# Test RMSE: 0.7461
#
# --- Round 56 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.210895538330078}
# Test RMSE: 0.7462
#
# --- Round 57 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.179293155670166}
# Test RMSE: 0.7461
#
# --- Round 58 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.220233917236328}
# Test RMSE: 0.7461
#
# --- Round 59 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.244225025177002}
# Test RMSE: 0.7461
#
# --- Round 60 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.239460468292236}
# Test RMSE: 0.7462
#
# --- Round 61 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.252901554107666}
# Test RMSE: 0.7462
#
# --- Round 62 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.231204509735107}
# Test RMSE: 0.7461
#
# --- Round 63 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.272014617919922}
# Test RMSE: 0.7461
#
# --- Round 64 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.261900901794434}
# Test RMSE: 0.7461
#
# --- Round 65 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.284743785858154}
# Test RMSE: 0.7460
#
# --- Round 66 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.332371234893799}
# Test RMSE: 0.7461
#
# --- Round 67 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.336513042449951}
# Test RMSE: 0.7460
#
# --- Round 68 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.340654373168945}
# Test RMSE: 0.7461
#
# --- Round 69 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.309909820556641}
# Test RMSE: 0.7461
#
# --- Round 70 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.333630084991455}
# Test RMSE: 0.7462
#
# --- Round 71 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.320976257324219}
# Test RMSE: 0.7462
#
# --- Round 72 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.290245532989502}
# Test RMSE: 0.7463
#
# --- Round 73 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.31380033493042}
# Test RMSE: 0.7465
#
# --- Round 74 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.335910320281982}
# Test RMSE: 0.7464
#
# --- Round 75 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.320933818817139}
# Test RMSE: 0.7465
#
# --- Round 76 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.316644191741943}
# Test RMSE: 0.7465
#
# --- Round 77 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.288237571716309}
# Test RMSE: 0.7466
#
# --- Round 78 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.262302398681641}
# Test RMSE: 0.7467
#
# --- Round 79 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.240361213684082}
# Test RMSE: 0.7467
#
# --- Round 80 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.215631008148193}
# Test RMSE: 0.7469
#
# --- Round 81 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.215333938598633}
# Test RMSE: 0.7469
#
# --- Round 82 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.188380241394043}
# Test RMSE: 0.7466
#
# --- Round 83 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.231503009796143}
# Test RMSE: 0.7466
#
# --- Round 84 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.204034805297852}
# Test RMSE: 0.7466
#
# --- Round 85 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.175915241241455}
# Test RMSE: 0.7468
#
# --- Round 86 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.194064617156982}
# Test RMSE: 0.7468
#
# --- Round 87 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.166310787200928}
# Test RMSE: 0.7469
#
# --- Round 88 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.151825428009033}
# Test RMSE: 0.7471
#
# --- Round 89 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.159688472747803}
# Test RMSE: 0.7468
#
# --- Round 90 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.188305377960205}
# Test RMSE: 0.7469
#
# --- Round 91 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.169951438903809}
# Test RMSE: 0.7467
#
# --- Round 92 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.21449613571167}
# Test RMSE: 0.7465
#
# --- Round 93 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.207587718963623}
# Test RMSE: 0.7465
#
# --- Round 94 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.18093729019165}
# Test RMSE: 0.7466
#
# --- Round 95 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.159926891326904}
# Test RMSE: 0.7464
#
# --- Round 96 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.176495552062988}
# Test RMSE: 0.7465
#
# --- Round 97 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.153002738952637}
# Test RMSE: 0.7463
#
# --- Round 98 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.199547290802002}
# Test RMSE: 0.7464
#
# --- Round 99 ---
# {'lengthscale': tensor([1.0009785891, 1.0183191299], device='cuda:0'), 'eta': 0.10361376404762268, 'tau²_hat': 5.185178279876709}
# Test RMSE: 0.7464

# %%
print('final result', result_random['rmse'][-1])
print('first result', result_random['rmse'][0])
plt.plot(result_random['rmse']);
# Out:
# final result 0.7464359402656555
# first result 0.7461008429527283
