# %%
import math
import numpy as np

import scipy
from scipy.stats import qmc
from smt.sampling_methods import LHS

from sklearn.metrics import mean_squared_error

import matplotlib
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import Tensor

import os
os.makedirs("fig/0/", exist_ok=True)
os.makedirs("data/0/", exist_ok=True)

# %matplotlib inline 
font = {'size'   : 30}
matplotlib.rc('font', **font)
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
torch.set_default_dtype(torch.float)
torch.set_default_device(device)
torch.set_printoptions(precision=10)

# %%
class Sine(nn.Module):
    def __init__(self, w0=1.0):
        super().__init__()
        self.w0 = w0

    def forward(self, x):
        return torch.sin(self.w0 * x)

# %%
class Autoencoder(nn.Module):
    def __init__(self, input_dim, latent_dim, hidden_dims=[6,],
                 activation=nn.LogSigmoid, activation_kwargs=None):
        super().__init__()
        if activation_kwargs is None:
            activation_kwargs = {}
        act = lambda: activation(**activation_kwargs)

        # ----- Encoder -----
        encoder_layers = []
        prev_dim = input_dim
        for h in hidden_dims:
            encoder_layers.append(nn.Linear(prev_dim, h))
            encoder_layers.append(nn.BatchNorm1d(h,affine=False))
            #encoder_layers.append(nn.LayerNorm(h))
            encoder_layers.append(act())
            #encoder_layers.append(nn.Dropout(p=0.1))
            prev_dim = h
        encoder_layers.append(nn.Linear(prev_dim, latent_dim))  # Final layer to latent
        encoder_layers.append(nn.BatchNorm1d(latent_dim,affine=False))
        #encoder_layers.append(nn.LayerNorm(latent_dim))
        encoder_layers.append(act())
        self.encoder_net = nn.Sequential(*encoder_layers)

        # ----- Decoder -----
        decoder_layers = []
        prev_dim = latent_dim
        for h in reversed(hidden_dims):
            decoder_layers.append(nn.Linear(prev_dim, h))
            decoder_layers.append(act())
            prev_dim = h
        decoder_layers.append(nn.Linear(prev_dim, input_dim))  # Final output
        self.decoder_net = nn.Sequential(*decoder_layers)

    def encode(self, x):
        return self.encoder_net(x)

    def decode(self, z):
        return self.decoder_net(z)

    def forward(self, x):
        z = self.encode(x)
        x_hat = self.decode(z)
        return x_hat, z

    def ae_loss(self, x, lambda_l2_z=0.001, lambda_l2_param=0.001):
        """
        AE loss with optional latent L2 and parameter L2 regularization
    
        Args:
            x: input tensor
            lambda_l2_z: regularization on latent code z (default 1e-3)
            lambda_l2_param: explicit L2 on model parameters (default 1e-3)
    
        Returns:
            total_loss, recon_loss, latent_l2, param_l2
        """
        x_hat, z = self.forward(x)
        recon_loss = F.mse_loss(x_hat, x, reduction='mean')
    
        # --- Latent code regularization ---
        latent_l2 = torch.mean(z.pow(2)) if lambda_l2_z > 0 else torch.tensor(0., device=x.device)
    
        # --- Explicit parameter regularization ---
        param_l2 = torch.tensor(0., device=x.device)
        if lambda_l2_param > 0:
            for param in self.parameters():
                if param.requires_grad:
                    param_l2 += torch.sum(param.pow(2))
    
        total_loss = recon_loss + lambda_l2_z * latent_l2 + lambda_l2_param * param_l2
        return total_loss, recon_loss, latent_l2, param_l2

# %%
class ParametricGP(nn.Module):
    def __init__(self, latent_dim):
        super().__init__()
        self.log_lengthscale = nn.Parameter(torch.zeros(latent_dim))  # θ_l
        self.log_eta = nn.Parameter(torch.tensor(-1.0))                # log η
        self._last_tau2_hat = 1.0

    def kernel(self, x1, x2):
        """
        Gaussian RBF kernel with ARD (SE-ARD), scaled by tau².
        """
        lengthscale = torch.exp(self.log_lengthscale)
        x1_ = x1 / lengthscale
        x2_ = x2 / lengthscale
        dist_sq = torch.cdist(x1_, x2_, p=2).pow(2)
        return torch.exp(-0.5 * dist_sq)  # base kernel k(x,x')

    def compute_K_eta(self, x):
        """
        Return K + ηI (without τ²), to be scaled externally.
        """
        K = self.kernel(x, x)
        eta = torch.exp(self.log_eta)
        N = x.size(0)
        return K + eta * torch.eye(N, device=x.device)

    def predict(self, x_train, y_train, x_test):
        """
        GP posterior mean and variance following Eqn (2.2) from your paper.
        """
        K_eta = self.compute_K_eta(x_train)
        k_star = self.kernel(x_train, x_test)
        k_ss_diag = torch.ones(x_test.size(0), device=x_test.device)  # since k(x,x)=1

        L = torch.linalg.cholesky(K_eta + 1e-8 * torch.eye(K_eta.shape[0], device=K_eta.device))
        alpha = torch.cholesky_solve(y_train, L)

        # Estimate τ² from data
        N = y_train.shape[0]
        tau2_hat = ((y_train.T @ alpha) / N).squeeze().detach()
        self._last_tau2_hat = tau2_hat.item()

        mean = k_star.T @ alpha                                 # (M, 1)
        v = torch.cholesky_solve(k_star, L)
        k_star_Kinv_k_star = (k_star.T @ v).diagonal().unsqueeze(-1)
        eta = torch.exp(self.log_eta)

        var = tau2_hat * (1 + eta - k_star_Kinv_k_star)         # (M, 1)
        return mean, var

    def log_marginal_likelihood(self, x_train, y_train):
        """
        Profiled log-likelihood over η, using τ² = yᵀ K⁻¹ y / N
        """
        K_eta = self.compute_K_eta(x_train)
        L = torch.linalg.cholesky(K_eta + 1e-8 * torch.eye(K_eta.shape[0], device=K_eta.device))
        alpha = torch.cholesky_solve(y_train, L)

        N = y_train.shape[0]
        tau2_hat = ((y_train.T @ alpha) / N).squeeze().detach()
        self._last_tau2_hat = tau2_hat.item()

        term1 = y_train.T @ alpha
        term2 = torch.logdet(K_eta)
        return -(term1 + term2).squeeze()

    def log_marginal_likelihood(self, x_train, y_train):
       """
       Log marginal likelihood, with τ² = hat τ²
       """
       N = y_train.shape[0]
       K_eta = self.compute_K_eta(x_train)            # (N, N)
       L = torch.linalg.cholesky(K_eta + 1e-8 * torch.eye(N, device=K_eta.device))
       alpha = torch.cholesky_solve(y_train, L)           # (N, 1)
    
       tau2_hat = (y_train.T @ alpha) / N                 # scalar
       term1 = N * tau2_hat.log()
       term2 = 2 * L.diag().log().sum()
       # const: term3 = N * math.log(2 * math.pi)
    
       nll = term1 + term2 # half positive log likelihood
       return -nll.squeeze()

    def get_hyperparams(self):
        return {
            "lengthscale": torch.exp(self.log_lengthscale).detach(),
            "eta": torch.exp(self.log_eta).item(),
            "tau²_hat": self._last_tau2_hat
        }

# %%
class JointModel(nn.Module):
    def __init__(self, ae, gp):
        """
        ae: Autoencoder model (with .encode(x): (N, d))
        gp: ParametricGP model (with .predict and .log_marginal_likelihood)
        """
        super().__init__()
        self.ae = ae
        self.gp = gp

    def forward(self, x_train, y_train, x_test):
        """
        Run AE + GP prediction pipeline

        Args:
            x_train: (N, D) input data
            y_train: (N, 1) target values
            x_test:  (M, D) test input data

        Returns:
            y_pred: mean predictions (M, 1)
            y_var:  predictive variances (M, 1)
        """
        z_train = self.ae.encode(x_train)  # (N, d)
        z_test = self.ae.encode(x_test)    # (M, d)
        return self.gp.predict(z_train, y_train, z_test)

    def loss(self, x, y):
        """
        Loss function: AE reconstruction + GP negative log marginal likelihood

        Args:
            x: (N, D)
            y: (N, 1)

        Returns:
            total_loss:  scalar
            ae_loss:     scalar
            gp_nll:      scalar
        """
        # Autoencoder loss
        ae_total, ae_recon, _, _ = self.ae.ae_loss(x)

        # GP negative log marginal likelihood
        z = self.ae.encode(x)
        gp_nll = -self.gp.log_marginal_likelihood(z, y)  # (maximize log-likelihood = minimize -ll)

        # Combined loss
        total_loss = ae_total + gp_nll
        return total_loss, ae_total, gp_nll

# %%
def generate_dataset_for_al_gp(
    N_train=10,
    N_test=500,
    N_ref=100,
    N_cand=100,
    noise_scale=0.1,
    device="cpu",
    seed=None
):
    """
    Generate active learning sets using the BH groundwater flow model.

    Inputs are normalized to [0, 1]^8 using Latin Hypercube Sampling.

    Returns:
        x_train, y_train
        x_test, y_test
        x_ref, y_ref
        x_cand, y_cand
    """
    if seed is not None:
        np.random.seed(seed)
        torch.manual_seed(seed)

    def f(x_zeroOne):
        # x_zeroOne: numpy array of shape (N, 8) in [0,1]^8
        l_bounds = np.array([0.05, 100, 63070, 990, 63.1, 700, 1120, 9855])
        u_bounds = np.array([0.15, 50000, 115600, 1110, 116, 820, 1680, 12045])
        x_physical = l_bounds + x_zeroOne * (u_bounds - l_bounds)

        r_w = x_physical[:, 0]
        r   = x_physical[:, 1]
        T_u = x_physical[:, 2]
        H_u = x_physical[:, 3]
        T_l = x_physical[:, 4]
        H_l = x_physical[:, 5]
        L   = x_physical[:, 6]
        K_w = x_physical[:, 7]

        numerator = 2 * np.pi * T_u * (H_u - H_l)
        log_rrw = np.log(r / r_w)
        denominator = log_rrw * (1 + 2 * L * T_u / (log_rrw * r_w**2 * K_w) + T_u / T_l)
        y = numerator / denominator
        return y.reshape(-1, 1).astype(np.float32)

    def sample_lhs(N):
        sampler = qmc.LatinHypercube(d=8, seed=seed)
        return sampler.random(n=N)  # shape (N, 8) in [0,1]

    def add_noise(y, scale):
        return y + np.random.randn(*y.shape) * scale

    def to_tensor(x, y):
        return (
            torch.tensor(x, dtype=torch.float32, device=device),
            torch.tensor(y, dtype=torch.float32, device=device),
        )

    # Training
    x_train_np = sample_lhs(N_train)
    y_train_np = f(x_train_np)
    y_train_np = add_noise(y_train_np, noise_scale)

    # Test
    x_test_np = sample_lhs(N_test)
    y_test_np = f(x_test_np)
    y_test_np = add_noise(y_test_np, noise_scale)

    # Reference
    x_ref_np = sample_lhs(N_ref)
    y_ref_np = f(x_ref_np)

    # Candidate
    x_cand_np = sample_lhs(N_cand)
    y_cand_np = f(x_cand_np)
    y_cand_np = add_noise(y_cand_np, noise_scale)

    return (
        *to_tensor(x_train_np, y_train_np),
        *to_tensor(x_test_np, y_test_np),
        *to_tensor(x_ref_np, y_ref_np),
        *to_tensor(x_cand_np, y_cand_np)
    )

# %%
def train_joint(
    model, x_train, y_train,
    max_outer_iter=5000,
    max_inner_iter=10,
    tol_loss_change_pct=1e-8,
    verbose=False,
):
    """
    Train a JointModel using L-BFGS with outer loop and early stopping.

    Args:
        model: JointModel instance
        x_train: (N, D)
        y_train: (N, 1)
        max_outer_iter: number of outer optimization steps
        max_inner_iter: L-BFGS inner max_iter
        tol_loss_change_pct: relative loss change to early stop
        verbose: whether to print log

    Returns:
        loss_history: list of total loss per outer iteration
    """
    loss_history = []

    optimizer = torch.optim.LBFGS(
        model.parameters(),
        lr=0.001,
        history_size=50,
        max_iter=max_inner_iter,
        line_search_fn="strong_wolfe"
    )

    for outer_epoch in range(max_outer_iter):
        def closure():
            optimizer.zero_grad()
            total_loss, ae_loss, gp_nll = model.loss(x_train, y_train)
            if torch.isnan(total_loss) or torch.isinf(total_loss):
                print("  total_loss is NaN/Inf")
            if torch.isnan(ae_loss) or torch.isinf(ae_loss):
                print("  ae_loss is NaN/Inf")
            if torch.isnan(gp_nll) or torch.isinf(gp_nll):
                print("  gp_nll is NaN/Inf")
            total_loss.backward()
            if verbose:
                print(f"[Epoch {outer_epoch:03d}] Total: {total_loss.item():.5f} | AE: {ae_loss.item():.5f} | GP-NLL: {gp_nll.item():.5f}")
            return total_loss

        optimizer.step(closure)

        # Compute current loss for stopping check
        with torch.no_grad():
            current_loss, _, _ = model.loss(x_train, y_train)
            loss_history.append(current_loss.item())

        # Early stopping check
        if len(loss_history) >= 2:
            numer = abs(loss_history[-1] - loss_history[-2])
            denom = abs(loss_history[-1] - loss_history[0]) + 1e-8
            rel_change = numer / denom
            if rel_change < tol_loss_change_pct:
                if verbose:
                    print(f"[Stopping] Relative loss change {rel_change:.2e} < tol {tol_loss_change_pct}")
                break
    return loss_history

# %%
def alc_acquisition(model, x_train, y_train, x_cand, x_ref, k_variance=50):
    """
    Two-stage ALC acquisition:
    1. From all candidates, pick top-k_variance with highest posterior variance.
    2. Among these, compute exact ALC (Cohn style) and select best one.
    """
    model.gp.eval()
    model.ae.eval()

    N, Nc, Nr = x_train.shape[0], x_cand.shape[0], x_ref.shape[0]
    device = x_train.device

    with torch.no_grad():
        # Encode inputs
        z_train = model.ae.encode(x_train)
        z_cand = model.ae.encode(x_cand)
        z_ref = model.ae.encode(x_ref)

        # GP kernel and posterior variance
        K = model.gp.compute_K_eta(z_train)  # (N, N)
        L = torch.linalg.cholesky(K + 1e-8 * torch.eye(N, device=device))
        K_s = model.gp.kernel(z_train, z_cand)  # (N, Nc)
        v = torch.cholesky_solve(K_s, L)
        var_cand = model.gp.compute_K_eta(z_cand).diagonal(dim1=0, dim2=1) - (K_s * v).sum(dim=0)

        topk_var_idx = torch.topk(var_cand, k=min(k_variance, Nc)).indices

        # Compute tau² (MLE of variance)
        alpha = torch.cholesky_solve(y_train, L)
        tau2_hat = (y_train.T @ alpha / N).squeeze()

        # Base posterior covariance at z_ref
        K_s_ref = model.gp.kernel(z_train, z_ref)
        K_ss_ref = model.gp.kernel(z_ref,z_ref)
        v_ref = torch.cholesky_solve(K_s_ref, L)
        cov_orig = K_ss_ref - K_s_ref.T @ v_ref
        trace_orig = cov_orig.diag().sum()

        # Evaluate ALC among top candidates
        best_score = -float('inf')
        best_idx = -1

        for idx in topk_var_idx:
            x_aug = torch.vstack([x_train, x_cand[idx:idx+1]])
            z_aug = model.ae.encode(x_aug)

            K_aug = model.gp.compute_K_eta(z_aug)
            L_aug = torch.linalg.cholesky(K_aug + 1e-8 * torch.eye(K_aug.size(0), device=device))

            K_s_aug = model.gp.kernel(z_aug, z_ref)
            K_ss_aug = model.gp.kernel(z_ref,z_ref)
            v_aug = torch.cholesky_solve(K_s_aug, L_aug)
            cov_new = K_ss_aug - K_s_aug.T @ v_aug

            trace_new = cov_new.diag().sum()
            alc_score = tau2_hat * (trace_orig - trace_new)

            if alc_score > best_score:
                best_score = alc_score
                best_idx = idx.item()

    return best_idx, best_score

# %%
def run_active_learning(
    model, x_train_init, y_train_init,
    x_cand, y_cand,
    x_ref, x_test, y_test,
    T=100,
    save_plot_path=None,
    randomAC = False,
    topk=100,
    epsilon=0.02,
    delta=1e-4,
    patience=3
):
    x_train = x_train_init.clone()
    y_train = y_train_init.clone()

    rmse_list = []
    rrmse_list = [] 
    rmspesd_list = []
    T = min(T, len(y_cand))
    slow_count = 0

    for t in range(T):
        print(f"\n--- Round {t} ---")

        # Retrain model
        model.train()
        train_joint(model, x_train, y_train, max_outer_iter=10000, max_inner_iter=100, verbose=False)
        print(model.gp.get_hyperparams())

        # Evaluate on test
        model.eval()
        with torch.no_grad():
            z_train = model.ae.encode(x_train)
            z_test = model.ae.encode(x_test)
            y_pred, y_var = model.gp.predict(z_train, y_train, z_test)
            rmse = torch.sqrt(torch.mean((y_pred - y_test) ** 2)).item()
            rmspesd = rmspe_sd(y_pred, y_test)

            y_mean = y_test.mean()
            rrmse = torch.sqrt(torch.sum((y_pred - y_test) ** 2) / torch.sum((y_test - y_mean) ** 2)).item()

            print(f"Test RMSE: {rmse:.4f}")
            print(f"Test RRMSE: {rrmse:.4f}")
            print(f"Test rmsepd_sd: {rmspesd:.4f}")

            rmse_list.append(rmse)
            rrmse_list.append(rrmse)
            rmspesd_list.append(rmspesd)

        # Select new point
        if randomAC:
            best_idx = np.random.choice(len(y_cand), size=1, replace=False)
        else:
            best_idx, _ = alc_acquisition(model, x_train, y_train, x_cand, x_ref, k_variance=topk)
        if isinstance(best_idx, int):
            best_idx = [best_idx]

        x_new = x_cand[best_idx]
        y_new = y_cand[best_idx]
        x_train = torch.cat([x_train, x_new], dim=0)
        y_train = torch.cat([y_train, y_new], dim=0)

        mask = torch.ones(len(x_cand), dtype=torch.bool, device=x_cand.device)
        mask[best_idx] = False
        x_cand = x_cand[mask]
        y_cand = y_cand[mask]

    return {
        "rmse": np.array(rmse_list),
        "rrmse": np.array(rrmse_list),
        "rmspesd": np.array(rmspesd_list),
        "final_x_train": x_train,
        "final_y_train": y_train,
        "x_test": x_test
    }

# %%
def rmspe_sd(pred_y,true_y):
    N_test = true_y.shape[0]
    pred_y = pred_y.view((N_test,1))
    SSPE = torch.sum( (pred_y-true_y)**2)
    MSPE = SSPE/N_test
    RMSPE = torch.sqrt(MSPE)
    STD = torch.std(true_y)
    return (RMSPE/STD).item()

# %%
# === 2. 生成数据 ===
latent_dim = 4
x_train, y_train, x_test, y_test, x_ref, y_ref, x_cand, y_cand = generate_dataset_for_al_gp(
    N_train=50,
    N_test=1000,
    N_ref=5000,
    N_cand=1000,
    noise_scale=0.,
    device=device,
    seed=None
)
np.save('data/0/ALAEmGP-Borehole-xtrainInitial.npy',x_train.cpu().numpy())
np.save('data/0/ALAEmGP-Borehole-ytrainInitial.npy',y_train.cpu().numpy())

# === 3. 初始化模型 ===
ae = Autoencoder(input_dim=8, latent_dim=latent_dim,hidden_dims=[30]).to(device)
gp = ParametricGP(latent_dim=latent_dim).to(device)
model = JointModel(ae, gp).to(device)

import copy
ae_copy = Autoencoder(input_dim=8, latent_dim=latent_dim, hidden_dims=[30]).to(device)
gp_copy = ParametricGP(latent_dim=latent_dim).to(device)
model_copy = JointModel(ae_copy, gp_copy).to(device)

model_copy.load_state_dict(copy.deepcopy(model.state_dict()))

# === 4. 运行主循环 ===
result = run_active_learning(
    model=model,
    x_train_init=x_train,
    y_train_init=y_train,
    x_cand=x_cand,
    y_cand=y_cand,
    x_ref=x_ref,
    x_test=x_test,
    y_test=y_test,
    T=200,
    save_plot_path="fig/0/ALAEmGP-Borehole",
    randomAC=False
)

np.save('data/0/ALAEmGP-Borehole-xtest.npy',result['x_test'].cpu().numpy())
np.save('data/0/ALAEmGP-Borehole-xtrainFinal.npy',result['final_x_train'].cpu().numpy())
np.save('data/0/ALAEmGP-Borehole-ytrainFinal.npy',result['final_y_train'].cpu().numpy())
np.save('data/0/ALAEmGP-Borehole-testrmse.npy',result['rmse'])
np.save('data/0/ALAEmGP-Borehole-testrmspesd.npy',result['rmspesd'])
# Out:
# --- Round 0 ---
# {'lengthscale': tensor([ 3.2530357838,  7.2943854332,  9.8903446198, 14.7436513901],
#        device='cuda:0'), 'eta': 3.0374303605640307e-05, 'tau²_hat': 1.0}
# Test RMSE: 4.9161
# Test RRMSE: 0.1078
# Test rmsepd_sd: 0.1077
#
# --- Round 1 ---
# {'lengthscale': tensor([ 3.2530434132,  7.2943911552,  9.8903474808, 14.7435665131],
#        device='cuda:0'), 'eta': 3.0374272682820447e-05, 'tau²_hat': 116615.7578125}
# Test RMSE: 4.7818
# Test RRMSE: 0.1048
# Test rmsepd_sd: 0.1048
#
# --- Round 2 ---
# {'lengthscale': tensor([ 3.2530698776,  7.2944169044,  9.8903532028, 14.7432889938],
#        device='cuda:0'), 'eta': 3.0374128982657567e-05, 'tau²_hat': 119872.3984375}
# Test RMSE: 4.7773
# Test RRMSE: 0.1047
# Test rmsepd_sd: 0.1047
#
# --- Round 3 ---
# {'lengthscale': tensor([ 3.2530760765,  7.2944240570,  9.8903560638, 14.7432012558],
#        device='cuda:0'), 'eta': 3.037409987882711e-05, 'tau²_hat': 123521.7734375}
# Test RMSE: 4.8142
# Test RRMSE: 0.1055
# Test rmsepd_sd: 0.1055
#
# --- Round 4 ---
# {'lengthscale': tensor([ 3.2530789375,  7.2944288254,  9.8903608322, 14.7431488037],
#        device='cuda:0'), 'eta': 3.037409987882711e-05, 'tau²_hat': 128774.71875}
# Test RMSE: 4.4778
# Test RRMSE: 0.0982
# Test rmsepd_sd: 0.0981
#
# --- Round 5 ---
# {'lengthscale': tensor([ 3.2530789375,  7.2944288254,  9.8903608322, 14.7431488037],
#        device='cuda:0'), 'eta': 3.037409987882711e-05, 'tau²_hat': 169318.484375}
# Test RMSE: 4.4491
# Test RRMSE: 0.0975
# Test rmsepd_sd: 0.0975
#
# --- Round 6 ---
# {'lengthscale': tensor([ 3.2586278915,  7.3058815002,  9.8967676163, 14.6422138214],
#        device='cuda:0'), 'eta': 3.0337101634358987e-05, 'tau²_hat': 160385.84375}
# Test RMSE: 3.7421
# Test RRMSE: 0.0820
# Test rmsepd_sd: 0.0820
#
# --- Round 7 ---
# {'lengthscale': tensor([ 3.2630028725,  7.3085632324,  9.9000062943, 14.6004905701],
#        device='cuda:0'), 'eta': 3.031584492418915e-05, 'tau²_hat': 100513.7890625}
# Test RMSE: 3.5459
# Test RRMSE: 0.0777
# Test rmsepd_sd: 0.0777
#
# --- Round 8 ---
# {'lengthscale': tensor([ 3.2675027847,  7.3117856979,  9.9027843475, 14.5477437973],
#        device='cuda:0'), 'eta': 3.02825264952844e-05, 'tau²_hat': 88360.0}
# Test RMSE: 3.5173
# Test RRMSE: 0.0771
# Test rmsepd_sd: 0.0771
#
# --- Round 9 ---
# {'lengthscale': tensor([ 3.2707688808,  7.3139872551,  9.9054870605, 14.5098962784],
#        device='cuda:0'), 'eta': 3.02583648590371e-05, 'tau²_hat': 82036.3828125}
# Test RMSE: 3.4132
# Test RRMSE: 0.0748
# Test rmsepd_sd: 0.0748
#
# --- Round 10 ---
# {'lengthscale': tensor([ 3.2749905586,  7.3165893555,  9.9089603424, 14.4662523270],
#        device='cuda:0'), 'eta': 3.0229552066884935e-05, 'tau²_hat': 76919.390625}
# Test RMSE: 3.3873
# Test RRMSE: 0.0743
# Test rmsepd_sd: 0.0742
#
# --- Round 11 ---
# {'lengthscale': tensor([ 3.2792599201,  7.3195352554,  9.9110651016, 14.4253015518],
#        device='cuda:0'), 'eta': 3.0204251743271016e-05, 'tau²_hat': 77559.40625}
# Test RMSE: 3.2683
# Test RRMSE: 0.0717
# Test rmsepd_sd: 0.0716
#
# --- Round 12 ---
# {'lengthscale': tensor([ 3.2792708874,  7.3195433617,  9.9110679626, 14.4251852036],
#        device='cuda:0'), 'eta': 3.0204164431779645e-05, 'tau²_hat': 85426.15625}
# Test RMSE: 3.2540
# Test RRMSE: 0.0713
# Test rmsepd_sd: 0.0713
#
# --- Round 13 ---
# {'lengthscale': tensor([ 3.2792708874,  7.3195433617,  9.9110679626, 14.4251852036],
#        device='cuda:0'), 'eta': 3.0204164431779645e-05, 'tau²_hat': 85061.4140625}
# Test RMSE: 3.1635
# Test RRMSE: 0.0694
# Test rmsepd_sd: 0.0693
#
# --- Round 14 ---
# {'lengthscale': tensor([ 3.2840123177,  7.3233580589,  9.9116535187, 14.3847894669],
#        device='cuda:0'), 'eta': 3.0179862733348273e-05, 'tau²_hat': 95302.3203125}
# Test RMSE: 3.1468
# Test RRMSE: 0.0690
# Test rmsepd_sd: 0.0690
#
# --- Round 15 ---
# {'lengthscale': tensor([ 3.2888786793,  7.3271269798,  9.9130487442, 14.3416175842],
#        device='cuda:0'), 'eta': 3.0153998523019254e-05, 'tau²_hat': 90752.78125}
# Test RMSE: 3.0543
# Test RRMSE: 0.0670
# Test rmsepd_sd: 0.0669
#
# --- Round 16 ---
# {'lengthscale': tensor([ 3.2938642502,  7.3309721947,  9.9149627686, 14.2978105545],
#        device='cuda:0'), 'eta': 3.01287309412146e-05, 'tau²_hat': 86985.1875}
# Test RMSE: 3.0059
# Test RRMSE: 0.0659
# Test rmsepd_sd: 0.0659
#
# --- Round 17 ---
# {'lengthscale': tensor([ 3.2989377975,  7.3348321915,  9.9168214798, 14.2516031265],
#        device='cuda:0'), 'eta': 3.0101073207333684e-05, 'tau²_hat': 86641.1796875}
# Test RMSE: 2.9319
# Test RRMSE: 0.0643
# Test rmsepd_sd: 0.0642
#
# --- Round 18 ---
# {'lengthscale': tensor([ 3.3034715652,  7.3380489349,  9.9184474945, 14.1996269226],
#        device='cuda:0'), 'eta': 3.006716178788338e-05, 'tau²_hat': 85956.8203125}
# Test RMSE: 2.8620
# Test RRMSE: 0.0627
# Test rmsepd_sd: 0.0627
#
# --- Round 19 ---
# {'lengthscale': tensor([ 3.3034822941,  7.3380570412,  9.9184551239, 14.1995115280],
#        device='cuda:0'), 'eta': 3.0067076295381412e-05, 'tau²_hat': 78531.0234375}
# Test RMSE: 2.8561
# Test RRMSE: 0.0626
# Test rmsepd_sd: 0.0626
#
# --- Round 20 ---
# {'lengthscale': tensor([ 3.3034939766,  7.3380661011,  9.9184617996, 14.1994028091],
#        device='cuda:0'), 'eta': 3.0067019906709902e-05, 'tau²_hat': 80546.421875}
# Test RMSE: 2.7925
# Test RRMSE: 0.0612
# Test rmsepd_sd: 0.0612
#
# --- Round 21 ---
# {'lengthscale': tensor([ 3.3088338375,  7.3417820930,  9.9223213196, 14.1479911804],
#        device='cuda:0'), 'eta': 3.0035149393370375e-05, 'tau²_hat': 85869.0546875}
# Test RMSE: 2.7329
# Test RRMSE: 0.0599
# Test rmsepd_sd: 0.0599
#
# --- Round 22 ---
# {'lengthscale': tensor([ 3.3088409901,  7.3417849541,  9.9223270416, 14.1479063034],
#        device='cuda:0'), 'eta': 3.003509118570946e-05, 'tau²_hat': 77719.6171875}
# Test RMSE: 2.7664
# Test RRMSE: 0.0606
# Test rmsepd_sd: 0.0606
#
# --- Round 23 ---
# {'lengthscale': tensor([ 3.3088488579,  7.3417897224,  9.9223289490, 14.1478157043],
#        device='cuda:0'), 'eta': 3.003503479703795e-05, 'tau²_hat': 78154.765625}
# Test RMSE: 2.7861
# Test RRMSE: 0.0611
# Test rmsepd_sd: 0.0610
#
# --- Round 24 ---
# {'lengthscale': tensor([ 3.3121020794,  7.3435583115,  9.9235258102, 14.1076545715],
#        device='cuda:0'), 'eta': 3.000529068231117e-05, 'tau²_hat': 77667.7265625}
# Test RMSE: 2.8285
# Test RRMSE: 0.0620
# Test rmsepd_sd: 0.0620
#
# --- Round 25 ---
# {'lengthscale': tensor([ 3.3146569729,  7.3449487686,  9.9238338470, 14.0644769669],
#        device='cuda:0'), 'eta': 2.997254159708973e-05, 'tau²_hat': 72912.484375}
# Test RMSE: 2.6680
# Test RRMSE: 0.0585
# Test rmsepd_sd: 0.0585
#
# --- Round 26 ---
# {'lengthscale': tensor([ 3.3146688938,  7.3449540138,  9.9238338470, 14.0643520355],
#        device='cuda:0'), 'eta': 2.9972457923577167e-05, 'tau²_hat': 76788.265625}
# Test RMSE: 2.6931
# Test RRMSE: 0.0590
# Test rmsepd_sd: 0.0590
#
# --- Round 27 ---
# {'lengthscale': tensor([ 3.3216443062,  7.3485188484,  9.9263420105, 13.9916763306],
#        device='cuda:0'), 'eta': 2.9918881409685127e-05, 'tau²_hat': 80888.65625}
# Test RMSE: 2.5388
# Test RRMSE: 0.0557
# Test rmsepd_sd: 0.0556
#
# --- Round 28 ---
# {'lengthscale': tensor([ 3.3216538429,  7.3485236168,  9.9263467789, 13.9915618896],
#        device='cuda:0'), 'eta': 2.991879591718316e-05, 'tau²_hat': 78261.296875}
# Test RMSE: 2.5219
# Test RRMSE: 0.0553
# Test rmsepd_sd: 0.0553
#
# --- Round 29 ---
# {'lengthscale': tensor([ 3.3216650486,  7.3485302925,  9.9263515472, 13.9914398193],
#        device='cuda:0'), 'eta': 2.9918710424681194e-05, 'tau²_hat': 77811.6640625}
# Test RMSE: 2.4711
# Test RRMSE: 0.0542
# Test rmsepd_sd: 0.0541
#
# --- Round 30 ---
# {'lengthscale': tensor([ 3.3257184029,  7.3504643440,  9.9255867004, 13.9480905533],
#        device='cuda:0'), 'eta': 2.9887742130085826e-05, 'tau²_hat': 78162.1015625}
# Test RMSE: 2.3036
# Test RRMSE: 0.0505
# Test rmsepd_sd: 0.0505
#
# --- Round 31 ---
# {'lengthscale': tensor([ 3.3257248402,  7.3504686356,  9.9255924225, 13.9480209351],
#        device='cuda:0'), 'eta': 2.988768210343551e-05, 'tau²_hat': 85175.1015625}
# Test RMSE: 2.3319
# Test RRMSE: 0.0511
# Test rmsepd_sd: 0.0511
#
# --- Round 32 ---
# {'lengthscale': tensor([ 3.3257317543,  7.3504729271,  9.9255971909, 13.9479541779],
#        device='cuda:0'), 'eta': 2.9887625714764e-05, 'tau²_hat': 87540.109375}
# Test RMSE: 2.3385
# Test RRMSE: 0.0513
# Test rmsepd_sd: 0.0512
#
# --- Round 33 ---
# {'lengthscale': tensor([ 3.3283278942,  7.3522362709,  9.9269552231, 13.9245862961],
#        device='cuda:0'), 'eta': 2.987315019709058e-05, 'tau²_hat': 87024.859375}
# Test RMSE: 2.2263
# Test RRMSE: 0.0488
# Test rmsepd_sd: 0.0488
#
# --- Round 34 ---
# {'lengthscale': tensor([ 3.3369357586,  7.3575892448,  9.9289665222, 13.8265190125],
#        device='cuda:0'), 'eta': 2.9799681215081364e-05, 'tau²_hat': 79295.3671875}
# Test RMSE: 2.1038
# Test RRMSE: 0.0461
# Test rmsepd_sd: 0.0461
#
# --- Round 35 ---
# {'lengthscale': tensor([ 3.3404822350,  7.3599095345,  9.9305858612, 13.7816343307],
#        device='cuda:0'), 'eta': 2.9763696147711016e-05, 'tau²_hat': 71250.109375}
# Test RMSE: 2.0678
# Test RRMSE: 0.0453
# Test rmsepd_sd: 0.0453
#
# --- Round 36 ---
# {'lengthscale': tensor([ 3.3439211845,  7.3619275093,  9.9321136475, 13.7410907745],
#        device='cuda:0'), 'eta': 2.9731070753769018e-05, 'tau²_hat': 67816.1171875}
# Test RMSE: 2.0478
# Test RRMSE: 0.0449
# Test rmsepd_sd: 0.0449
#
# --- Round 37 ---
# {'lengthscale': tensor([ 3.3439307213,  7.3619337082,  9.9321155548, 13.7409887314],
#        device='cuda:0'), 'eta': 2.973098526126705e-05, 'tau²_hat': 65088.89453125}
# Test RMSE: 2.0216
# Test RRMSE: 0.0443
# Test rmsepd_sd: 0.0443
#
# --- Round 38 ---
# {'lengthscale': tensor([ 3.3439390659,  7.3619394302,  9.9321184158, 13.7408943176],
#        device='cuda:0'), 'eta': 2.9730901587754488e-05, 'tau²_hat': 73434.640625}
# Test RMSE: 2.0336
# Test RRMSE: 0.0446
# Test rmsepd_sd: 0.0446
#
# --- Round 39 ---
# {'lengthscale': tensor([ 3.3439471722,  7.3619451523,  9.9321212769, 13.7408390045],
#        device='cuda:0'), 'eta': 2.973087248392403e-05, 'tau²_hat': 73399.4765625}
# Test RMSE: 1.9695
# Test RRMSE: 0.0432
# Test rmsepd_sd: 0.0432
#
# --- Round 40 ---
# {'lengthscale': tensor([ 3.3494663239,  7.3665595055,  9.9339532852, 13.7011699677],
#        device='cuda:0'), 'eta': 2.9711343813687563e-05, 'tau²_hat': 118580.296875}
# Test RMSE: 1.8445
# Test RRMSE: 0.0404
# Test rmsepd_sd: 0.0404
#
# --- Round 41 ---
# {'lengthscale': tensor([ 3.3518600464,  7.3682584763,  9.9356775284, 13.6844549179],
#        device='cuda:0'), 'eta': 2.9700804589083418e-05, 'tau²_hat': 97210.4609375}
# Test RMSE: 1.7175
# Test RRMSE: 0.0377
# Test rmsepd_sd: 0.0376
#
# --- Round 42 ---
# {'lengthscale': tensor([ 3.3518707752,  7.3682661057,  9.9356842041, 13.6843471527],
#        device='cuda:0'), 'eta': 2.970071909658145e-05, 'tau²_hat': 83820.1328125}
# Test RMSE: 1.7330
# Test RRMSE: 0.0380
# Test rmsepd_sd: 0.0380
#
# --- Round 43 ---
# {'lengthscale': tensor([ 3.3518807888,  7.3682727814,  9.9356918335, 13.6842470169],
#        device='cuda:0'), 'eta': 2.9700633604079485e-05, 'tau²_hat': 81932.828125}
# Test RMSE: 1.7169
# Test RRMSE: 0.0376
# Test rmsepd_sd: 0.0376
#
# --- Round 44 ---
# {'lengthscale': tensor([ 3.3519327641,  7.3683099747,  9.9357194901, 13.6837644577],
#        device='cuda:0'), 'eta': 2.9700295272050425e-05, 'tau²_hat': 83868.3671875}
# Test RMSE: 1.7169
# Test RRMSE: 0.0376
# Test rmsepd_sd: 0.0376
#
# --- Round 45 ---
# {'lengthscale': tensor([ 3.3582854271,  7.3731441498,  9.9391412735, 13.6235370636],
#        device='cuda:0'), 'eta': 2.965464227600023e-05, 'tau²_hat': 83364.5703125}
# Test RMSE: 1.6123
# Test RRMSE: 0.0353
# Test rmsepd_sd: 0.0353
#
# --- Round 46 ---
# {'lengthscale': tensor([ 3.3582906723,  7.3731484413,  9.9391441345, 13.6234426498],
#        device='cuda:0'), 'eta': 2.965455860248767e-05, 'tau²_hat': 76480.6484375}
# Test RMSE: 1.5900
# Test RRMSE: 0.0349
# Test rmsepd_sd: 0.0348
#
# --- Round 47 ---
# {'lengthscale': tensor([ 3.3582949638,  7.3731522560,  9.9391441345, 13.6233491898],
#        device='cuda:0'), 'eta': 2.9654473109985702e-05, 'tau²_hat': 77309.359375}
# Test RMSE: 1.6025
# Test RRMSE: 0.0351
# Test rmsepd_sd: 0.0351
#
# --- Round 48 ---
# {'lengthscale': tensor([ 3.3582973480,  7.3731536865,  9.9391441345, 13.6232776642],
#        device='cuda:0'), 'eta': 2.9654416721314192e-05, 'tau²_hat': 76705.8515625}
# Test RMSE: 1.6253
# Test RRMSE: 0.0356
# Test rmsepd_sd: 0.0356
#
# --- Round 49 ---
# {'lengthscale': tensor([ 3.3583006859,  7.3731565475,  9.9391441345, 13.6231899261],
#        device='cuda:0'), 'eta': 2.965432940982282e-05, 'tau²_hat': 80490.8125}
# Test RMSE: 1.6159
# Test RRMSE: 0.0354
# Test rmsepd_sd: 0.0354
#
# --- Round 50 ---
# {'lengthscale': tensor([ 3.3592202663,  7.3740210533,  9.9391174316, 13.5687036514],
#        device='cuda:0'), 'eta': 2.959909579658415e-05, 'tau²_hat': 78859.921875}
# Test RMSE: 1.5755
# Test RRMSE: 0.0345
# Test rmsepd_sd: 0.0345
#
# --- Round 51 ---
# {'lengthscale': tensor([ 3.3601198196,  7.3747115135,  9.9395437241, 13.5535821915],
#        device='cuda:0'), 'eta': 2.9585322408820502e-05, 'tau²_hat': 75853.3203125}
# Test RMSE: 1.4962
# Test RRMSE: 0.0328
# Test rmsepd_sd: 0.0328
#
# --- Round 52 ---
# {'lengthscale': tensor([ 3.3630995750,  7.3768434525,  9.9407310486, 13.4919338226],
#        device='cuda:0'), 'eta': 2.952666545752436e-05, 'tau²_hat': 68186.4140625}
# Test RMSE: 1.4930
# Test RRMSE: 0.0327
# Test rmsepd_sd: 0.0327
#
# --- Round 53 ---
# {'lengthscale': tensor([ 3.3637039661,  7.3773169518,  9.9409303665, 13.4688682556],
#        device='cuda:0'), 'eta': 2.9503446057788096e-05, 'tau²_hat': 63449.0625}
# Test RMSE: 1.4586
# Test RRMSE: 0.0320
# Test rmsepd_sd: 0.0320
#
# --- Round 54 ---
# {'lengthscale': tensor([ 3.3637084961,  7.3773193359,  9.9409303665, 13.4687385559],
#        device='cuda:0'), 'eta': 2.950330417661462e-05, 'tau²_hat': 59278.9140625}
# Test RMSE: 1.4553
# Test RRMSE: 0.0319
# Test rmsepd_sd: 0.0319
#
# --- Round 55 ---
# {'lengthscale': tensor([ 3.3655121326,  7.3783917427,  9.9413051605, 13.4171638489],
#        device='cuda:0'), 'eta': 2.9451803129632026e-05, 'tau²_hat': 59042.96484375}
# Test RMSE: 1.4211
# Test RRMSE: 0.0312
# Test rmsepd_sd: 0.0311
#
# --- Round 56 ---
# {'lengthscale': tensor([ 3.3655149937,  7.3783931732,  9.9413051605, 13.4170742035],
#        device='cuda:0'), 'eta': 2.945171763713006e-05, 'tau²_hat': 56654.93359375}
# Test RMSE: 1.4238
# Test RRMSE: 0.0312
# Test rmsepd_sd: 0.0312
#
# --- Round 57 ---
# {'lengthscale': tensor([ 3.3659415245,  7.3786411285,  9.9413852692, 13.3991527557],
#        device='cuda:0'), 'eta': 2.9433131203404628e-05, 'tau²_hat': 56588.75390625}
# Test RMSE: 1.4089
# Test RRMSE: 0.0309
# Test rmsepd_sd: 0.0309
#
# --- Round 58 ---
# {'lengthscale': tensor([ 3.3659443855,  7.3786425591,  9.9413881302, 13.3989896774],
#        device='cuda:0'), 'eta': 2.9432962037390098e-05, 'tau²_hat': 52737.02734375}
# Test RMSE: 1.4150
# Test RRMSE: 0.0310
# Test rmsepd_sd: 0.0310
#
# --- Round 59 ---
# {'lengthscale': tensor([ 3.3659472466,  7.3786425591,  9.9413900375, 13.3987541199],
#        device='cuda:0'), 'eta': 2.9432738301693462e-05, 'tau²_hat': 52620.3515625}
# Test RMSE: 1.4112
# Test RRMSE: 0.0309
# Test rmsepd_sd: 0.0309
#
# --- Round 60 ---
# {'lengthscale': tensor([ 3.3659615517,  7.3786468506,  9.9413976669, 13.3980188370],
#        device='cuda:0'), 'eta': 2.9431979783112183e-05, 'tau²_hat': 52652.328125}
# Test RMSE: 1.4127
# Test RRMSE: 0.0310
# Test rmsepd_sd: 0.0310
#
# --- Round 61 ---
# {'lengthscale': tensor([ 3.3665995598,  7.3788919449,  9.9416790009, 13.3738851547],
#        device='cuda:0'), 'eta': 2.9406755857053213e-05, 'tau²_hat': 52583.19921875}
# Test RMSE: 1.3878
# Test RRMSE: 0.0304
# Test rmsepd_sd: 0.0304
#
# --- Round 62 ---
# {'lengthscale': tensor([ 3.3666038513,  7.3788948059,  9.9416790009, 13.3737449646],
#        device='cuda:0'), 'eta': 2.9406617613858543e-05, 'tau²_hat': 50898.7578125}
# Test RMSE: 1.3755
# Test RRMSE: 0.0302
# Test rmsepd_sd: 0.0301
#
# --- Round 63 ---
# {'lengthscale': tensor([ 3.3673026562,  7.3793082237,  9.9418392181, 13.3529777527],
#        device='cuda:0'), 'eta': 2.9385002562776208e-05, 'tau²_hat': 50518.1640625}
# Test RMSE: 1.3854
# Test RRMSE: 0.0304
# Test rmsepd_sd: 0.0304
#
# --- Round 64 ---
# {'lengthscale': tensor([ 3.3673074245,  7.3793101311,  9.9418401718, 13.3528280258],
#        device='cuda:0'), 'eta': 2.938486431958154e-05, 'tau²_hat': 49619.359375}
# Test RMSE: 1.3849
# Test RRMSE: 0.0304
# Test rmsepd_sd: 0.0303
#
# --- Round 65 ---
# {'lengthscale': tensor([ 3.3673105240,  7.3793101311,  9.9418430328, 13.3527231216],
#        device='cuda:0'), 'eta': 2.9384749723249115e-05, 'tau²_hat': 49230.37890625}
# Test RMSE: 1.4021
# Test RRMSE: 0.0307
# Test rmsepd_sd: 0.0307
#
# --- Round 66 ---
# {'lengthscale': tensor([ 3.3679680824,  7.3794393539,  9.9422225952, 13.3341350555],
#        device='cuda:0'), 'eta': 2.9365895898081362e-05, 'tau²_hat': 49699.83984375}
# Test RMSE: 1.3700
# Test RRMSE: 0.0300
# Test rmsepd_sd: 0.0300
#
# --- Round 67 ---
# {'lengthscale': tensor([ 3.3679735661,  7.3794412613,  9.9422245026, 13.3339786530],
#        device='cuda:0'), 'eta': 2.9365728551056236e-05, 'tau²_hat': 47870.79296875}
# Test RMSE: 1.3746
# Test RRMSE: 0.0301
# Test rmsepd_sd: 0.0301
#
# --- Round 68 ---
# {'lengthscale': tensor([ 3.3701736927,  7.3803343773,  9.9432725906, 13.2769737244],
#        device='cuda:0'), 'eta': 2.9307841032277793e-05, 'tau²_hat': 47428.53125}
# Test RMSE: 1.3656
# Test RRMSE: 0.0299
# Test rmsepd_sd: 0.0299
#
# --- Round 69 ---
# {'lengthscale': tensor([ 3.3730087280,  7.3815259933,  9.9446783066, 13.1883087158],
#        device='cuda:0'), 'eta': 2.9218817871878855e-05, 'tau²_hat': 45408.26953125}
# Test RMSE: 1.3226
# Test RRMSE: 0.0290
# Test rmsepd_sd: 0.0290
#
# --- Round 70 ---
# {'lengthscale': tensor([ 3.3730087280,  7.3815259933,  9.9446783066, 13.1883049011],
#        device='cuda:0'), 'eta': 2.9218817871878855e-05, 'tau²_hat': 41780.56640625}
# Test RMSE: 1.3189
# Test RRMSE: 0.0289
# Test rmsepd_sd: 0.0289
#
# --- Round 71 ---
# {'lengthscale': tensor([ 3.3799636364,  7.3843460083,  9.9471282959, 13.0007591248],
#        device='cuda:0'), 'eta': 2.9018541681580245e-05, 'tau²_hat': 41644.3671875}
# Test RMSE: 1.3351
# Test RRMSE: 0.0293
# Test rmsepd_sd: 0.0293
#
# --- Round 72 ---
# {'lengthscale': tensor([ 3.3804311752,  7.3843517303,  9.9474630356, 12.9788036346],
#        device='cuda:0'), 'eta': 2.8994143576710485e-05, 'tau²_hat': 37283.7734375}
# Test RMSE: 1.2835
# Test RRMSE: 0.0281
# Test rmsepd_sd: 0.0281
#
# --- Round 73 ---
# {'lengthscale': tensor([ 3.3804385662,  7.3843555450,  9.9474668503, 12.9786491394],
#        device='cuda:0'), 'eta': 2.8993978048674762e-05, 'tau²_hat': 35944.98828125}
# Test RMSE: 1.2680
# Test RRMSE: 0.0278
# Test rmsepd_sd: 0.0278
#
# --- Round 74 ---
# {'lengthscale': tensor([ 3.3816201687,  7.3848891258,  9.9482135773, 12.9510679245],
#        device='cuda:0'), 'eta': 2.8964821467525326e-05, 'tau²_hat': 39968.97265625}
# Test RMSE: 1.2539
# Test RRMSE: 0.0275
# Test rmsepd_sd: 0.0275
#
# --- Round 75 ---
# {'lengthscale': tensor([ 3.3816258907,  7.3848924637,  9.9482164383, 12.9509420395],
#        device='cuda:0'), 'eta': 2.8964683224330656e-05, 'tau²_hat': 39160.62890625}
# Test RMSE: 1.2646
# Test RRMSE: 0.0277
# Test rmsepd_sd: 0.0277
#
# --- Round 76 ---
# {'lengthscale': tensor([ 3.3834915161,  7.3859167099,  9.9492483139, 12.9138822556],
#        device='cuda:0'), 'eta': 2.8926064260303974e-05, 'tau²_hat': 42931.921875}
# Test RMSE: 1.2350
# Test RRMSE: 0.0271
# Test rmsepd_sd: 0.0271
#
# --- Round 77 ---
# {'lengthscale': tensor([ 3.3846898079,  7.3862891197,  9.9502210617, 12.8880767822],
#        device='cuda:0'), 'eta': 2.8898517484776676e-05, 'tau²_hat': 40591.8125}
# Test RMSE: 1.2220
# Test RRMSE: 0.0268
# Test rmsepd_sd: 0.0268
#
# --- Round 78 ---
# {'lengthscale': tensor([ 3.3853478432,  7.3865151405,  9.9507875443, 12.8727025986],
#        device='cuda:0'), 'eta': 2.8882095648441464e-05, 'tau²_hat': 39842.41015625}
# Test RMSE: 1.2397
# Test RRMSE: 0.0272
# Test rmsepd_sd: 0.0272
#
# --- Round 79 ---
# {'lengthscale': tensor([ 3.3853552341,  7.3865170479,  9.9507932663, 12.8725185394],
#        device='cuda:0'), 'eta': 2.888190465455409e-05, 'tau²_hat': 41491.51953125}
# Test RMSE: 1.2276
# Test RRMSE: 0.0269
# Test rmsepd_sd: 0.0269
#
# --- Round 80 ---
# {'lengthscale': tensor([ 3.3879005909,  7.3871812820,  9.9528427124, 12.8076953888],
#        device='cuda:0'), 'eta': 2.881134241761174e-05, 'tau²_hat': 41464.66796875}
# Test RMSE: 1.2292
# Test RRMSE: 0.0269
# Test rmsepd_sd: 0.0269
#
# --- Round 81 ---
# {'lengthscale': tensor([ 3.3879039288,  7.3871831894,  9.9528455734, 12.8075580597],
#        device='cuda:0'), 'eta': 2.8811175070586614e-05, 'tau²_hat': 39812.22265625}
# Test RMSE: 1.2216
# Test RRMSE: 0.0268
# Test rmsepd_sd: 0.0268
#
# --- Round 82 ---
# {'lengthscale': tensor([ 3.3879075050,  7.3871850967,  9.9528474808, 12.8074426651],
#        device='cuda:0'), 'eta': 2.88110659312224e-05, 'tau²_hat': 39069.56640625}
# Test RMSE: 1.2237
# Test RRMSE: 0.0268
# Test rmsepd_sd: 0.0268
#
# --- Round 83 ---
# {'lengthscale': tensor([ 3.3884854317,  7.3874406815,  9.9532060623, 12.7890672684],
#        device='cuda:0'), 'eta': 2.879074054362718e-05, 'tau²_hat': 41389.22265625}
# Test RMSE: 1.1844
# Test RRMSE: 0.0260
# Test rmsepd_sd: 0.0260
#
# --- Round 84 ---
# {'lengthscale': tensor([ 3.3884854317,  7.3874406815,  9.9532060623, 12.7890672684],
#        device='cuda:0'), 'eta': 2.879074054362718e-05, 'tau²_hat': 39357.00390625}
# Test RMSE: 1.1924
# Test RRMSE: 0.0261
# Test rmsepd_sd: 0.0261
#
# --- Round 85 ---
# {'lengthscale': tensor([ 3.3884854317,  7.3874406815,  9.9532060623, 12.7890672684],
#        device='cuda:0'), 'eta': 2.879074054362718e-05, 'tau²_hat': 41242.328125}
# Test RMSE: 1.1796
# Test RRMSE: 0.0259
# Test rmsepd_sd: 0.0258
#
# --- Round 86 ---
# {'lengthscale': tensor([ 3.3884899616,  7.3874435425,  9.9532108307, 12.7889270782],
#        device='cuda:0'), 'eta': 2.879057683458086e-05, 'tau²_hat': 41829.32421875}
# Test RMSE: 1.1592
# Test RRMSE: 0.0254
# Test rmsepd_sd: 0.0254
#
# --- Round 87 ---
# {'lengthscale': tensor([ 3.3884899616,  7.3874435425,  9.9532108307, 12.7889242172],
#        device='cuda:0'), 'eta': 2.879057683458086e-05, 'tau²_hat': 41327.19921875}
# Test RMSE: 1.1644
# Test RRMSE: 0.0255
# Test rmsepd_sd: 0.0255
#
# --- Round 88 ---
# {'lengthscale': tensor([ 3.3891100883,  7.3878216743,  9.9538803101, 12.7679300308],
#        device='cuda:0'), 'eta': 2.8768234187737107e-05, 'tau²_hat': 41161.62890625}
# Test RMSE: 1.1956
# Test RRMSE: 0.0262
# Test rmsepd_sd: 0.0262
#
# --- Round 89 ---
# {'lengthscale': tensor([ 3.3896307945,  7.3882279396,  9.9542694092, 12.7519941330],
#        device='cuda:0'), 'eta': 2.875057361961808e-05, 'tau²_hat': 40273.328125}
# Test RMSE: 1.1762
# Test RRMSE: 0.0258
# Test rmsepd_sd: 0.0258
#
# --- Round 90 ---
# {'lengthscale': tensor([ 3.3913733959,  7.3895726204,  9.9556741714, 12.6918535233],
#        device='cuda:0'), 'eta': 2.868355659302324e-05, 'tau²_hat': 39613.20703125}
# Test RMSE: 1.1671
# Test RRMSE: 0.0256
# Test rmsepd_sd: 0.0256
#
# --- Round 91 ---
# {'lengthscale': tensor([ 3.3913741112,  7.3895726204,  9.9556741714, 12.6918354034],
#        device='cuda:0'), 'eta': 2.868355659302324e-05, 'tau²_hat': 38903.37109375}
# Test RMSE: 1.1701
# Test RRMSE: 0.0257
# Test rmsepd_sd: 0.0256
#
# --- Round 92 ---
# {'lengthscale': tensor([ 3.3913769722,  7.3895745277,  9.9556760788, 12.6917562485],
#        device='cuda:0'), 'eta': 2.8683476557489485e-05, 'tau²_hat': 38631.94921875}
# Test RMSE: 1.1655
# Test RRMSE: 0.0256
# Test rmsepd_sd: 0.0255
#
# --- Round 93 ---
# {'lengthscale': tensor([ 3.3913943768,  7.3895831108,  9.9556903839, 12.6913032532],
#        device='cuda:0'), 'eta': 2.8682983611361124e-05, 'tau²_hat': 38546.984375}
# Test RMSE: 1.1680
# Test RRMSE: 0.0256
# Test rmsepd_sd: 0.0256
#
# --- Round 94 ---
# {'lengthscale': tensor([ 3.3918368816,  7.3898353577,  9.9559736252, 12.6805562973],
#        device='cuda:0'), 'eta': 2.867089642677456e-05, 'tau²_hat': 38138.6171875}
# Test RMSE: 1.1547
# Test RRMSE: 0.0253
# Test rmsepd_sd: 0.0253
#
# --- Round 95 ---
# {'lengthscale': tensor([ 3.3941202164,  7.3906579018,  9.9577178955, 12.6019754410],
#        device='cuda:0'), 'eta': 2.8581649530678988e-05, 'tau²_hat': 37265.6640625}
# Test RMSE: 1.1518
# Test RRMSE: 0.0253
# Test rmsepd_sd: 0.0252
#
# --- Round 96 ---
# {'lengthscale': tensor([ 3.3941259384,  7.3906593323,  9.9577226639, 12.6018218994],
#        device='cuda:0'), 'eta': 2.858148582163267e-05, 'tau²_hat': 36280.640625}
# Test RMSE: 1.1565
# Test RRMSE: 0.0254
# Test rmsepd_sd: 0.0253
#
# --- Round 97 ---
# {'lengthscale': tensor([ 3.3945994377,  7.3908848763,  9.9581689835, 12.5885753632],
#        device='cuda:0'), 'eta': 2.856663559214212e-05, 'tau²_hat': 36457.2109375}
# Test RMSE: 1.1221
# Test RRMSE: 0.0246
# Test rmsepd_sd: 0.0246
#
# --- Round 98 ---
# {'lengthscale': tensor([ 3.3951015472,  7.3910756111,  9.9586887360, 12.5693311691],
#        device='cuda:0'), 'eta': 2.854433114407584e-05, 'tau²_hat': 35259.94140625}
# Test RMSE: 1.1286
# Test RRMSE: 0.0247
# Test rmsepd_sd: 0.0247
#
# --- Round 99 ---
# {'lengthscale': tensor([ 3.3951015472,  7.3910756111,  9.9586887360, 12.5693273544],
#        device='cuda:0'), 'eta': 2.854433114407584e-05, 'tau²_hat': 34448.16796875}
# Test RMSE: 1.1457
# Test RRMSE: 0.0251
# Test rmsepd_sd: 0.0251
#
# --- Round 100 ---
# {'lengthscale': tensor([ 3.3954541683,  7.3911972046,  9.9590549469, 12.5588159561],
#        device='cuda:0'), 'eta': 2.853254773071967e-05, 'tau²_hat': 35533.109375}
# Test RMSE: 1.1218
# Test RRMSE: 0.0246
# Test rmsepd_sd: 0.0246
#
# --- Round 101 ---
# {'lengthscale': tensor([ 3.3954591751,  7.3911986351,  9.9590597153, 12.5586252213],
#        device='cuda:0'), 'eta': 2.853232763300184e-05, 'tau²_hat': 34340.26953125}
# Test RMSE: 1.1220
# Test RRMSE: 0.0246
# Test rmsepd_sd: 0.0246
#
# --- Round 102 ---
# {'lengthscale': tensor([ 3.3954598904,  7.3911986351,  9.9590597153, 12.5586099625],
#        device='cuda:0'), 'eta': 2.8532302167150192e-05, 'tau²_hat': 34340.34375}
# Test RMSE: 1.1336
# Test RRMSE: 0.0249
# Test rmsepd_sd: 0.0248
#
# --- Round 103 ---
# {'lengthscale': tensor([ 3.3959078789,  7.3913822174,  9.9594984055, 12.5445213318],
#        device='cuda:0'), 'eta': 2.851636236300692e-05, 'tau²_hat': 34199.6796875}
# Test RMSE: 1.1176
# Test RRMSE: 0.0245
# Test rmsepd_sd: 0.0245
#
# --- Round 104 ---
# {'lengthscale': tensor([ 3.3959133625,  7.3913836479,  9.9595031738, 12.5443086624],
#        device='cuda:0'), 'eta': 2.851611679943744e-05, 'tau²_hat': 33490.59375}
# Test RMSE: 1.1106
# Test RRMSE: 0.0243
# Test rmsepd_sd: 0.0243
#
# --- Round 105 ---
# {'lengthscale': tensor([ 3.3959197998,  7.3913874626,  9.9595079422, 12.5440158844],
#        device='cuda:0'), 'eta': 2.8515789381344803e-05, 'tau²_hat': 33435.18359375}
# Test RMSE: 1.1177
# Test RRMSE: 0.0245
# Test rmsepd_sd: 0.0245
#
# --- Round 106 ---
# {'lengthscale': tensor([ 3.3959197998,  7.3913874626,  9.9595079422, 12.5440158844],
#        device='cuda:0'), 'eta': 2.8515789381344803e-05, 'tau²_hat': 33312.92578125}
# Test RMSE: 1.1239
# Test RRMSE: 0.0246
# Test rmsepd_sd: 0.0246
#
# --- Round 107 ---
# {'lengthscale': tensor([ 3.3959233761,  7.3913874626,  9.9595127106, 12.5438270569],
#        device='cuda:0'), 'eta': 2.851559838745743e-05, 'tau²_hat': 33275.296875}
# Test RMSE: 1.1320
# Test RRMSE: 0.0248
# Test rmsepd_sd: 0.0248
#
# --- Round 108 ---
# {'lengthscale': tensor([ 3.3959271908,  7.3913893700,  9.9595174789, 12.5436534882],
#        device='cuda:0'), 'eta': 2.851540921255946e-05, 'tau²_hat': 33183.17578125}
# Test RMSE: 1.1243
# Test RRMSE: 0.0246
# Test rmsepd_sd: 0.0246
#
# --- Round 109 ---
# {'lengthscale': tensor([ 3.3959338665,  7.3913908005,  9.9595222473, 12.5434265137],
#        device='cuda:0'), 'eta': 2.851513636414893e-05, 'tau²_hat': 33269.73828125}
# Test RMSE: 1.1226
# Test RRMSE: 0.0246
# Test rmsepd_sd: 0.0246
#
# --- Round 110 ---
# {'lengthscale': tensor([ 3.3959338665,  7.3913908005,  9.9595222473, 12.5434265137],
#        device='cuda:0'), 'eta': 2.851513636414893e-05, 'tau²_hat': 33654.11328125}
# Test RMSE: 1.1245
# Test RRMSE: 0.0247
# Test rmsepd_sd: 0.0246
#
# --- Round 111 ---
# {'lengthscale': tensor([ 3.3961219788,  7.3913416862,  9.9597549438, 12.5294284821],
#        device='cuda:0'), 'eta': 2.8499369363998994e-05, 'tau²_hat': 34022.9375}
# Test RMSE: 1.1314
# Test RRMSE: 0.0248
# Test rmsepd_sd: 0.0248
#
# --- Round 112 ---
# {'lengthscale': tensor([ 3.3961260319,  7.3913416862,  9.9597578049, 12.5292587280],
#        device='cuda:0'), 'eta': 2.8499178370111622e-05, 'tau²_hat': 33503.953125}
# Test RMSE: 1.1258
# Test RRMSE: 0.0247
# Test rmsepd_sd: 0.0247
#
# --- Round 113 ---
# {'lengthscale': tensor([ 3.3961260319,  7.3913416862,  9.9597578049, 12.5292530060],
#        device='cuda:0'), 'eta': 2.8499178370111622e-05, 'tau²_hat': 34333.05078125}
# Test RMSE: 1.1249
# Test RRMSE: 0.0247
# Test rmsepd_sd: 0.0246
#
# --- Round 114 ---
# {'lengthscale': tensor([ 3.3961300850,  7.3913431168,  9.9597597122, 12.5290880203],
#        device='cuda:0'), 'eta': 2.8498989195213653e-05, 'tau²_hat': 34424.359375}
# Test RMSE: 1.1280
# Test RRMSE: 0.0247
# Test rmsepd_sd: 0.0247
#
# --- Round 115 ---
# {'lengthscale': tensor([ 3.3968911171,  7.3915281296,  9.9604930878, 12.4989986420],
#        device='cuda:0'), 'eta': 2.8463759008445777e-05, 'tau²_hat': 34051.81640625}
# Test RMSE: 1.1017
# Test RRMSE: 0.0242
# Test rmsepd_sd: 0.0241
#
# --- Round 116 ---
# {'lengthscale': tensor([ 3.3969664574,  7.3915300369,  9.9605941772, 12.4950304031],
#        device='cuda:0'), 'eta': 2.8459227905841544e-05, 'tau²_hat': 33322.00390625}
# Test RMSE: 1.1016
# Test RRMSE: 0.0241
# Test rmsepd_sd: 0.0241
#
# --- Round 117 ---
# {'lengthscale': tensor([ 3.3969707489,  7.3915300369,  9.9605979919, 12.4948549271],
#        device='cuda:0'), 'eta': 2.8459036911954172e-05, 'tau²_hat': 33058.98828125}
# Test RMSE: 1.0958
# Test RRMSE: 0.0240
# Test rmsepd_sd: 0.0240
#
# --- Round 118 ---
# {'lengthscale': tensor([ 3.3969707489,  7.3915300369,  9.9605979919, 12.4948492050],
#        device='cuda:0'), 'eta': 2.8459036911954172e-05, 'tau²_hat': 32223.126953125}
# Test RMSE: 1.0970
# Test RRMSE: 0.0240
# Test rmsepd_sd: 0.0240
#
# --- Round 119 ---
# {'lengthscale': tensor([ 3.3969707489,  7.3915300369,  9.9605979919, 12.4948492050],
#        device='cuda:0'), 'eta': 2.8459036911954172e-05, 'tau²_hat': 32355.91796875}
# Test RMSE: 1.1001
# Test RRMSE: 0.0241
# Test rmsepd_sd: 0.0241
#
# --- Round 120 ---
# {'lengthscale': tensor([ 3.3969724178,  7.3915300369,  9.9605998993, 12.4947080612],
#        device='cuda:0'), 'eta': 2.8458875021897256e-05, 'tau²_hat': 32653.455078125}
# Test RMSE: 1.1072
# Test RRMSE: 0.0243
# Test rmsepd_sd: 0.0243
#
# --- Round 121 ---
# {'lengthscale': tensor([ 3.3969736099,  7.3915300369,  9.9606027603, 12.4945774078],
#        device='cuda:0'), 'eta': 2.8458709493861534e-05, 'tau²_hat': 32236.40625}
# Test RMSE: 1.0995
# Test RRMSE: 0.0241
# Test rmsepd_sd: 0.0241
#
# --- Round 122 ---
# {'lengthscale': tensor([ 3.3969755173,  7.3915300369,  9.9606056213, 12.4944429398],
#        device='cuda:0'), 'eta': 2.8458547603804618e-05, 'tau²_hat': 32209.6484375}
# Test RMSE: 1.0964
# Test RRMSE: 0.0240
# Test rmsepd_sd: 0.0240
#
# --- Round 123 ---
# {'lengthscale': tensor([ 3.3972680569,  7.3915333748,  9.9609212875, 12.4759140015],
#        device='cuda:0'), 'eta': 2.8436979846446775e-05, 'tau²_hat': 31727.51953125}
# Test RMSE: 1.1085
# Test RRMSE: 0.0243
# Test rmsepd_sd: 0.0243
#
# --- Round 124 ---
# {'lengthscale': tensor([ 3.3972709179,  7.3915333748,  9.9609241486, 12.4757528305],
#        device='cuda:0'), 'eta': 2.8436790671548806e-05, 'tau²_hat': 31102.349609375}
# Test RMSE: 1.1053
# Test RRMSE: 0.0242
# Test rmsepd_sd: 0.0242
#
# --- Round 125 ---
# {'lengthscale': tensor([ 3.3972733021,  7.3915333748,  9.9609251022, 12.4755954742],
#        device='cuda:0'), 'eta': 2.8436599677661434e-05, 'tau²_hat': 30849.708984375}
# Test RMSE: 1.1052
# Test RRMSE: 0.0242
# Test rmsepd_sd: 0.0242
#
# --- Round 126 ---
# {'lengthscale': tensor([ 3.3972764015,  7.3915333748,  9.9609308243, 12.4753522873],
#        device='cuda:0'), 'eta': 2.843633046722971e-05, 'tau²_hat': 30875.783203125}
# Test RMSE: 1.1021
# Test RRMSE: 0.0242
# Test rmsepd_sd: 0.0241
#
# --- Round 127 ---
# {'lengthscale': tensor([ 3.3979709148,  7.3915653229,  9.9622631073, 12.4018030167],
#        device='cuda:0'), 'eta': 2.835141094692517e-05, 'tau²_hat': 30930.65234375}
# Test RMSE: 1.1164
# Test RRMSE: 0.0245
# Test rmsepd_sd: 0.0245
#
# --- Round 128 ---
# {'lengthscale': tensor([ 3.3979856968,  7.3915438652,  9.9625005722, 12.3869915009],
#        device='cuda:0'), 'eta': 2.8334274247754365e-05, 'tau²_hat': 31130.44921875}
# Test RMSE: 1.0788
# Test RRMSE: 0.0237
# Test rmsepd_sd: 0.0236
#
# --- Round 129 ---
# {'lengthscale': tensor([ 3.3979868889,  7.3915457726,  9.9625024796, 12.3868999481],
#        device='cuda:0'), 'eta': 2.8334166927379556e-05, 'tau²_hat': 29849.15234375}
# Test RMSE: 1.0713
# Test RRMSE: 0.0235
# Test rmsepd_sd: 0.0235
#
# --- Round 130 ---
# {'lengthscale': tensor([ 3.3981399536,  7.3916745186,  9.9627189636, 12.3759574890],
#        device='cuda:0'), 'eta': 2.8321388526819646e-05, 'tau²_hat': 32943.40625}
# Test RMSE: 1.0474
# Test RRMSE: 0.0230
# Test rmsepd_sd: 0.0230
#
# --- Round 131 ---
# {'lengthscale': tensor([ 3.3984000683,  7.3918242455,  9.9631509781, 12.3606262207],
#        device='cuda:0'), 'eta': 2.8303566068643704e-05, 'tau²_hat': 31950.0}
# Test RMSE: 1.0385
# Test RRMSE: 0.0228
# Test rmsepd_sd: 0.0228
#
# --- Round 132 ---
# {'lengthscale': tensor([ 3.3984000683,  7.3918242455,  9.9631509781, 12.3606262207],
#        device='cuda:0'), 'eta': 2.8303566068643704e-05, 'tau²_hat': 31563.82421875}
# Test RMSE: 1.0364
# Test RRMSE: 0.0227
# Test rmsepd_sd: 0.0227
#
# --- Round 133 ---
# {'lengthscale': tensor([ 3.3984024525,  7.3918261528,  9.9631557465, 12.3604288101],
#        device='cuda:0'), 'eta': 2.8303351427894086e-05, 'tau²_hat': 31593.45703125}
# Test RMSE: 1.0400
# Test RRMSE: 0.0228
# Test rmsepd_sd: 0.0228
#
# --- Round 134 ---
# {'lengthscale': tensor([ 3.3986165524,  7.3919267654,  9.9636640549, 12.3421506882],
#        device='cuda:0'), 'eta': 2.8282385756028816e-05, 'tau²_hat': 31253.05859375}
# Test RMSE: 1.0257
# Test RRMSE: 0.0225
# Test rmsepd_sd: 0.0225
#
# --- Round 135 ---
# {'lengthscale': tensor([ 3.3986165524,  7.3919267654,  9.9636640549, 12.3421506882],
#        device='cuda:0'), 'eta': 2.8282385756028816e-05, 'tau²_hat': 31097.865234375}
# Test RMSE: 1.0270
# Test RRMSE: 0.0225
# Test rmsepd_sd: 0.0225
#
# --- Round 136 ---
# {'lengthscale': tensor([ 3.3989233971,  7.3921046257,  9.9641199112, 12.3266201019],
#        device='cuda:0'), 'eta': 2.82643195532728e-05, 'tau²_hat': 31036.84375}
# Test RMSE: 1.0287
# Test RRMSE: 0.0226
# Test rmsepd_sd: 0.0225
#
# --- Round 137 ---
# {'lengthscale': tensor([ 3.3990554810,  7.3921542168,  9.9643936157, 12.3163919449],
#        device='cuda:0'), 'eta': 2.8252030460862443e-05, 'tau²_hat': 30580.828125}
# Test RMSE: 1.0221
# Test RRMSE: 0.0224
# Test rmsepd_sd: 0.0224
#
# --- Round 138 ---
# {'lengthscale': tensor([ 3.3993570805,  7.3921980858,  9.9650917053, 12.2924823761],
#        device='cuda:0'), 'eta': 2.822394344548229e-05, 'tau²_hat': 30561.0546875}
# Test RMSE: 1.0224
# Test RRMSE: 0.0224
# Test rmsepd_sd: 0.0224
#
# --- Round 139 ---
# {'lengthscale': tensor([ 3.3997719288,  7.3923001289,  9.9659194946, 12.2653236389],
#        device='cuda:0'), 'eta': 2.819254768837709e-05, 'tau²_hat': 30126.44140625}
# Test RMSE: 0.9913
# Test RRMSE: 0.0217
# Test rmsepd_sd: 0.0217
#
# --- Round 140 ---
# {'lengthscale': tensor([ 3.4003114700,  7.3924784660,  9.9668102264, 12.2322921753],
#        device='cuda:0'), 'eta': 2.8153805033070967e-05, 'tau²_hat': 29732.052734375}
# Test RMSE: 1.0030
# Test RRMSE: 0.0220
# Test rmsepd_sd: 0.0220
#
# --- Round 141 ---
# {'lengthscale': tensor([ 3.4003129005,  7.3924784660,  9.9668121338, 12.2321548462],
#        device='cuda:0'), 'eta': 2.8153644962003455e-05, 'tau²_hat': 28852.763671875}
# Test RMSE: 1.0013
# Test RRMSE: 0.0220
# Test rmsepd_sd: 0.0219
#
# --- Round 142 ---
# {'lengthscale': tensor([ 3.4003767967,  7.3924727440,  9.9671192169, 12.2195453644],
#        device='cuda:0'), 'eta': 2.813861283357255e-05, 'tau²_hat': 28935.884765625}
# Test RMSE: 0.9805
# Test RRMSE: 0.0215
# Test rmsepd_sd: 0.0215
#
# --- Round 143 ---
# {'lengthscale': tensor([ 3.4003767967,  7.3924727440,  9.9671192169, 12.2195453644],
#        device='cuda:0'), 'eta': 2.813861283357255e-05, 'tau²_hat': 28150.0625}
# Test RMSE: 0.9886
# Test RRMSE: 0.0217
# Test rmsepd_sd: 0.0217
#
# --- Round 144 ---
# {'lengthscale': tensor([ 3.4003796577,  7.3924727440,  9.9671258926, 12.2192955017],
#        device='cuda:0'), 'eta': 2.8138318157289177e-05, 'tau²_hat': 28293.599609375}
# Test RMSE: 0.9921
# Test RRMSE: 0.0217
# Test rmsepd_sd: 0.0217
#
# --- Round 145 ---
# {'lengthscale': tensor([ 3.4005923271,  7.3925099373,  9.9677057266, 12.1922197342],
#        device='cuda:0'), 'eta': 2.810653495544102e-05, 'tau²_hat': 28138.912109375}
# Test RMSE: 0.9573
# Test RRMSE: 0.0210
# Test rmsepd_sd: 0.0210
#
# --- Round 146 ---
# {'lengthscale': tensor([ 3.4007856846,  7.3925185204,  9.9682044983, 12.1715984344],
#        device='cuda:0'), 'eta': 2.8081673008273356e-05, 'tau²_hat': 27719.841796875}
# Test RMSE: 0.9696
# Test RRMSE: 0.0213
# Test rmsepd_sd: 0.0212
#
# --- Round 147 ---
# {'lengthscale': tensor([ 3.4009156227,  7.3924942017,  9.9686183929, 12.1544427872],
#        device='cuda:0'), 'eta': 2.8061460398021154e-05, 'tau²_hat': 27359.091796875}
# Test RMSE: 0.9423
# Test RRMSE: 0.0207
# Test rmsepd_sd: 0.0206
#
# --- Round 148 ---
# {'lengthscale': tensor([ 3.4009175301,  7.3924942017,  9.9686231613, 12.1542596817],
#        device='cuda:0'), 'eta': 2.8061245757271536e-05, 'tau²_hat': 27254.00390625}
# Test RMSE: 0.9493
# Test RRMSE: 0.0208
# Test rmsepd_sd: 0.0208
#
# --- Round 149 ---
# {'lengthscale': tensor([ 3.4010279179,  7.3924851418,  9.9688587189, 12.1435451508],
#        device='cuda:0'), 'eta': 2.8048430976923555e-05, 'tau²_hat': 27557.888671875}
# Test RMSE: 0.9547
# Test RRMSE: 0.0209
# Test rmsepd_sd: 0.0209
#
# --- Round 150 ---
# {'lengthscale': tensor([ 3.4014396667,  7.3924975395,  9.9695882797, 12.1096630096],
#        device='cuda:0'), 'eta': 2.8006892534904182e-05, 'tau²_hat': 27443.5390625}
# Test RMSE: 0.9623
# Test RRMSE: 0.0211
# Test rmsepd_sd: 0.0211
#
# --- Round 151 ---
# {'lengthscale': tensor([ 3.4014406204,  7.3924975395,  9.9695911407, 12.1095104218],
#        device='cuda:0'), 'eta': 2.8006708816974424e-05, 'tau²_hat': 26979.330078125}
# Test RMSE: 0.9632
# Test RRMSE: 0.0211
# Test rmsepd_sd: 0.0211
#
# --- Round 152 ---
# {'lengthscale': tensor([ 3.4015669823,  7.3924431801,  9.9699516296, 12.0931634903],
#        device='cuda:0'), 'eta': 2.798716195684392e-05, 'tau²_hat': 26623.21875}
# Test RMSE: 0.9230
# Test RRMSE: 0.0202
# Test rmsepd_sd: 0.0202
#
# --- Round 153 ---
# {'lengthscale': tensor([ 3.4015674591,  7.3924412727,  9.9699544907, 12.0930080414],
#        device='cuda:0'), 'eta': 2.798700370476581e-05, 'tau²_hat': 26388.392578125}
# Test RMSE: 0.9258
# Test RRMSE: 0.0203
# Test rmsepd_sd: 0.0203
#
# --- Round 154 ---
# {'lengthscale': tensor([ 3.4015684128,  7.3924393654,  9.9699592590, 12.0928058624],
#        device='cuda:0'), 'eta': 2.798676177917514e-05, 'tau²_hat': 26398.6640625}
# Test RMSE: 0.9267
# Test RRMSE: 0.0203
# Test rmsepd_sd: 0.0203
#
# --- Round 155 ---
# {'lengthscale': tensor([ 3.4016435146,  7.3924055099,  9.9702062607, 12.0809240341],
#        device='cuda:0'), 'eta': 2.7972566385869868e-05, 'tau²_hat': 26414.931640625}
# Test RMSE: 0.9490
# Test RRMSE: 0.0208
# Test rmsepd_sd: 0.0208
#
# --- Round 156 ---
# {'lengthscale': tensor([ 3.4015932083,  7.3922953606,  9.9705743790, 12.0642814636],
#        device='cuda:0'), 'eta': 2.795240652631037e-05, 'tau²_hat': 26557.599609375}
# Test RMSE: 0.9447
# Test RRMSE: 0.0207
# Test rmsepd_sd: 0.0207
#
# --- Round 157 ---
# {'lengthscale': tensor([ 3.4015130997,  7.3920111656,  9.9713563919, 12.0278129578],
#        device='cuda:0'), 'eta': 2.7908616175409406e-05, 'tau²_hat': 27756.77734375}
# Test RMSE: 0.9134
# Test RRMSE: 0.0200
# Test rmsepd_sd: 0.0200
#
# --- Round 158 ---
# {'lengthscale': tensor([ 3.4014897346,  7.3919439316,  9.9715442657, 12.0186109543],
#        device='cuda:0'), 'eta': 2.789759855659213e-05, 'tau²_hat': 27033.1015625}
# Test RMSE: 0.9145
# Test RRMSE: 0.0200
# Test rmsepd_sd: 0.0200
#
# --- Round 159 ---
# {'lengthscale': tensor([ 3.4014887810,  7.3919425011,  9.9715471268, 12.0184516907],
#        device='cuda:0'), 'eta': 2.7897413019672967e-05, 'tau²_hat': 26663.30859375}
# Test RMSE: 0.9158
# Test RRMSE: 0.0201
# Test rmsepd_sd: 0.0201
#
# --- Round 160 ---
# {'lengthscale': tensor([ 3.4014585018,  7.3919034004,  9.9716215134, 12.0146064758],
#        device='cuda:0'), 'eta': 2.7892758225789294e-05, 'tau²_hat': 26391.9609375}
# Test RMSE: 0.9103
# Test RRMSE: 0.0200
# Test rmsepd_sd: 0.0199
#
# --- Round 161 ---
# {'lengthscale': tensor([ 3.4011914730,  7.3915848732,  9.9721984863, 11.9866218567],
#        device='cuda:0'), 'eta': 2.7858890462084673e-05, 'tau²_hat': 26119.41015625}
# Test RMSE: 0.8950
# Test RRMSE: 0.0196
# Test rmsepd_sd: 0.0196
#
# --- Round 162 ---
# {'lengthscale': tensor([ 3.4011902809,  7.3915829659,  9.9722013474, 11.9864959717],
#        device='cuda:0'), 'eta': 2.7858728572027758e-05, 'tau²_hat': 25680.0078125}
# Test RMSE: 0.8923
# Test RRMSE: 0.0196
# Test rmsepd_sd: 0.0196
#
# --- Round 163 ---
# {'lengthscale': tensor([ 3.4010586739,  7.3914103508,  9.9723911285, 11.9747276306],
#        device='cuda:0'), 'eta': 2.7844651413033716e-05, 'tau²_hat': 25999.794921875}
# Test RMSE: 0.8983
# Test RRMSE: 0.0197
# Test rmsepd_sd: 0.0197
#
# --- Round 164 ---
# {'lengthscale': tensor([ 3.4010581970,  7.3914103508,  9.9723958969, 11.9745273590],
#        device='cuda:0'), 'eta': 2.7844413125421852e-05, 'tau²_hat': 25851.630859375}
# Test RMSE: 0.9034
# Test RRMSE: 0.0198
# Test rmsepd_sd: 0.0198
#
# --- Round 165 ---
# {'lengthscale': tensor([ 3.4010784626,  7.3913288116,  9.9730100632, 11.9451828003],
#        device='cuda:0'), 'eta': 2.780959584924858e-05, 'tau²_hat': 25831.541015625}
# Test RMSE: 0.8713
# Test RRMSE: 0.0191
# Test rmsepd_sd: 0.0191
#
# --- Round 166 ---
# {'lengthscale': tensor([ 3.4009790421,  7.3911848068,  9.9731874466, 11.9338254929],
#        device='cuda:0'), 'eta': 2.779609894787427e-05, 'tau²_hat': 25500.595703125}
# Test RMSE: 0.8833
# Test RRMSE: 0.0194
# Test rmsepd_sd: 0.0194
#
# --- Round 167 ---
# {'lengthscale': tensor([ 3.4009778500,  7.3911828995,  9.9731903076, 11.9336338043],
#        device='cuda:0'), 'eta': 2.7795860660262406e-05, 'tau²_hat': 25488.1484375}
# Test RMSE: 0.8816
# Test RRMSE: 0.0193
# Test rmsepd_sd: 0.0193
#
# --- Round 168 ---
# {'lengthscale': tensor([ 3.4009768963,  7.3911809921,  9.9731950760, 11.9334316254],
#        device='cuda:0'), 'eta': 2.7795620553661138e-05, 'tau²_hat': 25204.009765625}
# Test RMSE: 0.8846
# Test RRMSE: 0.0194
# Test rmsepd_sd: 0.0194
#
# --- Round 169 ---
# {'lengthscale': tensor([ 3.4009180069,  7.3911213875,  9.9734802246, 11.9173793793],
#        device='cuda:0'), 'eta': 2.777643567242194e-05, 'tau²_hat': 25155.951171875}
# Test RMSE: 0.8639
# Test RRMSE: 0.0189
# Test rmsepd_sd: 0.0189
#
# --- Round 170 ---
# {'lengthscale': tensor([ 3.4008867741,  7.3910965919,  9.9736986160, 11.9047088623],
#        device='cuda:0'), 'eta': 2.77618455584161e-05, 'tau²_hat': 25147.919921875}
# Test RMSE: 0.8671
# Test RRMSE: 0.0190
# Test rmsepd_sd: 0.0190
#
# --- Round 171 ---
# {'lengthscale': tensor([ 3.4008522034,  7.3910651207,  9.9738960266, 11.8944549561],
#        device='cuda:0'), 'eta': 2.7749669243348762e-05, 'tau²_hat': 24808.92578125}
# Test RMSE: 0.8590
# Test RRMSE: 0.0188
# Test rmsepd_sd: 0.0188
#
# --- Round 172 ---
# {'lengthscale': tensor([ 3.4008595943,  7.3910579681,  9.9740705490, 11.8843727112],
#        device='cuda:0'), 'eta': 2.773776213871315e-05, 'tau²_hat': 24530.49609375}
# Test RMSE: 0.8596
# Test RRMSE: 0.0188
# Test rmsepd_sd: 0.0188
#
# --- Round 173 ---
# {'lengthscale': tensor([ 3.4008595943,  7.3910579681,  9.9740705490, 11.8843469620],
#        device='cuda:0'), 'eta': 2.77377366728615e-05, 'tau²_hat': 24387.5546875}
# Test RMSE: 0.8543
# Test RRMSE: 0.0187
# Test rmsepd_sd: 0.0187
#
# --- Round 174 ---
# {'lengthscale': tensor([ 3.4008598328,  7.3910579681,  9.9740715027, 11.8842220306],
#        device='cuda:0'), 'eta': 2.773757660179399e-05, 'tau²_hat': 24470.919921875}
# Test RMSE: 0.8565
# Test RRMSE: 0.0188
# Test rmsepd_sd: 0.0188
#
# --- Round 175 ---
# {'lengthscale': tensor([ 3.4008598328,  7.3910579681,  9.9740743637, 11.8840570450],
#        device='cuda:0'), 'eta': 2.773739288386423e-05, 'tau²_hat': 24536.431640625}
# Test RMSE: 0.8545
# Test RRMSE: 0.0187
# Test rmsepd_sd: 0.0187
#
# --- Round 176 ---
# {'lengthscale': tensor([ 3.4008598328,  7.3910579681,  9.9740743637, 11.8840570450],
#        device='cuda:0'), 'eta': 2.773739288386423e-05, 'tau²_hat': 24171.337890625}
# Test RMSE: 0.8505
# Test RRMSE: 0.0186
# Test rmsepd_sd: 0.0186
#
# --- Round 177 ---
# {'lengthscale': tensor([ 3.4008595943,  7.3910579681,  9.9740772247, 11.8839159012],
#        device='cuda:0'), 'eta': 2.773723281279672e-05, 'tau²_hat': 24069.615234375}
# Test RMSE: 0.8523
# Test RRMSE: 0.0187
# Test rmsepd_sd: 0.0187
#
# --- Round 178 ---
# {'lengthscale': tensor([ 3.4008595943,  7.3910579681,  9.9740819931, 11.8836784363],
#        device='cuda:0'), 'eta': 2.7736969059333205e-05, 'tau²_hat': 23966.599609375}
# Test RMSE: 0.8583
# Test RRMSE: 0.0188
# Test rmsepd_sd: 0.0188
#
# --- Round 179 ---
# {'lengthscale': tensor([ 3.4008677006,  7.3910331726,  9.9743432999, 11.8707418442],
#        device='cuda:0'), 'eta': 2.7721922378987074e-05, 'tau²_hat': 23843.07421875}
# Test RMSE: 0.8493
# Test RRMSE: 0.0186
# Test rmsepd_sd: 0.0186
#
# --- Round 180 ---
# {'lengthscale': tensor([ 3.4007577896,  7.3908624649,  9.9749708176, 11.8383636475],
#        device='cuda:0'), 'eta': 2.7684089218382724e-05, 'tau²_hat': 23742.85546875}
# Test RMSE: 0.8329
# Test RRMSE: 0.0183
# Test rmsepd_sd: 0.0183
#
# --- Round 181 ---
# {'lengthscale': tensor([ 3.4007577896,  7.3908624649,  9.9749708176, 11.8383274078],
#        device='cuda:0'), 'eta': 2.768403646769002e-05, 'tau²_hat': 23345.732421875}
# Test RMSE: 0.8305
# Test RRMSE: 0.0182
# Test rmsepd_sd: 0.0182
#
# --- Round 182 ---
# {'lengthscale': tensor([ 3.4007055759,  7.3908071518,  9.9753637314, 11.8177881241],
#        device='cuda:0'), 'eta': 2.7659942134050652e-05, 'tau²_hat': 23318.814453125}
# Test RMSE: 0.8446
# Test RRMSE: 0.0185
# Test rmsepd_sd: 0.0185
#
# --- Round 183 ---
# {'lengthscale': tensor([ 3.4006426334,  7.3906788826,  9.9756488800, 11.8024263382],
#        device='cuda:0'), 'eta': 2.764150849543512e-05, 'tau²_hat': 23109.931640625}
# Test RMSE: 0.8280
# Test RRMSE: 0.0182
# Test rmsepd_sd: 0.0181
#
# --- Round 184 ---
# {'lengthscale': tensor([ 3.4006426334,  7.3906774521,  9.9756536484, 11.8021984100],
#        device='cuda:0'), 'eta': 2.7641246560961008e-05, 'tau²_hat': 23165.681640625}
# Test RMSE: 0.8208
# Test RRMSE: 0.0180
# Test rmsepd_sd: 0.0180
#
# --- Round 185 ---
# {'lengthscale': tensor([ 3.4006426334,  7.3906774521,  9.9756536484, 11.8021984100],
#        device='cuda:0'), 'eta': 2.7641246560961008e-05, 'tau²_hat': 23016.98046875}
# Test RMSE: 0.8189
# Test RRMSE: 0.0180
# Test rmsepd_sd: 0.0179
#
# --- Round 186 ---
# {'lengthscale': tensor([ 3.4006426334,  7.3906774521,  9.9756536484, 11.8021926880],
#        device='cuda:0'), 'eta': 2.7641246560961008e-05, 'tau²_hat': 22985.802734375}
# Test RMSE: 0.8195
# Test RRMSE: 0.0180
# Test rmsepd_sd: 0.0180
#
# --- Round 187 ---
# {'lengthscale': tensor([ 3.4006423950,  7.3906755447,  9.9756584167, 11.8019704819],
#        device='cuda:0'), 'eta': 2.764098098850809e-05, 'tau²_hat': 23059.01953125}
# Test RMSE: 0.8194
# Test RRMSE: 0.0180
# Test rmsepd_sd: 0.0180
#
# --- Round 188 ---
# {'lengthscale': tensor([ 3.3999192715,  7.3889784813,  9.9811086655, 11.5386123657],
#        device='cuda:0'), 'eta': 2.733680776145775e-05, 'tau²_hat': 22909.43359375}
# Test RMSE: 0.7900
# Test RRMSE: 0.0173
# Test rmsepd_sd: 0.0173
#
# --- Round 189 ---
# {'lengthscale': tensor([ 3.3997950554,  7.3889284134,  9.9812307358, 11.5257806778],
#        device='cuda:0'), 'eta': 2.7321560992277227e-05, 'tau²_hat': 21376.1015625}
# Test RMSE: 0.7501
# Test RRMSE: 0.0164
# Test rmsepd_sd: 0.0164
#
# --- Round 190 ---
# {'lengthscale': tensor([ 3.3995375633,  7.3886814117,  9.9814138412, 11.5098285675],
#        device='cuda:0'), 'eta': 2.7302572561893612e-05, 'tau²_hat': 20606.74609375}
# Test RMSE: 0.7543
# Test RRMSE: 0.0165
# Test rmsepd_sd: 0.0165
#
# --- Round 191 ---
# {'lengthscale': tensor([ 3.3995332718,  7.3886780739,  9.9814167023, 11.5096206665],
#        device='cuda:0'), 'eta': 2.7302337912260555e-05, 'tau²_hat': 20367.712890625}
# Test RMSE: 0.7453
# Test RRMSE: 0.0163
# Test rmsepd_sd: 0.0163
#
# --- Round 192 ---
# {'lengthscale': tensor([ 3.3993136883,  7.3885359764,  9.9815750122, 11.4962816238],
#        device='cuda:0'), 'eta': 2.728672006924171e-05, 'tau²_hat': 20103.1171875}
# Test RMSE: 0.7395
# Test RRMSE: 0.0162
# Test rmsepd_sd: 0.0162
#
# --- Round 193 ---
# {'lengthscale': tensor([ 3.3993136883,  7.3885359764,  9.9815750122, 11.4962816238],
#        device='cuda:0'), 'eta': 2.728672006924171e-05, 'tau²_hat': 19926.763671875}
# Test RMSE: 0.7391
# Test RRMSE: 0.0162
# Test rmsepd_sd: 0.0162
#
# --- Round 194 ---
# {'lengthscale': tensor([ 3.3991110325,  7.3883237839,  9.9817419052, 11.4845609665],
#        device='cuda:0'), 'eta': 2.7272906663711183e-05, 'tau²_hat': 19951.048828125}
# Test RMSE: 0.7422
# Test RRMSE: 0.0163
# Test rmsepd_sd: 0.0163
#
# --- Round 195 ---
# {'lengthscale': tensor([ 3.3991062641,  7.3883209229,  9.9817466736, 11.4842548370],
#        device='cuda:0'), 'eta': 2.727254104684107e-05, 'tau²_hat': 20093.474609375}
# Test RMSE: 0.7450
# Test RRMSE: 0.0163
# Test rmsepd_sd: 0.0163
#
# --- Round 196 ---
# {'lengthscale': tensor([ 3.3989553452,  7.3881659508,  9.9819250107, 11.4724950790],
#        device='cuda:0'), 'eta': 2.725917693169322e-05, 'tau²_hat': 19973.873046875}
# Test RMSE: 0.7427
# Test RRMSE: 0.0163
# Test rmsepd_sd: 0.0163
#
# --- Round 197 ---
# {'lengthscale': tensor([ 3.3987987041,  7.3880252838,  9.9821910858, 11.4570074081],
#        device='cuda:0'), 'eta': 2.7241349016549066e-05, 'tau²_hat': 19977.626953125}
# Test RMSE: 0.7466
# Test RRMSE: 0.0164
# Test rmsepd_sd: 0.0164
#
# --- Round 198 ---
# {'lengthscale': tensor([ 3.3987960815,  7.3880224228,  9.9821939468, 11.4568138123],
#        device='cuda:0'), 'eta': 2.7241114366916008e-05, 'tau²_hat': 19966.5625}
# Test RMSE: 0.7501
# Test RRMSE: 0.0164
# Test rmsepd_sd: 0.0164
#
# --- Round 199 ---
# {'lengthscale': tensor([ 3.3986427784,  7.3878517151,  9.9824323654, 11.4428749084],
#        device='cuda:0'), 'eta': 2.722501267271582e-05, 'tau²_hat': 19925.537109375}
# Test RMSE: 0.7414
# Test RRMSE: 0.0163
# Test rmsepd_sd: 0.0162

# %%
print('final result', result['rmspesd'][-1])
print('first result', result['rmspesd'][0])
print('best result',min(result['rmspesd']))
# Out:
# final result 0.01624472066760063
# first result 0.10771948844194412
# best result 0.01619463786482811

# %%
print('final result', result['rrmse'][-1])
print('first result', result['rrmse'][0])
print('best result',min(result['rrmse']))
# Out:
# final result 0.016252849251031876
# first result 0.10777338594198227
# best result 0.016202742233872414

# %%
print('final result', result['rmse'][-1])
print('first result', result['rmse'][0])
print('best result',min(result['rmse']))
plt.plot(result['rmse']);
# Out:
# final result 0.7413694858551025
# first result 4.916054725646973
# best result 0.7390838265419006

# %%
result_random = run_active_learning(
    model=model_copy,
    x_train_init=x_train,
    y_train_init=y_train,
    x_cand=x_cand,
    y_cand=y_cand,
    x_ref=x_ref,
    x_test=x_test,
    y_test=y_test,
    T=200,
    save_plot_path="fig/0/rALAEmGP-Borehole",
    randomAC=True
)
np.save('data/0/rALAEmGP-Borehole-xtrainFinal.npy',result_random['final_x_train'].cpu().numpy())
np.save('data/0/rALAEmGP-Borehole-ytrainFinal.npy',result_random['final_y_train'].cpu().numpy())
np.save('data/0/rALAEmGP-Borehole-testrmse.npy',result_random['rmse'])
np.save('data/0/rALAEmGP-Borehole-testrmspesd.npy',result_random['rmspesd'])
# Out:
# --- Round 0 ---
# {'lengthscale': tensor([ 3.2530357838,  7.2943854332,  9.8903446198, 14.7436513901],
#        device='cuda:0'), 'eta': 3.0374303605640307e-05, 'tau²_hat': 1.0}
# Test RMSE: 4.9161
# Test RRMSE: 0.1078
# Test rmsepd_sd: 0.1077
#
# --- Round 1 ---
# {'lengthscale': tensor([ 3.2646241188,  7.3012652397,  9.8973226547, 14.6701431274],
#        device='cuda:0'), 'eta': 3.034497240150813e-05, 'tau²_hat': 116615.7578125}
# Test RMSE: 4.4918
# Test RRMSE: 0.0985
# Test rmsepd_sd: 0.0984
#
# --- Round 2 ---
# {'lengthscale': tensor([ 3.2646241188,  7.3012652397,  9.8973226547, 14.6701431274],
#        device='cuda:0'), 'eta': 3.034497240150813e-05, 'tau²_hat': 93733.4140625}
# Test RMSE: 4.4699
# Test RRMSE: 0.0980
# Test rmsepd_sd: 0.0979
#
# --- Round 3 ---
# {'lengthscale': tensor([ 3.2646257877,  7.3012657166,  9.8973226547, 14.6701297760],
#        device='cuda:0'), 'eta': 3.034497240150813e-05, 'tau²_hat': 97028.0}
# Test RMSE: 4.4504
# Test RRMSE: 0.0976
# Test rmsepd_sd: 0.0975
#
# --- Round 4 ---
# {'lengthscale': tensor([ 3.2654018402,  7.3016157150,  9.8968858719, 14.6620740891],
#        device='cuda:0'), 'eta': 3.033918619621545e-05, 'tau²_hat': 95916.078125}
# Test RMSE: 4.3966
# Test RRMSE: 0.0964
# Test rmsepd_sd: 0.0963
#
# --- Round 5 ---
# {'lengthscale': tensor([ 3.2654139996,  7.3016228676,  9.8968858719, 14.6619825363],
#        device='cuda:0'), 'eta': 3.0339127988554537e-05, 'tau²_hat': 93051.5546875}
# Test RMSE: 4.4204
# Test RRMSE: 0.0969
# Test rmsepd_sd: 0.0969
#
# --- Round 6 ---
# {'lengthscale': tensor([ 3.2654271126,  7.3016295433,  9.8968906403, 14.6618814468],
#        device='cuda:0'), 'eta': 3.0339069780893624e-05, 'tau²_hat': 103008.359375}
# Test RMSE: 4.4821
# Test RRMSE: 0.0983
# Test rmsepd_sd: 0.0982
#
# --- Round 7 ---
# {'lengthscale': tensor([ 3.2703886032,  7.3043513298,  9.8984928131, 14.6224298477],
#        device='cuda:0'), 'eta': 3.0316712582134642e-05, 'tau²_hat': 104292.578125}
# Test RMSE: 4.3403
# Test RRMSE: 0.0952
# Test rmsepd_sd: 0.0951
#
# --- Round 8 ---
# {'lengthscale': tensor([ 3.2991726398,  7.3197379112,  9.9056224823, 14.3860301971],
#        device='cuda:0'), 'eta': 3.0157132641761564e-05, 'tau²_hat': 96091.0859375}
# Test RMSE: 3.6321
# Test RRMSE: 0.0796
# Test rmsepd_sd: 0.0796
#
# --- Round 9 ---
# {'lengthscale': tensor([ 3.2991850376,  7.3197441101,  9.9056224823, 14.3859100342],
#        device='cuda:0'), 'eta': 3.0157045330270194e-05, 'tau²_hat': 71420.8984375}
# Test RMSE: 3.6277
# Test RRMSE: 0.0795
# Test rmsepd_sd: 0.0795
#
# --- Round 10 ---
# {'lengthscale': tensor([ 3.3034334183,  7.3218932152,  9.9069089890, 14.3532819748],
#        device='cuda:0'), 'eta': 3.0134249755064957e-05, 'tau²_hat': 80304.40625}
# Test RMSE: 3.4667
# Test RRMSE: 0.0760
# Test rmsepd_sd: 0.0760
#
# --- Round 11 ---
# {'lengthscale': tensor([ 3.3034465313,  7.3218994141,  9.9069089890, 14.3531684875],
#        device='cuda:0'), 'eta': 3.0134162443573587e-05, 'tau²_hat': 83394.3359375}
# Test RMSE: 3.4719
# Test RRMSE: 0.0761
# Test rmsepd_sd: 0.0761
#
# --- Round 12 ---
# {'lengthscale': tensor([ 3.3565988541,  7.3525886536,  9.9287633896, 14.0320043564],
#        device='cuda:0'), 'eta': 2.994871283590328e-05, 'tau²_hat': 82218.03125}
# Test RMSE: 2.4396
# Test RRMSE: 0.0535
# Test rmsepd_sd: 0.0535
#
# --- Round 13 ---
# {'lengthscale': tensor([ 3.3566036224,  7.3525905609,  9.9287652969, 14.0319509506],
#        device='cuda:0'), 'eta': 2.994865644723177e-05, 'tau²_hat': 63340.8359375}
# Test RMSE: 2.3341
# Test RRMSE: 0.0512
# Test rmsepd_sd: 0.0511
#
# --- Round 14 ---
# {'lengthscale': tensor([ 3.3600633144,  7.3536434174,  9.9307308197, 13.9943523407],
#        device='cuda:0'), 'eta': 2.9917910069343634e-05, 'tau²_hat': 89654.1015625}
# Test RMSE: 2.2745
# Test RRMSE: 0.0499
# Test rmsepd_sd: 0.0498
#
# --- Round 15 ---
# {'lengthscale': tensor([ 3.3600728512,  7.3536496162,  9.9307308197, 13.9942588806],
#        device='cuda:0'), 'eta': 2.991782639583107e-05, 'tau²_hat': 76365.125}
# Test RMSE: 2.2671
# Test RRMSE: 0.0497
# Test rmsepd_sd: 0.0497
#
# --- Round 16 ---
# {'lengthscale': tensor([ 3.3601257801,  7.3536810875,  9.9307308197, 13.9937572479],
#        device='cuda:0'), 'eta': 2.991742621816229e-05, 'tau²_hat': 75242.7421875}
# Test RMSE: 2.2379
# Test RRMSE: 0.0491
# Test rmsepd_sd: 0.0490
#
# --- Round 17 ---
# {'lengthscale': tensor([ 3.3659982681,  7.3569836617,  9.9305744171, 13.9383869171],
#        device='cuda:0'), 'eta': 2.987135485454928e-05, 'tau²_hat': 74218.09375}
# Test RMSE: 2.1313
# Test RRMSE: 0.0467
# Test rmsepd_sd: 0.0467
#
# --- Round 18 ---
# {'lengthscale': tensor([ 3.3700282574,  7.3584270477,  9.9317493439, 13.8936586380],
#        device='cuda:0'), 'eta': 2.9830473067704588e-05, 'tau²_hat': 66428.296875}
# Test RMSE: 2.0799
# Test RRMSE: 0.0456
# Test rmsepd_sd: 0.0456
#
# --- Round 19 ---
# {'lengthscale': tensor([ 3.3700356483,  7.3584313393,  9.9317493439, 13.8935728073],
#        device='cuda:0'), 'eta': 2.9830389394192025e-05, 'tau²_hat': 62560.20703125}
# Test RMSE: 2.0911
# Test RRMSE: 0.0458
# Test rmsepd_sd: 0.0458
#
# --- Round 20 ---
# {'lengthscale': tensor([ 3.3700466156,  7.3584361076,  9.9317493439, 13.8934431076],
#        device='cuda:0'), 'eta': 2.9830276616849005e-05, 'tau²_hat': 61645.97265625}
# Test RMSE: 2.1044
# Test RRMSE: 0.0461
# Test rmsepd_sd: 0.0461
#
# --- Round 21 ---
# {'lengthscale': tensor([ 3.3723006248,  7.3596282005,  9.9312353134, 13.8667974472],
#        device='cuda:0'), 'eta': 2.9805534722981974e-05, 'tau²_hat': 60783.6015625}
# Test RMSE: 2.0435
# Test RRMSE: 0.0448
# Test rmsepd_sd: 0.0448
#
# --- Round 22 ---
# {'lengthscale': tensor([ 3.3723080158,  7.3596305847,  9.9312353134, 13.8667049408],
#        device='cuda:0'), 'eta': 2.980545104946941e-05, 'tau²_hat': 55357.859375}
# Test RMSE: 2.0498
# Test RRMSE: 0.0449
# Test rmsepd_sd: 0.0449
#
# --- Round 23 ---
# {'lengthscale': tensor([ 3.3761661053,  7.3611531258,  9.9316139221, 13.8235483170],
#        device='cuda:0'), 'eta': 2.9763752536382526e-05, 'tau²_hat': 56617.22265625}
# Test RMSE: 1.9499
# Test RRMSE: 0.0427
# Test rmsepd_sd: 0.0427
#
# --- Round 24 ---
# {'lengthscale': tensor([ 3.3777692318,  7.3619198799,  9.9316024780, 13.8050127029],
#        device='cuda:0'), 'eta': 2.974610288219992e-05, 'tau²_hat': 55590.21875}
# Test RMSE: 1.9487
# Test RRMSE: 0.0427
# Test rmsepd_sd: 0.0427
#
# --- Round 25 ---
# {'lengthscale': tensor([ 3.3777763844,  7.3619222641,  9.9316043854, 13.8048973083],
#        device='cuda:0'), 'eta': 2.9745988285867497e-05, 'tau²_hat': 49542.5703125}
# Test RMSE: 1.9450
# Test RRMSE: 0.0426
# Test rmsepd_sd: 0.0426
#
# --- Round 26 ---
# {'lengthscale': tensor([ 3.3777821064,  7.3619251251,  9.9316043854, 13.8048152924],
#        device='cuda:0'), 'eta': 2.974590279336553e-05, 'tau²_hat': 68452.5859375}
# Test RMSE: 1.9464
# Test RRMSE: 0.0427
# Test rmsepd_sd: 0.0426
#
# --- Round 27 ---
# {'lengthscale': tensor([ 3.3806164265,  7.3631672859,  9.9318275452, 13.7649326324],
#        device='cuda:0'), 'eta': 2.9708595320698805e-05, 'tau²_hat': 71921.3125}
# Test RMSE: 1.8481
# Test RRMSE: 0.0405
# Test rmsepd_sd: 0.0405
#
# --- Round 28 ---
# {'lengthscale': tensor([ 3.3824601173,  7.3640851974,  9.9323358536, 13.7448225021],
#        device='cuda:0'), 'eta': 2.968993067042902e-05, 'tau²_hat': 66166.0234375}
# Test RMSE: 1.8279
# Test RRMSE: 0.0401
# Test rmsepd_sd: 0.0401
#
# --- Round 29 ---
# {'lengthscale': tensor([ 3.3881270885,  7.3667383194,  9.9332818985, 13.6741065979],
#        device='cuda:0'), 'eta': 2.962131839012727e-05, 'tau²_hat': 58640.1015625}
# Test RMSE: 1.7325
# Test RRMSE: 0.0380
# Test rmsepd_sd: 0.0380
#
# --- Round 30 ---
# {'lengthscale': tensor([ 3.3881397247,  7.3667454720,  9.9332818985, 13.6739444733],
#        device='cuda:0'), 'eta': 2.962114922411274e-05, 'tau²_hat': 51660.1015625}
# Test RMSE: 1.7652
# Test RRMSE: 0.0387
# Test rmsepd_sd: 0.0387
#
# --- Round 31 ---
# {'lengthscale': tensor([ 3.3881452084,  7.3667488098,  9.9332818985, 13.6738786697],
#        device='cuda:0'), 'eta': 2.9621091016451828e-05, 'tau²_hat': 53147.1015625}
# Test RMSE: 1.7899
# Test RRMSE: 0.0392
# Test rmsepd_sd: 0.0392
#
# --- Round 32 ---
# {'lengthscale': tensor([ 3.3897082806,  7.3676557541,  9.9331808090, 13.6568069458],
#        device='cuda:0'), 'eta': 2.9604965675389394e-05, 'tau²_hat': 54535.33203125}
# Test RMSE: 1.7650
# Test RRMSE: 0.0387
# Test rmsepd_sd: 0.0387
#
# --- Round 33 ---
# {'lengthscale': tensor([ 3.3897180557,  7.3676614761,  9.9331808090, 13.6566953659],
#        device='cuda:0'), 'eta': 2.9604852898046374e-05, 'tau²_hat': 50677.0390625}
# Test RMSE: 1.7558
# Test RRMSE: 0.0385
# Test rmsepd_sd: 0.0385
#
# --- Round 34 ---
# {'lengthscale': tensor([ 3.3897273540,  7.3676667213,  9.9331808090, 13.6565914154],
#        device='cuda:0'), 'eta': 2.9604740120703354e-05, 'tau²_hat': 50636.65625}
# Test RMSE: 1.7583
# Test RRMSE: 0.0385
# Test rmsepd_sd: 0.0385
#
# --- Round 35 ---
# {'lengthscale': tensor([ 3.3950772285,  7.3705787659,  9.9337148666, 13.6036443710],
#        device='cuda:0'), 'eta': 2.9554585125879385e-05, 'tau²_hat': 49931.03515625}
# Test RMSE: 1.7068
# Test RRMSE: 0.0374
# Test rmsepd_sd: 0.0374
#
# --- Round 36 ---
# {'lengthscale': tensor([ 3.3966014385,  7.3713278770,  9.9341030121, 13.5895175934],
#        device='cuda:0'), 'eta': 2.9541535695898347e-05, 'tau²_hat': 48238.96484375}
# Test RMSE: 1.6774
# Test RRMSE: 0.0368
# Test rmsepd_sd: 0.0368
#
# --- Round 37 ---
# {'lengthscale': tensor([ 3.3966114521,  7.3713321686,  9.9341030121, 13.5893945694],
#        device='cuda:0'), 'eta': 2.954142473754473e-05, 'tau²_hat': 45322.9609375}
# Test RMSE: 1.6832
# Test RRMSE: 0.0369
# Test rmsepd_sd: 0.0369
#
# --- Round 38 ---
# {'lengthscale': tensor([ 3.4017097950,  7.3737621307,  9.9345026016, 13.5275707245],
#        device='cuda:0'), 'eta': 2.9481449018931016e-05, 'tau²_hat': 45625.8671875}
# Test RMSE: 1.6916
# Test RRMSE: 0.0371
# Test rmsepd_sd: 0.0371
#
# --- Round 39 ---
# {'lengthscale': tensor([ 3.4017105103,  7.3737626076,  9.9345026016, 13.5275611877],
#        device='cuda:0'), 'eta': 2.9481449018931016e-05, 'tau²_hat': 42748.82421875}
# Test RMSE: 1.6917
# Test RRMSE: 0.0371
# Test rmsepd_sd: 0.0371
#
# --- Round 40 ---
# {'lengthscale': tensor([ 3.4017159939,  7.3737659454,  9.9345026016, 13.5275039673],
#        device='cuda:0'), 'eta': 2.948139444924891e-05, 'tau²_hat': 44369.1171875}
# Test RMSE: 1.6942
# Test RRMSE: 0.0371
# Test rmsepd_sd: 0.0371
#
# --- Round 41 ---
# {'lengthscale': tensor([ 3.4017214775,  7.3737688065,  9.9345026016, 13.5274391174],
#        device='cuda:0'), 'eta': 2.94813380605774e-05, 'tau²_hat': 44149.41796875}
# Test RMSE: 1.6924
# Test RRMSE: 0.0371
# Test rmsepd_sd: 0.0371
#
# --- Round 42 ---
# {'lengthscale': tensor([ 3.4017262459,  7.3737721443,  9.9345026016, 13.5273838043],
#        device='cuda:0'), 'eta': 2.948128167190589e-05, 'tau²_hat': 44847.49609375}
# Test RMSE: 1.6922
# Test RRMSE: 0.0371
# Test rmsepd_sd: 0.0371
#
# --- Round 43 ---
# {'lengthscale': tensor([ 3.4017262459,  7.3737721443,  9.9345026016, 13.5273838043],
#        device='cuda:0'), 'eta': 2.948128167190589e-05, 'tau²_hat': 44421.203125}
# Test RMSE: 1.6474
# Test RRMSE: 0.0361
# Test rmsepd_sd: 0.0361
#
# --- Round 44 ---
# {'lengthscale': tensor([ 3.4031026363,  7.3745708466,  9.9349832535, 13.5130262375],
#        device='cuda:0'), 'eta': 2.9469081709976308e-05, 'tau²_hat': 48743.515625}
# Test RMSE: 1.5752
# Test RRMSE: 0.0345
# Test rmsepd_sd: 0.0345
#
# --- Round 45 ---
# {'lengthscale': tensor([ 3.4055626392,  7.3757576942,  9.9358978271, 13.4822101593],
#        device='cuda:0'), 'eta': 2.944247898994945e-05, 'tau²_hat': 46464.66796875}
# Test RMSE: 1.5323
# Test RRMSE: 0.0336
# Test rmsepd_sd: 0.0336
#
# --- Round 46 ---
# {'lengthscale': tensor([ 3.4072787762,  7.3762803078,  9.9364976883, 13.4592437744],
#        device='cuda:0'), 'eta': 2.9420416467473842e-05, 'tau²_hat': 44497.31640625}
# Test RMSE: 1.5294
# Test RRMSE: 0.0335
# Test rmsepd_sd: 0.0335
#
# --- Round 47 ---
# {'lengthscale': tensor([ 3.4072864056,  7.3762822151,  9.9364995956, 13.4591445923],
#        device='cuda:0'), 'eta': 2.9420334612950683e-05, 'tau²_hat': 41561.4453125}
# Test RMSE: 1.5301
# Test RRMSE: 0.0335
# Test rmsepd_sd: 0.0335
#
# --- Round 48 ---
# {'lengthscale': tensor([ 3.4072966576,  7.3762845993,  9.9365043640, 13.4589996338],
#        device='cuda:0'), 'eta': 2.942022001661826e-05, 'tau²_hat': 44596.41015625}
# Test RMSE: 1.5222
# Test RRMSE: 0.0334
# Test rmsepd_sd: 0.0334
#
# --- Round 49 ---
# {'lengthscale': tensor([ 3.4073016644,  7.3762850761,  9.9365062714, 13.4589319229],
#        device='cuda:0'), 'eta': 2.942016362794675e-05, 'tau²_hat': 44202.72265625}
# Test RMSE: 1.5049
# Test RRMSE: 0.0330
# Test rmsepd_sd: 0.0330
#
# --- Round 50 ---
# {'lengthscale': tensor([ 3.4083659649,  7.3765964508,  9.9369974136, 13.4458599091],
#        device='cuda:0'), 'eta': 2.9408440241240896e-05, 'tau²_hat': 43842.67578125}
# Test RMSE: 1.4944
# Test RRMSE: 0.0328
# Test rmsepd_sd: 0.0327
#
# --- Round 51 ---
# {'lengthscale': tensor([ 3.4105217457,  7.3773012161,  9.9379682541, 13.4192390442],
#        device='cuda:0'), 'eta': 2.9383769287960604e-05, 'tau²_hat': 42135.80078125}
# Test RMSE: 1.4975
# Test RRMSE: 0.0328
# Test rmsepd_sd: 0.0328
#
# --- Round 52 ---
# {'lengthscale': tensor([ 3.4125092030,  7.3773312569,  9.9387884140, 13.3920984268],
#        device='cuda:0'), 'eta': 2.9357244784478098e-05, 'tau²_hat': 40602.72265625}
# Test RMSE: 1.4620
# Test RRMSE: 0.0321
# Test rmsepd_sd: 0.0320
#
# --- Round 53 ---
# {'lengthscale': tensor([ 3.4125092030,  7.3773312569,  9.9387884140, 13.3920984268],
#        device='cuda:0'), 'eta': 2.9357244784478098e-05, 'tau²_hat': 38357.1171875}
# Test RMSE: 1.4642
# Test RRMSE: 0.0321
# Test rmsepd_sd: 0.0321
#
# --- Round 54 ---
# {'lengthscale': tensor([ 3.4125094414,  7.3773312569,  9.9387884140, 13.3920955658],
#        device='cuda:0'), 'eta': 2.9357244784478098e-05, 'tau²_hat': 38141.03125}
# Test RMSE: 1.4673
# Test RRMSE: 0.0322
# Test rmsepd_sd: 0.0322
#
# --- Round 55 ---
# {'lengthscale': tensor([ 3.4125161171,  7.3773326874,  9.9387903214, 13.3920154572],
#        device='cuda:0'), 'eta': 2.9357161110965535e-05, 'tau²_hat': 38799.63671875}
# Test RMSE: 1.4773
# Test RRMSE: 0.0324
# Test rmsepd_sd: 0.0324
#
# --- Round 56 ---
# {'lengthscale': tensor([ 3.4125161171,  7.3773326874,  9.9387903214, 13.3920154572],
#        device='cuda:0'), 'eta': 2.9357161110965535e-05, 'tau²_hat': 38933.06640625}
# Test RMSE: 1.4785
# Test RRMSE: 0.0324
# Test rmsepd_sd: 0.0324
#
# --- Round 57 ---
# {'lengthscale': tensor([ 3.4125225544,  7.3773341179,  9.9387931824, 13.3919382095],
#        device='cuda:0'), 'eta': 2.935707561846357e-05, 'tau²_hat': 38617.640625}
# Test RMSE: 1.4689
# Test RRMSE: 0.0322
# Test rmsepd_sd: 0.0322
#
# --- Round 58 ---
# {'lengthscale': tensor([ 3.4125285149,  7.3773355484,  9.9387960434, 13.3918647766],
#        device='cuda:0'), 'eta': 2.935701922979206e-05, 'tau²_hat': 38026.6328125}
# Test RMSE: 1.4769
# Test RRMSE: 0.0324
# Test rmsepd_sd: 0.0324
#
# --- Round 59 ---
# {'lengthscale': tensor([ 3.4127333164,  7.3773555756,  9.9388599396, 13.3892183304],
#        device='cuda:0'), 'eta': 2.9354499929468147e-05, 'tau²_hat': 37770.890625}
# Test RMSE: 1.4638
# Test RRMSE: 0.0321
# Test rmsepd_sd: 0.0321
#
# --- Round 60 ---
# {'lengthscale': tensor([ 3.4143917561,  7.3775186539,  9.9394092560, 13.3676910400],
#        device='cuda:0'), 'eta': 2.9333372367545962e-05, 'tau²_hat': 37784.703125}
# Test RMSE: 1.4600
# Test RRMSE: 0.0320
# Test rmsepd_sd: 0.0320
#
# --- Round 61 ---
# {'lengthscale': tensor([ 3.4169833660,  7.3774428368,  9.9404659271, 13.3340902328],
#        device='cuda:0'), 'eta': 2.930015580204781e-05, 'tau²_hat': 35949.34375}
# Test RMSE: 1.4094
# Test RRMSE: 0.0309
# Test rmsepd_sd: 0.0309
#
# --- Round 62 ---
# {'lengthscale': tensor([ 3.4169840813,  7.3774428368,  9.9404659271, 13.3340806961],
#        device='cuda:0'), 'eta': 2.930015580204781e-05, 'tau²_hat': 35346.4453125}
# Test RMSE: 1.4120
# Test RRMSE: 0.0310
# Test rmsepd_sd: 0.0309
#
# --- Round 63 ---
# {'lengthscale': tensor([ 3.4177768230,  7.3775219917,  9.9406509399, 13.3189449310],
#        device='cuda:0'), 'eta': 2.9285240088938735e-05, 'tau²_hat': 35155.26953125}
# Test RMSE: 1.3945
# Test RRMSE: 0.0306
# Test rmsepd_sd: 0.0306
#
# --- Round 64 ---
# {'lengthscale': tensor([ 3.4188725948,  7.3771848679,  9.9409379959, 13.2974662781],
#        device='cuda:0'), 'eta': 2.9262431780807674e-05, 'tau²_hat': 34560.16015625}
# Test RMSE: 1.3910
# Test RRMSE: 0.0305
# Test rmsepd_sd: 0.0305
#
# --- Round 65 ---
# {'lengthscale': tensor([ 3.4194819927,  7.3771429062,  9.9410943985, 13.2863206863],
#        device='cuda:0'), 'eta': 2.9250879379105754e-05, 'tau²_hat': 33606.6328125}
# Test RMSE: 1.3805
# Test RRMSE: 0.0303
# Test rmsepd_sd: 0.0302
#
# --- Round 66 ---
# {'lengthscale': tensor([ 3.4194912910,  7.3771414757,  9.9410963058, 13.2861471176],
#        device='cuda:0'), 'eta': 2.9250684747239575e-05, 'tau²_hat': 32133.337890625}
# Test RMSE: 1.3803
# Test RRMSE: 0.0303
# Test rmsepd_sd: 0.0302
#
# --- Round 67 ---
# {'lengthscale': tensor([ 3.4194974899,  7.3771409988,  9.9410982132, 13.2860393524],
#        device='cuda:0'), 'eta': 2.9250571969896555e-05, 'tau²_hat': 32019.974609375}
# Test RMSE: 1.3886
# Test RRMSE: 0.0304
# Test rmsepd_sd: 0.0304
#
# --- Round 68 ---
# {'lengthscale': tensor([ 3.4194974899,  7.3771409988,  9.9410982132, 13.2860364914],
#        device='cuda:0'), 'eta': 2.9250571969896555e-05, 'tau²_hat': 31859.61328125}
# Test RMSE: 1.3929
# Test RRMSE: 0.0305
# Test rmsepd_sd: 0.0305
#
# --- Round 69 ---
# {'lengthscale': tensor([ 3.4201722145,  7.3771171570,  9.9412460327, 13.2731409073],
#        device='cuda:0'), 'eta': 2.9237102353363298e-05, 'tau²_hat': 32599.80078125}
# Test RMSE: 1.3754
# Test RRMSE: 0.0302
# Test rmsepd_sd: 0.0301
#
# --- Round 70 ---
# {'lengthscale': tensor([ 3.4201734066,  7.3771171570,  9.9412460327, 13.2731122971],
#        device='cuda:0'), 'eta': 2.923707324953284e-05, 'tau²_hat': 31036.859375}
# Test RMSE: 1.3816
# Test RRMSE: 0.0303
# Test rmsepd_sd: 0.0303
#
# --- Round 71 ---
# {'lengthscale': tensor([ 3.4253790379,  7.3761377335,  9.9422740936, 13.1656951904],
#        device='cuda:0'), 'eta': 2.912425588874612e-05, 'tau²_hat': 31079.609375}
# Test RMSE: 1.3263
# Test RRMSE: 0.0291
# Test rmsepd_sd: 0.0291
#
# --- Round 72 ---
# {'lengthscale': tensor([ 3.4253852367,  7.3761382103,  9.9422740936, 13.1655788422],
#        device='cuda:0'), 'eta': 2.912411764555145e-05, 'tau²_hat': 28106.798828125}
# Test RMSE: 1.3201
# Test RRMSE: 0.0289
# Test rmsepd_sd: 0.0289
#
# --- Round 73 ---
# {'lengthscale': tensor([ 3.4253888130,  7.3761396408,  9.9422740936, 13.1655101776],
#        device='cuda:0'), 'eta': 2.9124032153049484e-05, 'tau²_hat': 27813.220703125}
# Test RMSE: 1.3210
# Test RRMSE: 0.0290
# Test rmsepd_sd: 0.0289
#
# --- Round 74 ---
# {'lengthscale': tensor([ 3.4260578156,  7.3762984276,  9.9424314499, 13.1525430679],
#        device='cuda:0'), 'eta': 2.9110622563166544e-05, 'tau²_hat': 27678.8203125}
# Test RMSE: 1.3029
# Test RRMSE: 0.0286
# Test rmsepd_sd: 0.0285
#
# --- Round 75 ---
# {'lengthscale': tensor([ 3.4260632992,  7.3762989044,  9.9424314499, 13.1524391174],
#        device='cuda:0'), 'eta': 2.9110511604812928e-05, 'tau²_hat': 26194.0390625}
# Test RMSE: 1.3002
# Test RRMSE: 0.0285
# Test rmsepd_sd: 0.0285
#
# --- Round 76 ---
# {'lengthscale': tensor([ 3.4260692596,  7.3763003349,  9.9424314499, 13.1523265839],
#        device='cuda:0'), 'eta': 2.911040064645931e-05, 'tau²_hat': 26397.59375}
# Test RMSE: 1.2939
# Test RRMSE: 0.0284
# Test rmsepd_sd: 0.0284
#
# --- Round 77 ---
# {'lengthscale': tensor([ 3.4260740280,  7.3763003349,  9.9424314499, 13.1522350311],
#        device='cuda:0'), 'eta': 2.9110316972946748e-05, 'tau²_hat': 26747.67578125}
# Test RMSE: 1.2863
# Test RRMSE: 0.0282
# Test rmsepd_sd: 0.0282
#
# --- Round 78 ---
# {'lengthscale': tensor([ 3.4260740280,  7.3763003349,  9.9424314499, 13.1522350311],
#        device='cuda:0'), 'eta': 2.9110316972946748e-05, 'tau²_hat': 26790.736328125}
# Test RMSE: 1.2941
# Test RRMSE: 0.0284
# Test rmsepd_sd: 0.0284
#
# --- Round 79 ---
# {'lengthscale': tensor([ 3.4267323017,  7.3763437271,  9.9425086975, 13.1412277222],
#        device='cuda:0'), 'eta': 2.9098464437993243e-05, 'tau²_hat': 27541.796875}
# Test RMSE: 1.3032
# Test RRMSE: 0.0286
# Test rmsepd_sd: 0.0286
#
# --- Round 80 ---
# {'lengthscale': tensor([ 3.4267387390,  7.3763442039,  9.9425086975, 13.1410999298],
#        device='cuda:0'), 'eta': 2.9098326194798574e-05, 'tau²_hat': 26581.724609375}
# Test RMSE: 1.3205
# Test RRMSE: 0.0289
# Test rmsepd_sd: 0.0289
#
# --- Round 81 ---
# {'lengthscale': tensor([ 3.4273707867,  7.3764300346,  9.9425382614, 13.1283473969],
#        device='cuda:0'), 'eta': 2.9084731067996472e-05, 'tau²_hat': 26784.2109375}
# Test RMSE: 1.2912
# Test RRMSE: 0.0283
# Test rmsepd_sd: 0.0283
#
# --- Round 82 ---
# {'lengthscale': tensor([ 3.4312291145,  7.3769106865,  9.9429969788, 13.0519037247],
#        device='cuda:0'), 'eta': 2.9004542739130557e-05, 'tau²_hat': 26130.5703125}
# Test RMSE: 1.3144
# Test RRMSE: 0.0288
# Test rmsepd_sd: 0.0288
#
# --- Round 83 ---
# {'lengthscale': tensor([ 3.4320924282,  7.3770098686,  9.9431800842, 13.0381774902],
#        device='cuda:0'), 'eta': 2.898971979448106e-05, 'tau²_hat': 25499.318359375}
# Test RMSE: 1.2484
# Test RRMSE: 0.0274
# Test rmsepd_sd: 0.0274
#
# --- Round 84 ---
# {'lengthscale': tensor([ 3.4321253300,  7.3770151138,  9.9431896210, 13.0376501083],
#        device='cuda:0'), 'eta': 2.8989166821702383e-05, 'tau²_hat': 26452.796875}
# Test RMSE: 1.2634
# Test RRMSE: 0.0277
# Test rmsepd_sd: 0.0277
#
# --- Round 85 ---
# {'lengthscale': tensor([ 3.4328029156,  7.3771195412,  9.9433870316, 13.0272092819],
#        device='cuda:0'), 'eta': 2.8978329282836057e-05, 'tau²_hat': 26688.3046875}
# Test RMSE: 1.2706
# Test RRMSE: 0.0279
# Test rmsepd_sd: 0.0278
#
# --- Round 86 ---
# {'lengthscale': tensor([ 3.4342205524,  7.3773121834,  9.9437751770, 13.0055322647],
#        device='cuda:0'), 'eta': 2.895479519793298e-05, 'tau²_hat': 26045.27734375}
# Test RMSE: 1.2682
# Test RRMSE: 0.0278
# Test rmsepd_sd: 0.0278
#
# --- Round 87 ---
# {'lengthscale': tensor([ 3.4348030090,  7.3773565292,  9.9439506531, 12.9960823059],
#        device='cuda:0'), 'eta': 2.8944772566319443e-05, 'tau²_hat': 26047.267578125}
# Test RMSE: 1.2704
# Test RRMSE: 0.0278
# Test rmsepd_sd: 0.0278
#
# --- Round 88 ---
# {'lengthscale': tensor([ 3.4348046780,  7.3773565292,  9.9439506531, 12.9960508347],
#        device='cuda:0'), 'eta': 2.894474528147839e-05, 'tau²_hat': 25592.970703125}
# Test RMSE: 1.2798
# Test RRMSE: 0.0281
# Test rmsepd_sd: 0.0280
#
# --- Round 89 ---
# {'lengthscale': tensor([ 3.4364657402,  7.3775377274,  9.9445314407, 12.9695301056],
#        device='cuda:0'), 'eta': 2.8917347663082182e-05, 'tau²_hat': 25348.787109375}
# Test RMSE: 1.2537
# Test RRMSE: 0.0275
# Test rmsepd_sd: 0.0275
#
# --- Round 90 ---
# {'lengthscale': tensor([ 3.4374511242,  7.3776512146,  9.9448680878, 12.9548692703],
#        device='cuda:0'), 'eta': 2.8901798941660672e-05, 'tau²_hat': 24872.568359375}
# Test RMSE: 1.2614
# Test RRMSE: 0.0277
# Test rmsepd_sd: 0.0276
#
# --- Round 91 ---
# {'lengthscale': tensor([ 3.4374575615,  7.3776516914,  9.9448709488, 12.9547729492],
#        device='cuda:0'), 'eta': 2.8901687983307056e-05, 'tau²_hat': 24631.072265625}
# Test RMSE: 1.2617
# Test RRMSE: 0.0277
# Test rmsepd_sd: 0.0276
#
# --- Round 92 ---
# {'lengthscale': tensor([ 3.4380440712,  7.3777651787,  9.9450960159, 12.9463195801],
#        device='cuda:0'), 'eta': 2.8892787668155506e-05, 'tau²_hat': 25061.701171875}
# Test RMSE: 1.2541
# Test RRMSE: 0.0275
# Test rmsepd_sd: 0.0275
#
# --- Round 93 ---
# {'lengthscale': tensor([ 3.4380512238,  7.3777670860,  9.9450979233, 12.9462118149],
#        device='cuda:0'), 'eta': 2.8892674890812486e-05, 'tau²_hat': 24548.111328125}
# Test RMSE: 1.2717
# Test RRMSE: 0.0279
# Test rmsepd_sd: 0.0279
#
# --- Round 94 ---
# {'lengthscale': tensor([ 3.4380593300,  7.3777680397,  9.9451007843, 12.9460916519],
#        device='cuda:0'), 'eta': 2.889253846660722e-05, 'tau²_hat': 24608.048828125}
# Test RMSE: 1.2765
# Test RRMSE: 0.0280
# Test rmsepd_sd: 0.0280
#
# --- Round 95 ---
# {'lengthscale': tensor([ 3.4387609959,  7.3778929710,  9.9453706741, 12.9356002808],
#        device='cuda:0'), 'eta': 2.8881353500764817e-05, 'tau²_hat': 24404.77734375}
# Test RMSE: 1.2689
# Test RRMSE: 0.0278
# Test rmsepd_sd: 0.0278
#
# --- Round 96 ---
# {'lengthscale': tensor([ 3.4405019283,  7.3781752586,  9.9460468292, 12.9103765488],
#        device='cuda:0'), 'eta': 2.8854483389295638e-05, 'tau²_hat': 23855.310546875}
# Test RMSE: 1.2425
# Test RRMSE: 0.0272
# Test rmsepd_sd: 0.0272
#
# --- Round 97 ---
# {'lengthscale': tensor([ 3.4405407906,  7.3781819344,  9.9460601807, 12.9098072052],
#        device='cuda:0'), 'eta': 2.8853877665824257e-05, 'tau²_hat': 23211.21875}
# Test RMSE: 1.2453
# Test RRMSE: 0.0273
# Test rmsepd_sd: 0.0273
#
# --- Round 98 ---
# {'lengthscale': tensor([ 3.4405481815,  7.3781838417,  9.9460630417, 12.9096956253],
#        device='cuda:0'), 'eta': 2.8853768526460044e-05, 'tau²_hat': 23361.2578125}
# Test RMSE: 1.2348
# Test RRMSE: 0.0271
# Test rmsepd_sd: 0.0271
#
# --- Round 99 ---
# {'lengthscale': tensor([ 3.4405541420,  7.3781852722,  9.9460649490, 12.9096126556],
#        device='cuda:0'), 'eta': 2.8853686671936885e-05, 'tau²_hat': 23808.041015625}
# Test RMSE: 1.2426
# Test RRMSE: 0.0272
# Test rmsepd_sd: 0.0272
#
# --- Round 100 ---
# {'lengthscale': tensor([ 3.4405581951,  7.3781857491,  9.9460678101, 12.9095535278],
#        device='cuda:0'), 'eta': 2.8853630283265375e-05, 'tau²_hat': 23764.6171875}
# Test RMSE: 1.2471
# Test RRMSE: 0.0273
# Test rmsepd_sd: 0.0273
#
# --- Round 101 ---
# {'lengthscale': tensor([ 3.4405627251,  7.3781862259,  9.9460706711, 12.9094867706],
#        device='cuda:0'), 'eta': 2.8853548428742215e-05, 'tau²_hat': 24140.701171875}
# Test RMSE: 1.2456
# Test RRMSE: 0.0273
# Test rmsepd_sd: 0.0273
#
# --- Round 102 ---
# {'lengthscale': tensor([ 3.4405672550,  7.3781876564,  9.9460725784, 12.9094219208],
#        device='cuda:0'), 'eta': 2.885349385906011e-05, 'tau²_hat': 23956.310546875}
# Test RMSE: 1.2520
# Test RRMSE: 0.0274
# Test rmsepd_sd: 0.0274
#
# --- Round 103 ---
# {'lengthscale': tensor([ 3.4405703545,  7.3781881332,  9.9460725784, 12.9093694687],
#        device='cuda:0'), 'eta': 2.8853439289378002e-05, 'tau²_hat': 23935.69140625}
# Test RMSE: 1.2494
# Test RRMSE: 0.0274
# Test rmsepd_sd: 0.0274
#
# --- Round 104 ---
# {'lengthscale': tensor([ 3.4405736923,  7.3781895638,  9.9460725784, 12.9093112946],
#        device='cuda:0'), 'eta': 2.8853384719695896e-05, 'tau²_hat': 25676.431640625}
# Test RMSE: 1.2462
# Test RRMSE: 0.0273
# Test rmsepd_sd: 0.0273
#
# --- Round 105 ---
# {'lengthscale': tensor([ 3.4406731129,  7.3782114983,  9.9460964203, 12.9075574875],
#        device='cuda:0'), 'eta': 2.8851594834122807e-05, 'tau²_hat': 25613.70703125}
# Test RMSE: 1.2499
# Test RRMSE: 0.0274
# Test rmsepd_sd: 0.0274
#
# --- Round 106 ---
# {'lengthscale': tensor([ 3.4412789345,  7.3783483505,  9.9462652206, 12.8976669312],
#        device='cuda:0'), 'eta': 2.884138848457951e-05, 'tau²_hat': 24834.224609375}
# Test RMSE: 1.2446
# Test RRMSE: 0.0273
# Test rmsepd_sd: 0.0273
#
# --- Round 107 ---
# {'lengthscale': tensor([ 3.4412884712,  7.3783502579,  9.9462671280, 12.8975248337],
#        device='cuda:0'), 'eta': 2.884122295654379e-05, 'tau²_hat': 24034.103515625}
# Test RMSE: 1.2420
# Test RRMSE: 0.0272
# Test rmsepd_sd: 0.0272
#
# --- Round 108 ---
# {'lengthscale': tensor([ 3.4424011707,  7.3785629272,  9.9466419220, 12.8813266754],
#        device='cuda:0'), 'eta': 2.8824286346207373e-05, 'tau²_hat': 23907.236328125}
# Test RMSE: 1.2360
# Test RRMSE: 0.0271
# Test rmsepd_sd: 0.0271
#
# --- Round 109 ---
# {'lengthscale': tensor([ 3.4431006908,  7.3786916733,  9.9468526840, 12.8706960678],
#        device='cuda:0'), 'eta': 2.8812715754611418e-05, 'tau²_hat': 23594.994140625}
# Test RMSE: 1.2238
# Test RRMSE: 0.0268
# Test rmsepd_sd: 0.0268
#
# --- Round 110 ---
# {'lengthscale': tensor([ 3.4439918995,  7.3788142204,  9.9471521378, 12.8571243286],
#        device='cuda:0'), 'eta': 2.8798156563425437e-05, 'tau²_hat': 23110.357421875}
# Test RMSE: 1.1729
# Test RRMSE: 0.0257
# Test rmsepd_sd: 0.0257
#
# --- Round 111 ---
# {'lengthscale': tensor([ 3.4439964294,  7.3788161278,  9.9471540451, 12.8570575714],
#        device='cuda:0'), 'eta': 2.879810199374333e-05, 'tau²_hat': 26536.599609375}
# Test RMSE: 1.1716
# Test RRMSE: 0.0257
# Test rmsepd_sd: 0.0257
#
# --- Round 112 ---
# {'lengthscale': tensor([ 3.4439964294,  7.3788161278,  9.9471540451, 12.8570547104],
#        device='cuda:0'), 'eta': 2.879810199374333e-05, 'tau²_hat': 26510.673828125}
# Test RMSE: 1.1663
# Test RRMSE: 0.0256
# Test rmsepd_sd: 0.0256
#
# --- Round 113 ---
# {'lengthscale': tensor([ 3.4446647167,  7.3790159225,  9.9474477768, 12.8477611542],
#        device='cuda:0'), 'eta': 2.8788763302145526e-05, 'tau²_hat': 26210.60546875}
# Test RMSE: 1.1673
# Test RRMSE: 0.0256
# Test rmsepd_sd: 0.0256
#
# --- Round 114 ---
# {'lengthscale': tensor([ 3.4452314377,  7.3791570663,  9.9477119446, 12.8392543793],
#        device='cuda:0'), 'eta': 2.8779897547792643e-05, 'tau²_hat': 25824.076171875}
# Test RMSE: 1.1608
# Test RRMSE: 0.0254
# Test rmsepd_sd: 0.0254
#
# --- Round 115 ---
# {'lengthscale': tensor([ 3.4464540482,  7.3795051575,  9.9483375549, 12.8207416534],
#        device='cuda:0'), 'eta': 2.8760912755387835e-05, 'tau²_hat': 25120.072265625}
# Test RMSE: 1.1526
# Test RRMSE: 0.0253
# Test rmsepd_sd: 0.0253
#
# --- Round 116 ---
# {'lengthscale': tensor([ 3.4472212791,  7.3797020912,  9.9487123489, 12.8081607819],
#        device='cuda:0'), 'eta': 2.8747830583597533e-05, 'tau²_hat': 24707.9921875}
# Test RMSE: 1.1501
# Test RRMSE: 0.0252
# Test rmsepd_sd: 0.0252
#
# --- Round 117 ---
# {'lengthscale': tensor([ 3.4472308159,  7.3797049522,  9.9487171173, 12.8080053329],
#        device='cuda:0'), 'eta': 2.8747666874551214e-05, 'tau²_hat': 24121.501953125}
# Test RMSE: 1.1533
# Test RRMSE: 0.0253
# Test rmsepd_sd: 0.0253
#
# --- Round 118 ---
# {'lengthscale': tensor([ 3.4621922970,  7.3836693764,  9.9557666779, 12.5550498962],
#        device='cuda:0'), 'eta': 2.8484344511525705e-05, 'tau²_hat': 23909.892578125}
# Test RMSE: 1.1262
# Test RRMSE: 0.0247
# Test rmsepd_sd: 0.0247
#
# --- Round 119 ---
# {'lengthscale': tensor([ 3.4631574154,  7.3838362694,  9.9565877914, 12.5249547958],
#        device='cuda:0'), 'eta': 2.845227936632e-05, 'tau²_hat': 20682.015625}
# Test RMSE: 1.0747
# Test RRMSE: 0.0236
# Test rmsepd_sd: 0.0235
#
# --- Round 120 ---
# {'lengthscale': tensor([ 3.4635760784,  7.3839392662,  9.9568700790, 12.5146055222],
#        device='cuda:0'), 'eta': 2.8441263566492125e-05, 'tau²_hat': 19084.23046875}
# Test RMSE: 1.0875
# Test RRMSE: 0.0238
# Test rmsepd_sd: 0.0238
#
# --- Round 121 ---
# {'lengthscale': tensor([ 3.4640772343,  7.3840532303,  9.9571723938, 12.5032310486],
#        device='cuda:0'), 'eta': 2.842879075615201e-05, 'tau²_hat': 18876.96484375}
# Test RMSE: 1.0771
# Test RRMSE: 0.0236
# Test rmsepd_sd: 0.0236
#
# --- Round 122 ---
# {'lengthscale': tensor([ 3.4645493031,  7.3841485977,  9.9574518204, 12.4922008514],
#        device='cuda:0'), 'eta': 2.84167290374171e-05, 'tau²_hat': 18718.8359375}
# Test RMSE: 1.0755
# Test RRMSE: 0.0236
# Test rmsepd_sd: 0.0236
#
# --- Round 123 ---
# {'lengthscale': tensor([ 3.4645557404,  7.3841500282,  9.9574565887, 12.4920520782],
#        device='cuda:0'), 'eta': 2.8416567147360183e-05, 'tau²_hat': 18403.1328125}
# Test RMSE: 1.0733
# Test RRMSE: 0.0235
# Test rmsepd_sd: 0.0235
#
# --- Round 124 ---
# {'lengthscale': tensor([ 3.4645631313,  7.3841514587,  9.9574613571, 12.4918823242],
#        device='cuda:0'), 'eta': 2.841637615347281e-05, 'tau²_hat': 18418.935546875}
# Test RMSE: 1.0805
# Test RRMSE: 0.0237
# Test rmsepd_sd: 0.0237
#
# --- Round 125 ---
# {'lengthscale': tensor([ 3.4645681381,  7.3841528893,  9.9574642181, 12.4917669296],
#        device='cuda:0'), 'eta': 2.8416239729267545e-05, 'tau²_hat': 18354.298828125}
# Test RMSE: 1.0700
# Test RRMSE: 0.0235
# Test rmsepd_sd: 0.0234
#
# --- Round 126 ---
# {'lengthscale': tensor([ 3.4649152756,  7.3842177391,  9.9576520920, 12.4832773209],
#        device='cuda:0'), 'eta': 2.8406891942722723e-05, 'tau²_hat': 18556.54296875}
# Test RMSE: 1.0797
# Test RRMSE: 0.0237
# Test rmsepd_sd: 0.0237
#
# --- Round 127 ---
# {'lengthscale': tensor([ 3.4653332233,  7.3842759132,  9.9579029083, 12.4726190567],
#        device='cuda:0'), 'eta': 2.8395434128469788e-05, 'tau²_hat': 18429.41015625}
# Test RMSE: 1.0689
# Test RRMSE: 0.0234
# Test rmsepd_sd: 0.0234
#
# --- Round 128 ---
# {'lengthscale': tensor([ 3.4653403759,  7.3842763901,  9.9579076767, 12.4724464417],
#        device='cuda:0'), 'eta': 2.8395246772561222e-05, 'tau²_hat': 18312.716796875}
# Test RMSE: 1.0700
# Test RRMSE: 0.0235
# Test rmsepd_sd: 0.0234
#
# --- Round 129 ---
# {'lengthscale': tensor([ 3.4657919407,  7.3843517303,  9.9581689835, 12.4616689682],
#        device='cuda:0'), 'eta': 2.8383306926116347e-05, 'tau²_hat': 18190.7578125}
# Test RMSE: 1.0725
# Test RRMSE: 0.0235
# Test rmsepd_sd: 0.0235
#
# --- Round 130 ---
# {'lengthscale': tensor([ 3.4657919407,  7.3843517303,  9.9581689835, 12.4616689682],
#        device='cuda:0'), 'eta': 2.8383306926116347e-05, 'tau²_hat': 18166.501953125}
# Test RMSE: 1.0704
# Test RRMSE: 0.0235
# Test rmsepd_sd: 0.0235
#
# --- Round 131 ---
# {'lengthscale': tensor([ 3.4658017159,  7.3843536377,  9.9581737518, 12.4614429474],
#        device='cuda:0'), 'eta': 2.8383063181536272e-05, 'tau²_hat': 18079.056640625}
# Test RMSE: 1.0719
# Test RRMSE: 0.0235
# Test rmsepd_sd: 0.0235
#
# --- Round 132 ---
# {'lengthscale': tensor([ 3.4658091068,  7.3843555450,  9.9581785202, 12.4612703323],
#        device='cuda:0'), 'eta': 2.83828721876489e-05, 'tau²_hat': 18010.123046875}
# Test RMSE: 1.0787
# Test RRMSE: 0.0236
# Test rmsepd_sd: 0.0236
#
# --- Round 133 ---
# {'lengthscale': tensor([ 3.4658162594,  7.3843569756,  9.9581832886, 12.4611158371],
#        device='cuda:0'), 'eta': 2.8382712116581388e-05, 'tau²_hat': 18051.599609375}
# Test RMSE: 1.0831
# Test RRMSE: 0.0237
# Test rmsepd_sd: 0.0237
#
# --- Round 134 ---
# {'lengthscale': tensor([ 3.4658164978,  7.3843569756,  9.9581832886, 12.4611101151],
#        device='cuda:0'), 'eta': 2.8382712116581388e-05, 'tau²_hat': 17992.626953125}
# Test RMSE: 1.0862
# Test RRMSE: 0.0238
# Test rmsepd_sd: 0.0238
#
# --- Round 135 ---
# {'lengthscale': tensor([ 3.4658219814,  7.3843574524,  9.9581861496, 12.4609909058],
#        device='cuda:0'), 'eta': 2.8382575692376122e-05, 'tau²_hat': 17990.83203125}
# Test RMSE: 1.0956
# Test RRMSE: 0.0240
# Test rmsepd_sd: 0.0240
#
# --- Round 136 ---
# {'lengthscale': tensor([ 3.4658284187,  7.3843593597,  9.9581880569, 12.4608726501],
#        device='cuda:0'), 'eta': 2.8382439268170856e-05, 'tau²_hat': 18103.595703125}
# Test RMSE: 1.0921
# Test RRMSE: 0.0239
# Test rmsepd_sd: 0.0239
#
# --- Round 137 ---
# {'lengthscale': tensor([ 3.4658343792,  7.3843612671,  9.9581909180, 12.4607563019],
#        device='cuda:0'), 'eta': 2.8382331947796047e-05, 'tau²_hat': 18068.376953125}
# Test RMSE: 1.0965
# Test RRMSE: 0.0240
# Test rmsepd_sd: 0.0240
#
# --- Round 138 ---
# {'lengthscale': tensor([ 3.4663145542,  7.3844823837,  9.9584465027, 12.4518175125],
#        device='cuda:0'), 'eta': 2.8372589440550655e-05, 'tau²_hat': 18059.8984375}
# Test RMSE: 1.0977
# Test RRMSE: 0.0241
# Test rmsepd_sd: 0.0241
#
# --- Round 139 ---
# {'lengthscale': tensor([ 3.4669022560,  7.3846254349,  9.9588079453, 12.4402208328],
#        device='cuda:0'), 'eta': 2.8359954740153626e-05, 'tau²_hat': 17789.330078125}
# Test RMSE: 1.0787
# Test RRMSE: 0.0236
# Test rmsepd_sd: 0.0236
#
# --- Round 140 ---
# {'lengthscale': tensor([ 3.4709305763,  7.3855743408,  9.9611797333, 12.3592920303],
#        device='cuda:0'), 'eta': 2.827211210387759e-05, 'tau²_hat': 17568.857421875}
# Test RMSE: 1.0545
# Test RRMSE: 0.0231
# Test rmsepd_sd: 0.0231
#
# --- Round 141 ---
# {'lengthscale': tensor([ 3.4709365368,  7.3855762482,  9.9611845016, 12.3591499329],
#        device='cuda:0'), 'eta': 2.827194839483127e-05, 'tau²_hat': 17028.22265625}
# Test RMSE: 1.0601
# Test RRMSE: 0.0232
# Test rmsepd_sd: 0.0232
#
# --- Round 142 ---
# {'lengthscale': tensor([ 3.4711885452,  7.3856124878,  9.9613647461, 12.3532609940],
#        device='cuda:0'), 'eta': 2.8265534638194367e-05, 'tau²_hat': 17784.7890625}
# Test RMSE: 1.0432
# Test RRMSE: 0.0229
# Test rmsepd_sd: 0.0229
#
# --- Round 143 ---
# {'lengthscale': tensor([ 3.4716432095,  7.3856773376,  9.9616975784, 12.3415832520],
#        device='cuda:0'), 'eta': 2.825251613103319e-05, 'tau²_hat': 17438.021484375}
# Test RMSE: 1.0297
# Test RRMSE: 0.0226
# Test rmsepd_sd: 0.0226
#
# --- Round 144 ---
# {'lengthscale': tensor([ 3.4720041752,  7.3857359886,  9.9619255066, 12.3322935104],
#        device='cuda:0'), 'eta': 2.8242253392818384e-05, 'tau²_hat': 17154.05078125}
# Test RMSE: 1.0070
# Test RRMSE: 0.0221
# Test rmsepd_sd: 0.0221
#
# --- Round 145 ---
# {'lengthscale': tensor([ 3.4720442295,  7.3857202530,  9.9619617462, 12.3305797577],
#        device='cuda:0'), 'eta': 2.8240314350114204e-05, 'tau²_hat': 17141.783203125}
# Test RMSE: 1.0101
# Test RRMSE: 0.0221
# Test rmsepd_sd: 0.0221
#
# --- Round 146 ---
# {'lengthscale': tensor([ 3.4720489979,  7.3857192993,  9.9619636536, 12.3303709030],
#        device='cuda:0'), 'eta': 2.8240097890375182e-05, 'tau²_hat': 17448.9921875}
# Test RMSE: 1.0072
# Test RRMSE: 0.0221
# Test rmsepd_sd: 0.0221
#
# --- Round 147 ---
# {'lengthscale': tensor([ 3.4722616673,  7.3856205940,  9.9621753693, 12.3203716278],
#        device='cuda:0'), 'eta': 2.822851820383221e-05, 'tau²_hat': 17199.810546875}
# Test RMSE: 0.9992
# Test RRMSE: 0.0219
# Test rmsepd_sd: 0.0219
#
# --- Round 148 ---
# {'lengthscale': tensor([ 3.4722645283,  7.3856201172,  9.9621772766, 12.3202390671],
#        device='cuda:0'), 'eta': 2.822838541760575e-05, 'tau²_hat': 17111.44140625}
# Test RMSE: 1.0006
# Test RRMSE: 0.0219
# Test rmsepd_sd: 0.0219
#
# --- Round 149 ---
# {'lengthscale': tensor([ 3.4722683430,  7.3856182098,  9.9621801376, 12.3200540543],
#        device='cuda:0'), 'eta': 2.8228168957866728e-05, 'tau²_hat': 17194.5859375}
# Test RMSE: 1.0057
# Test RRMSE: 0.0220
# Test rmsepd_sd: 0.0220
#
# --- Round 150 ---
# {'lengthscale': tensor([ 3.4722712040,  7.3856163025,  9.9621820450, 12.3199014664],
#        device='cuda:0'), 'eta': 2.8228008886799216e-05, 'tau²_hat': 17118.201171875}
# Test RMSE: 0.9941
# Test RRMSE: 0.0218
# Test rmsepd_sd: 0.0218
#
# --- Round 151 ---
# {'lengthscale': tensor([ 3.4722740650,  7.3856139183,  9.9621877670, 12.3197107315],
#        device='cuda:0'), 'eta': 2.8227794246049598e-05, 'tau²_hat': 17088.384765625}
# Test RMSE: 0.9975
# Test RRMSE: 0.0219
# Test rmsepd_sd: 0.0219
#
# --- Round 152 ---
# {'lengthscale': tensor([ 3.4722762108,  7.3856110573,  9.9621915817, 12.3195486069],
#        device='cuda:0'), 'eta': 2.822760507115163e-05, 'tau²_hat': 17053.08984375}
# Test RMSE: 0.9943
# Test RRMSE: 0.0218
# Test rmsepd_sd: 0.0218
#
# --- Round 153 ---
# {'lengthscale': tensor([ 3.4724359512,  7.3854370117,  9.9624509811, 12.3074131012],
#        device='cuda:0'), 'eta': 2.82136370515218e-05, 'tau²_hat': 16949.390625}
# Test RMSE: 1.0037
# Test RRMSE: 0.0220
# Test rmsepd_sd: 0.0220
#
# --- Round 154 ---
# {'lengthscale': tensor([ 3.4725708961,  7.3852949142,  9.9626808167, 12.2970647812],
#        device='cuda:0'), 'eta': 2.8201880923006684e-05, 'tau²_hat': 16815.37890625}
# Test RMSE: 0.9914
# Test RRMSE: 0.0217
# Test rmsepd_sd: 0.0217
#
# --- Round 155 ---
# {'lengthscale': tensor([ 3.4725730419,  7.3852925301,  9.9626836777, 12.2968978882],
#        device='cuda:0'), 'eta': 2.820169356709812e-05, 'tau²_hat': 16906.37890625}
# Test RMSE: 0.9875
# Test RRMSE: 0.0216
# Test rmsepd_sd: 0.0216
#
# --- Round 156 ---
# {'lengthscale': tensor([ 3.4725730419,  7.3852915764,  9.9626865387, 12.2968063354],
#        device='cuda:0'), 'eta': 2.8201584427733906e-05, 'tau²_hat': 16674.1953125}
# Test RMSE: 0.9737
# Test RRMSE: 0.0213
# Test rmsepd_sd: 0.0213
#
# --- Round 157 ---
# {'lengthscale': tensor([ 3.4725730419,  7.3852906227,  9.9626874924, 12.2967157364],
#        device='cuda:0'), 'eta': 2.8201477107359096e-05, 'tau²_hat': 19441.033203125}
# Test RMSE: 0.9715
# Test RRMSE: 0.0213
# Test rmsepd_sd: 0.0213
#
# --- Round 158 ---
# {'lengthscale': tensor([ 3.4725511074,  7.3851823807,  9.9628906250, 12.2873201370],
#        device='cuda:0'), 'eta': 2.819082874339074e-05, 'tau²_hat': 19381.126953125}
# Test RMSE: 0.9832
# Test RRMSE: 0.0216
# Test rmsepd_sd: 0.0215
#
# --- Round 159 ---
# {'lengthscale': tensor([ 3.4726541042,  7.3851013184,  9.9631137848, 12.2784957886],
#        device='cuda:0'), 'eta': 2.8180827939650044e-05, 'tau²_hat': 19121.529296875}
# Test RMSE: 0.9598
# Test RRMSE: 0.0210
# Test rmsepd_sd: 0.0210
#
# --- Round 160 ---
# {'lengthscale': tensor([ 3.4727330208,  7.3849821091,  9.9633064270, 12.2686882019],
#        device='cuda:0'), 'eta': 2.816954474837985e-05, 'tau²_hat': 18868.162109375}
# Test RMSE: 0.9649
# Test RRMSE: 0.0212
# Test rmsepd_sd: 0.0211
#
# --- Round 161 ---
# {'lengthscale': tensor([ 3.4728887081,  7.3848586082,  9.9636001587, 12.2566366196],
#        device='cuda:0'), 'eta': 2.8155980544397607e-05, 'tau²_hat': 18554.935546875}
# Test RMSE: 0.9505
# Test RRMSE: 0.0208
# Test rmsepd_sd: 0.0208
#
# --- Round 162 ---
# {'lengthscale': tensor([ 3.4729831219,  7.3847374916,  9.9637813568, 12.2463140488],
#        device='cuda:0'), 'eta': 2.8144328098278493e-05, 'tau²_hat': 18323.630859375}
# Test RMSE: 0.9616
# Test RRMSE: 0.0211
# Test rmsepd_sd: 0.0211
#
# --- Round 163 ---
# {'lengthscale': tensor([ 3.4729855061,  7.3847370148,  9.9637832642, 12.2462005615],
#        device='cuda:0'), 'eta': 2.8144195312052034e-05, 'tau²_hat': 18119.69921875}
# Test RMSE: 0.9606
# Test RRMSE: 0.0211
# Test rmsepd_sd: 0.0210
#
# --- Round 164 ---
# {'lengthscale': tensor([ 3.4729874134,  7.3847346306,  9.9637861252, 12.2460269928],
#        device='cuda:0'), 'eta': 2.814400795614347e-05, 'tau²_hat': 17976.44140625}
# Test RMSE: 0.9584
# Test RRMSE: 0.0210
# Test rmsepd_sd: 0.0210
#
# --- Round 165 ---
# {'lengthscale': tensor([ 3.4731185436,  7.3845996857,  9.9639854431, 12.2363414764],
#        device='cuda:0'), 'eta': 2.813311220961623e-05, 'tau²_hat': 17923.80859375}
# Test RMSE: 0.9473
# Test RRMSE: 0.0208
# Test rmsepd_sd: 0.0208
#
# --- Round 166 ---
# {'lengthscale': tensor([ 3.4732813835,  7.3844070435,  9.9642724991, 12.2220277786],
#        device='cuda:0'), 'eta': 2.8116777684772387e-05, 'tau²_hat': 17706.912109375}
# Test RMSE: 0.9489
# Test RRMSE: 0.0208
# Test rmsepd_sd: 0.0208
#
# --- Round 167 ---
# {'lengthscale': tensor([ 3.4734013081,  7.3842525482,  9.9644289017, 12.2139062881],
#        device='cuda:0'), 'eta': 2.8107608159189112e-05, 'tau²_hat': 17377.533203125}
# Test RMSE: 0.9396
# Test RRMSE: 0.0206
# Test rmsepd_sd: 0.0206
#
# --- Round 168 ---
# {'lengthscale': tensor([ 3.4734039307,  7.3842501640,  9.9644317627, 12.2137556076],
#        device='cuda:0'), 'eta': 2.81074480881216e-05, 'tau²_hat': 17491.400390625}
# Test RMSE: 0.9402
# Test RRMSE: 0.0206
# Test rmsepd_sd: 0.0206
#
# --- Round 169 ---
# {'lengthscale': tensor([ 3.4735646248,  7.3840608597,  9.9645862579, 12.2025232315],
#        device='cuda:0'), 'eta': 2.8094958906876855e-05, 'tau²_hat': 17372.400390625}
# Test RMSE: 0.9449
# Test RRMSE: 0.0207
# Test rmsepd_sd: 0.0207
#
# --- Round 170 ---
# {'lengthscale': tensor([ 3.4735672474,  7.3840589523,  9.9645891190, 12.2023916245],
#        device='cuda:0'), 'eta': 2.8094826120650396e-05, 'tau²_hat': 17238.154296875}
# Test RMSE: 0.9334
# Test RRMSE: 0.0205
# Test rmsepd_sd: 0.0205
#
# --- Round 171 ---
# {'lengthscale': tensor([ 3.4735693932,  7.3840565681,  9.9645910263, 12.2022466660],
#        device='cuda:0'), 'eta': 2.809466423059348e-05, 'tau²_hat': 17360.6875}
# Test RMSE: 0.9374
# Test RRMSE: 0.0206
# Test rmsepd_sd: 0.0205
#
# --- Round 172 ---
# {'lengthscale': tensor([ 3.4735722542,  7.3840537071,  9.9645938873, 12.2020988464],
#        device='cuda:0'), 'eta': 2.8094504159525968e-05, 'tau²_hat': 17313.447265625}
# Test RMSE: 0.9391
# Test RRMSE: 0.0206
# Test rmsepd_sd: 0.0206
#
# --- Round 173 ---
# {'lengthscale': tensor([ 3.4735722542,  7.3840537071,  9.9645938873, 12.2020988464],
#        device='cuda:0'), 'eta': 2.8094504159525968e-05, 'tau²_hat': 17430.21484375}
# Test RMSE: 0.9365
# Test RRMSE: 0.0205
# Test rmsepd_sd: 0.0205
#
# --- Round 174 ---
# {'lengthscale': tensor([ 3.4737997055,  7.3839254379,  9.9647712708, 12.1924896240],
#        device='cuda:0'), 'eta': 2.808330646075774e-05, 'tau²_hat': 17380.548828125}
# Test RMSE: 0.9368
# Test RRMSE: 0.0205
# Test rmsepd_sd: 0.0205
#
# --- Round 175 ---
# {'lengthscale': tensor([ 3.4738023281,  7.3839225769,  9.9647741318, 12.1923151016],
#        device='cuda:0'), 'eta': 2.8083119104849175e-05, 'tau²_hat': 17319.8046875}
# Test RMSE: 0.9281
# Test RRMSE: 0.0203
# Test rmsepd_sd: 0.0203
#
# --- Round 176 ---
# {'lengthscale': tensor([ 3.4738042355,  7.3839201927,  9.9647760391, 12.1921787262],
#        device='cuda:0'), 'eta': 2.8082959033781663e-05, 'tau²_hat': 17024.119140625}
# Test RMSE: 0.9253
# Test RRMSE: 0.0203
# Test rmsepd_sd: 0.0203
#
# --- Round 177 ---
# {'lengthscale': tensor([ 3.4738059044,  7.3839182854,  9.9647789001, 12.1920652390],
#        device='cuda:0'), 'eta': 2.80828244285658e-05, 'tau²_hat': 17376.544921875}
# Test RMSE: 0.9255
# Test RRMSE: 0.0203
# Test rmsepd_sd: 0.0203
#
# --- Round 178 ---
# {'lengthscale': tensor([ 3.4738080502,  7.3839163780,  9.9647808075, 12.1919345856],
#        device='cuda:0'), 'eta': 2.8082689823349938e-05, 'tau²_hat': 17246.0703125}
# Test RMSE: 0.9224
# Test RRMSE: 0.0202
# Test rmsepd_sd: 0.0202
#
# --- Round 179 ---
# {'lengthscale': tensor([ 3.4739975929,  7.3837351799,  9.9649639130, 12.1800146103],
#        device='cuda:0'), 'eta': 2.80687690974446e-05, 'tau²_hat': 17288.798828125}
# Test RMSE: 0.9307
# Test RRMSE: 0.0204
# Test rmsepd_sd: 0.0204
#
# --- Round 180 ---
# {'lengthscale': tensor([ 3.4739997387,  7.3837332726,  9.9649667740, 12.1799068451],
#        device='cuda:0'), 'eta': 2.806863449222874e-05, 'tau²_hat': 17316.8515625}
# Test RMSE: 0.9206
# Test RRMSE: 0.0202
# Test rmsepd_sd: 0.0202
#
# --- Round 181 ---
# {'lengthscale': tensor([ 3.4742655754,  7.3835940361,  9.9651775360, 12.1677713394],
#        device='cuda:0'), 'eta': 2.8054662834620103e-05, 'tau²_hat': 17135.046875}
# Test RMSE: 0.9066
# Test RRMSE: 0.0199
# Test rmsepd_sd: 0.0199
#
# --- Round 182 ---
# {'lengthscale': tensor([ 3.4743363857,  7.3835229874,  9.9652519226, 12.1633100510],
#        device='cuda:0'), 'eta': 2.804923315125052e-05, 'tau²_hat': 16972.177734375}
# Test RMSE: 0.9129
# Test RRMSE: 0.0200
# Test rmsepd_sd: 0.0200
#
# --- Round 183 ---
# {'lengthscale': tensor([ 3.4744665623,  7.3833336830,  9.9654207230, 12.1532220840],
#        device='cuda:0'), 'eta': 2.803730603773147e-05, 'tau²_hat': 16607.986328125}
# Test RMSE: 0.9055
# Test RRMSE: 0.0199
# Test rmsepd_sd: 0.0198
#
# --- Round 184 ---
# {'lengthscale': tensor([ 3.4744694233,  7.3833298683,  9.9654226303, 12.1530313492],
#        device='cuda:0'), 'eta': 2.803709139698185e-05, 'tau²_hat': 16462.94921875}
# Test RMSE: 0.9060
# Test RRMSE: 0.0199
# Test rmsepd_sd: 0.0199
#
# --- Round 185 ---
# {'lengthscale': tensor([ 3.4745779037,  7.3831439018,  9.9655818939, 12.1424827576],
#        device='cuda:0'), 'eta': 2.8024900529999286e-05, 'tau²_hat': 16423.3984375}
# Test RMSE: 0.9003
# Test RRMSE: 0.0197
# Test rmsepd_sd: 0.0197
#
# --- Round 186 ---
# {'lengthscale': tensor([ 3.4745805264,  7.3831400871,  9.9655838013, 12.1422805786],
#        device='cuda:0'), 'eta': 2.802468770823907e-05, 'tau²_hat': 16420.181640625}
# Test RMSE: 0.8957
# Test RRMSE: 0.0196
# Test rmsepd_sd: 0.0196
#
# --- Round 187 ---
# {'lengthscale': tensor([ 3.4746799469,  7.3829560280,  9.9656791687, 12.1318454742],
#        device='cuda:0'), 'eta': 2.8012396796839312e-05, 'tau²_hat': 16379.978515625}
# Test RMSE: 0.8994
# Test RRMSE: 0.0197
# Test rmsepd_sd: 0.0197
#
# --- Round 188 ---
# {'lengthscale': tensor([ 3.4746799469,  7.3829560280,  9.9656791687, 12.1318454742],
#        device='cuda:0'), 'eta': 2.8012396796839312e-05, 'tau²_hat': 16141.1298828125}
# Test RMSE: 0.8896
# Test RRMSE: 0.0195
# Test rmsepd_sd: 0.0195
#
# --- Round 189 ---
# {'lengthscale': tensor([ 3.4746799469,  7.3829536438,  9.9656791687, 12.1317176819],
#        device='cuda:0'), 'eta': 2.80122367257718e-05, 'tau²_hat': 16247.345703125}
# Test RMSE: 0.8902
# Test RRMSE: 0.0195
# Test rmsepd_sd: 0.0195
#
# --- Round 190 ---
# {'lengthscale': tensor([ 3.4746799469,  7.3829512596,  9.9656791687, 12.1315860748],
#        device='cuda:0'), 'eta': 2.8012076654704288e-05, 'tau²_hat': 16250.6435546875}
# Test RMSE: 0.8901
# Test RRMSE: 0.0195
# Test rmsepd_sd: 0.0195
#
# --- Round 191 ---
# {'lengthscale': tensor([ 3.4746799469,  7.3829512596,  9.9656791687, 12.1315822601],
#        device='cuda:0'), 'eta': 2.8012076654704288e-05, 'tau²_hat': 16266.36328125}
# Test RMSE: 0.8934
# Test RRMSE: 0.0196
# Test rmsepd_sd: 0.0196
#
# --- Round 192 ---
# {'lengthscale': tensor([ 3.4746787548,  7.3828344345,  9.9657125473, 12.1262617111],
#        device='cuda:0'), 'eta': 2.8005852072965354e-05, 'tau²_hat': 16247.7431640625}
# Test RMSE: 0.8998
# Test RRMSE: 0.0197
# Test rmsepd_sd: 0.0197
#
# --- Round 193 ---
# {'lengthscale': tensor([ 3.4746787548,  7.3828339577,  9.9657125473, 12.1262416840],
#        device='cuda:0'), 'eta': 2.8005826607113704e-05, 'tau²_hat': 16094.791015625}
# Test RMSE: 0.8991
# Test RRMSE: 0.0197
# Test rmsepd_sd: 0.0197
#
# --- Round 194 ---
# {'lengthscale': tensor([ 3.4746789932,  7.3828310966,  9.9657125473, 12.1260995865],
#        device='cuda:0'), 'eta': 2.8005666536046192e-05, 'tau²_hat': 16109.7607421875}
# Test RMSE: 0.8955
# Test RRMSE: 0.0196
# Test rmsepd_sd: 0.0196
#
# --- Round 195 ---
# {'lengthscale': tensor([ 3.4746797085,  7.3828287125,  9.9657125473, 12.1259784698],
#        device='cuda:0'), 'eta': 2.800553193083033e-05, 'tau²_hat': 15993.1142578125}
# Test RMSE: 0.8886
# Test RRMSE: 0.0195
# Test rmsepd_sd: 0.0195
#
# --- Round 196 ---
# {'lengthscale': tensor([ 3.4746799469,  7.3828263283,  9.9657125473, 12.1258420944],
#        device='cuda:0'), 'eta': 2.8005371859762818e-05, 'tau²_hat': 16036.6484375}
# Test RMSE: 0.8884
# Test RRMSE: 0.0195
# Test rmsepd_sd: 0.0195
#
# --- Round 197 ---
# {'lengthscale': tensor([ 3.4746479988,  7.3823928833,  9.9657344818, 12.1128950119],
#        device='cuda:0'), 'eta': 2.7990607122774236e-05, 'tau²_hat': 16036.1787109375}
# Test RMSE: 0.8915
# Test RRMSE: 0.0195
# Test rmsepd_sd: 0.0195
#
# --- Round 198 ---
# {'lengthscale': tensor([ 3.4746475220,  7.3823904991,  9.9657344818, 12.1128282547],
#        device='cuda:0'), 'eta': 2.799052708724048e-05, 'tau²_hat': 16159.3525390625}
# Test RMSE: 0.8922
# Test RRMSE: 0.0196
# Test rmsepd_sd: 0.0195
#
# --- Round 199 ---
# {'lengthscale': tensor([ 3.4746458530,  7.3822245598,  9.9657535553, 12.1068353653],
#        device='cuda:0'), 'eta': 2.79836112895282e-05, 'tau²_hat': 16772.0546875}
# Test RMSE: 0.8894
# Test RRMSE: 0.0195
# Test rmsepd_sd: 0.0195

# %%
print('final result', result_random['rmspesd'][-1])
print('first result', result_random['rmspesd'][0])
print('best result',min(result_random['rmspesd']))
# Out:
# final result 0.019487928599119186
# first result 0.10771948844194412
# best result 0.019465720281004906

# %%
print('final result', result_random['rrmse'][-1])
print('first result', result_random['rrmse'][0])
print('best result',min(result_random['rrmse']))
# Out:
# final result 0.01949768140912056
# first result 0.10777338594198227
# best result 0.019475458189845085

# %%
print('final result', result_random['rmse'][-1])
print('first result', result_random['rmse'][0])
print('best result',min(result_random['rmse']))
plt.plot(result_random['rmse']);
# Out:
# final result 0.8893815875053406
# first result 4.916054725646973
# best result 0.8883680105209351
